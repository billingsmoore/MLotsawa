# %%
from datasets import load_dataset
train_dataset = load_dataset('pandas', data_files='/home/j/Documents/Projects/MLotsawa/data/large-dfs/10M-train.p', streaming=True)
eval_dataset = load_dataset('pandas', data_files='/home/j/Documents/Projects/MLotsawa/data/large-dfs/100k-eval.p', streaming=True)

# %%
from transformers import AutoTokenizer, DataCollatorForSeq2Seq

checkpoint = "/home/j/Documents/Projects/MLotsawa/models/final-model/small-data/checkpoint-375000"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)
# Out:
# 2024-08-19 14:11:13.657326: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-19 14:11:13.657374: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-19 14:11:13.657416: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-19 14:11:13.667362: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
source_lang = 'bo'
target_lang = 'en'
prefix = "translate Tibetan to English: "

def preprocess_function(examples):

    inputs = [prefix + example[source_lang] for example in examples['translation']]
    targets = [example[target_lang] for example in examples['translation']]
    
    model_inputs = tokenizer(inputs, text_target=targets, max_length=128, truncation=True)

    return model_inputs

# %%
tokenized_train_dataset = train_dataset.map(preprocess_function, batched=True)
tokenized_eval_dataset = eval_dataset.map(preprocess_function, batched=True)

# %%
import evaluate

metric = evaluate.load("sacrebleu")

# %%
import numpy as np


def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]

    return preds, labels


def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}

    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}
    return result

# %%
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer, EarlyStoppingCallback, Adafactor

early_stop = EarlyStoppingCallback()

model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint, device_map="auto")

optimizer = Adafactor(
    model.parameters(), 
    scale_parameter=True, 
    relative_step=False, 
    warmup_init=False, 
    lr=2e-5
)

# %%
from accelerate import Accelerator

accelerator = Accelerator()
model, optimizer = accelerator.prepare(model, optimizer)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir=f"../../models/final-model/",
    auto_find_batch_size=True,
    predict_with_generate=True,
    fp16=False, #check this
    push_to_hub=False,
    eval_strategy='epoch',
    save_strategy='epoch',
    load_best_model_at_end=True,
    max_steps=12500000
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset['train'],
    eval_dataset=tokenized_eval_dataset['train'],
    tokenizer=tokenizer,
    optimizers=(optimizer, None),
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    callbacks=[early_stop]
)

trainer.train()
# Out:
# max_steps is given, it will override any value given in num_train_epochs
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: billingsmoore. Use `wandb login --relogin` to force relogin
# wandb version 0.17.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>/home/j/Documents/Projects/MLotsawa/notebooks/final-model-training/wandb/run-20240819_141150-jfooqydd</code>
# Syncing run <strong><a href='https://wandb.ai/billingsmoore/huggingface/runs/jfooqydd/workspace' target="_blank">../../models/final-model/</a></strong> to <a href='https://wandb.ai/billingsmoore/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/billingsmoore/huggingface' target="_blank">https://wandb.ai/billingsmoore/huggingface</a>
#  View run at <a href='https://wandb.ai/billingsmoore/huggingface/runs/jfooqydd/workspace' target="_blank">https://wandb.ai/billingsmoore/huggingface/runs/jfooqydd/workspace</a>
#   0%|          | 0/12500000 [00:00<?, ?it/s]
# {'loss': 0.1247, 'grad_norm': 0.4581294655799866, 'learning_rate': 1.99992e-05, 'epoch': 0.0}
# {'loss': 0.1071, 'grad_norm': 0.5393722057342529, 'learning_rate': 1.99984e-05, 'epoch': 0.0}
# {'loss': 0.1167, 'grad_norm': 4.868246078491211, 'learning_rate': 1.9997600000000003e-05, 'epoch': 0.0}
# {'loss': 0.1111, 'grad_norm': 3.3111374378204346, 'learning_rate': 1.99968e-05, 'epoch': 0.0}
# {'loss': 0.1056, 'grad_norm': 1.5437523126602173, 'learning_rate': 1.9996000000000003e-05, 'epoch': 0.0}
# {'loss': 0.1172, 'grad_norm': 3.7210566997528076, 'learning_rate': 1.99952e-05, 'epoch': 0.0}
# {'loss': 0.113, 'grad_norm': 1.6470668315887451, 'learning_rate': 1.9994400000000003e-05, 'epoch': 0.0}
# {'loss': 0.1188, 'grad_norm': 2.9195923805236816, 'learning_rate': 1.99936e-05, 'epoch': 0.0}
# {'loss': 0.1186, 'grad_norm': 4.325334072113037, 'learning_rate': 1.9992800000000003e-05, 'epoch': 0.0}
# {'loss': 0.1186, 'grad_norm': 1.1441690921783447, 'learning_rate': 1.9992e-05, 'epoch': 0.0}
# {'loss': 0.1042, 'grad_norm': 3.4765310287475586, 'learning_rate': 1.9991200000000003e-05, 'epoch': 0.0}
# {'loss': 0.0989, 'grad_norm': 1.2201193571090698, 'learning_rate': 1.99904e-05, 'epoch': 0.0}
# {'loss': 0.1093, 'grad_norm': 8.31320571899414, 'learning_rate': 1.9989600000000003e-05, 'epoch': 0.0}
# {'loss': 0.1145, 'grad_norm': 5.0943098068237305, 'learning_rate': 1.99888e-05, 'epoch': 0.0}
# {'loss': 0.1093, 'grad_norm': 2.2370824813842773, 'learning_rate': 1.9988000000000002e-05, 'epoch': 0.0}
# {'loss': 0.1118, 'grad_norm': 2.377009391784668, 'learning_rate': 1.99872e-05, 'epoch': 0.0}
# {'loss': 0.097, 'grad_norm': 2.417933940887451, 'learning_rate': 1.9986400000000002e-05, 'epoch': 0.0}
# {'loss': 0.1004, 'grad_norm': 5.034811973571777, 'learning_rate': 1.99856e-05, 'epoch': 0.0}
# {'loss': 0.1083, 'grad_norm': 0.4002091586589813, 'learning_rate': 1.9984800000000002e-05, 'epoch': 0.0}
# {'loss': 0.1036, 'grad_norm': 0.6039993762969971, 'learning_rate': 1.9984e-05, 'epoch': 0.0}
# {'loss': 0.1031, 'grad_norm': 4.938512802124023, 'learning_rate': 1.9983200000000002e-05, 'epoch': 0.0}
# {'loss': 0.1072, 'grad_norm': 0.719749391078949, 'learning_rate': 1.99824e-05, 'epoch': 0.0}
# {'loss': 0.0924, 'grad_norm': 1.3854188919067383, 'learning_rate': 1.9981600000000002e-05, 'epoch': 0.0}
# {'loss': 0.1015, 'grad_norm': 0.393837034702301, 'learning_rate': 1.9980800000000004e-05, 'epoch': 0.0}
# {'loss': 0.1001, 'grad_norm': 1.18366277217865, 'learning_rate': 1.9980000000000002e-05, 'epoch': 0.0}
# {'loss': 0.094, 'grad_norm': 2.4660890102386475, 'learning_rate': 1.99792e-05, 'epoch': 0.0}
# {'loss': 0.1022, 'grad_norm': 1.6957378387451172, 'learning_rate': 1.9978400000000002e-05, 'epoch': 0.0}
# {'loss': 0.0934, 'grad_norm': 0.7366882562637329, 'learning_rate': 1.99776e-05, 'epoch': 0.0}
# {'loss': 0.0906, 'grad_norm': 1.5012097358703613, 'learning_rate': 1.99768e-05, 'epoch': 0.0}
# {'loss': 0.1008, 'grad_norm': 3.800572633743286, 'learning_rate': 1.9976000000000003e-05, 'epoch': 0.0}
# {'loss': 0.0985, 'grad_norm': 0.3792848289012909, 'learning_rate': 1.99752e-05, 'epoch': 0.0}
# {'loss': 0.1022, 'grad_norm': 3.0615603923797607, 'learning_rate': 1.9974400000000003e-05, 'epoch': 0.0}
# {'loss': 0.093, 'grad_norm': 3.098376512527466, 'learning_rate': 1.99736e-05, 'epoch': 0.0}
# {'loss': 0.096, 'grad_norm': 3.3008499145507812, 'learning_rate': 1.99728e-05, 'epoch': 0.0}
# {'loss': 0.0969, 'grad_norm': 1.4193196296691895, 'learning_rate': 1.9972e-05, 'epoch': 0.0}
# {'loss': 0.0969, 'grad_norm': 0.7625262141227722, 'learning_rate': 1.9971200000000003e-05, 'epoch': 0.0}
# {'loss': 0.0994, 'grad_norm': 4.614139080047607, 'learning_rate': 1.99704e-05, 'epoch': 0.0}
# {'loss': 0.0875, 'grad_norm': 2.581477165222168, 'learning_rate': 1.9969600000000003e-05, 'epoch': 0.0}
# {'loss': 0.097, 'grad_norm': 1.471432089805603, 'learning_rate': 1.99688e-05, 'epoch': 0.0}
# {'loss': 0.1029, 'grad_norm': 2.1521363258361816, 'learning_rate': 1.9968e-05, 'epoch': 0.0}
# {'loss': 0.0921, 'grad_norm': 0.7055982947349548, 'learning_rate': 1.99672e-05, 'epoch': 0.0}
# {'loss': 0.1003, 'grad_norm': 2.3710880279541016, 'learning_rate': 1.9966400000000002e-05, 'epoch': 0.0}
# {'loss': 0.0902, 'grad_norm': 0.1577298939228058, 'learning_rate': 1.99656e-05, 'epoch': 0.0}
# {'loss': 0.097, 'grad_norm': 1.2711148262023926, 'learning_rate': 1.9964800000000002e-05, 'epoch': 0.0}
# {'loss': 0.0916, 'grad_norm': 0.9545369744300842, 'learning_rate': 1.9964e-05, 'epoch': 0.0}
# {'loss': 0.0985, 'grad_norm': 3.565507173538208, 'learning_rate': 1.9963200000000002e-05, 'epoch': 0.0}
# {'loss': 0.0975, 'grad_norm': 6.744791507720947, 'learning_rate': 1.99624e-05, 'epoch': 0.0}
# {'loss': 0.099, 'grad_norm': 5.147609233856201, 'learning_rate': 1.9961600000000002e-05, 'epoch': 0.0}
# {'loss': 0.0917, 'grad_norm': 0.8118904829025269, 'learning_rate': 1.9960800000000004e-05, 'epoch': 0.0}
# {'loss': 0.115, 'grad_norm': 0.7114571332931519, 'learning_rate': 1.9960000000000002e-05, 'epoch': 0.0}
# {'loss': 0.1055, 'grad_norm': 2.8875226974487305, 'learning_rate': 1.99592e-05, 'epoch': 0.0}
# {'loss': 0.0923, 'grad_norm': 0.9002262949943542, 'learning_rate': 1.9958400000000002e-05, 'epoch': 0.0}
# {'loss': 0.0923, 'grad_norm': 3.071425437927246, 'learning_rate': 1.99576e-05, 'epoch': 0.0}
# {'loss': 0.0942, 'grad_norm': 0.07359050214290619, 'learning_rate': 1.9956800000000002e-05, 'epoch': 0.0}
# {'loss': 0.1035, 'grad_norm': 0.5431602001190186, 'learning_rate': 1.9956000000000003e-05, 'epoch': 0.0}
# {'loss': 0.1002, 'grad_norm': 0.6562232971191406, 'learning_rate': 1.99552e-05, 'epoch': 0.0}
# {'loss': 0.0893, 'grad_norm': 1.773655652999878, 'learning_rate': 1.9954400000000003e-05, 'epoch': 0.0}
# {'loss': 0.0843, 'grad_norm': 0.8475350141525269, 'learning_rate': 1.99536e-05, 'epoch': 0.0}
# {'loss': 0.0952, 'grad_norm': 1.3600174188613892, 'learning_rate': 1.99528e-05, 'epoch': 0.0}
# {'loss': 0.0984, 'grad_norm': 2.3999717235565186, 'learning_rate': 1.9952e-05, 'epoch': 0.0}
# {'loss': 0.0913, 'grad_norm': 1.005608081817627, 'learning_rate': 1.9951200000000003e-05, 'epoch': 0.0}
# {'loss': 0.1016, 'grad_norm': 3.9124794006347656, 'learning_rate': 1.99504e-05, 'epoch': 0.0}
# {'loss': 0.0814, 'grad_norm': 0.9553916454315186, 'learning_rate': 1.9949600000000003e-05, 'epoch': 0.0}
# {'loss': 0.091, 'grad_norm': 0.2316357046365738, 'learning_rate': 1.99488e-05, 'epoch': 0.0}
# {'loss': 0.0896, 'grad_norm': 0.9137887954711914, 'learning_rate': 1.9948e-05, 'epoch': 0.0}
# {'loss': 0.0865, 'grad_norm': 5.5762104988098145, 'learning_rate': 1.99472e-05, 'epoch': 0.0}
# {'loss': 0.0886, 'grad_norm': 5.881746768951416, 'learning_rate': 1.9946400000000003e-05, 'epoch': 0.0}
# {'loss': 0.0879, 'grad_norm': 2.443096876144409, 'learning_rate': 1.9945600000000004e-05, 'epoch': 0.0}
# {'loss': 0.0899, 'grad_norm': 1.1495591402053833, 'learning_rate': 1.9944800000000003e-05, 'epoch': 0.0}
# {'loss': 0.0974, 'grad_norm': 5.4625444412231445, 'learning_rate': 1.9944e-05, 'epoch': 0.0}
# {'loss': 0.0932, 'grad_norm': 1.2362680435180664, 'learning_rate': 1.9943200000000002e-05, 'epoch': 0.0}
# {'loss': 0.0959, 'grad_norm': 0.6111265420913696, 'learning_rate': 1.99424e-05, 'epoch': 0.0}
# {'loss': 0.0796, 'grad_norm': 1.7583338022232056, 'learning_rate': 1.9941600000000002e-05, 'epoch': 0.0}
# {'loss': 0.0839, 'grad_norm': 5.008857250213623, 'learning_rate': 1.9940800000000004e-05, 'epoch': 0.0}
# {'loss': 0.1011, 'grad_norm': 6.451408863067627, 'learning_rate': 1.9940000000000002e-05, 'epoch': 0.0}
# {'loss': 0.093, 'grad_norm': 0.6230709552764893, 'learning_rate': 1.99392e-05, 'epoch': 0.0}
# {'loss': 0.0894, 'grad_norm': 0.5339965224266052, 'learning_rate': 1.9938400000000002e-05, 'epoch': 0.0}
# {'loss': 0.0932, 'grad_norm': 1.3792039155960083, 'learning_rate': 1.99376e-05, 'epoch': 0.0}
# {'loss': 0.0955, 'grad_norm': 1.2379297018051147, 'learning_rate': 1.9936800000000002e-05, 'epoch': 0.0}
# {'loss': 0.0922, 'grad_norm': 1.1163939237594604, 'learning_rate': 1.9936000000000004e-05, 'epoch': 0.0}
# {'loss': 0.0837, 'grad_norm': 0.6208403706550598, 'learning_rate': 1.9935200000000002e-05, 'epoch': 0.0}
# {'loss': 0.0851, 'grad_norm': 3.181238889694214, 'learning_rate': 1.9934400000000003e-05, 'epoch': 0.0}
# {'loss': 0.0946, 'grad_norm': 2.302030563354492, 'learning_rate': 1.9933600000000002e-05, 'epoch': 0.0}
# {'loss': 0.0909, 'grad_norm': 1.9412455558776855, 'learning_rate': 1.99328e-05, 'epoch': 0.0}
# {'loss': 0.0969, 'grad_norm': 4.255438804626465, 'learning_rate': 1.9932e-05, 'epoch': 0.0}
# {'loss': 0.0789, 'grad_norm': 0.46568918228149414, 'learning_rate': 1.9931200000000003e-05, 'epoch': 0.0}
# {'loss': 0.0874, 'grad_norm': 1.8882317543029785, 'learning_rate': 1.99304e-05, 'epoch': 0.0}
# {'loss': 0.0862, 'grad_norm': 1.3817627429962158, 'learning_rate': 1.9929600000000003e-05, 'epoch': 0.0}
# wandb: 429 encountered (Filestream rate limit exceeded, retrying in 2.1 seconds.), retrying request
# wandb: 429 encountered (Filestream rate limit exceeded, retrying in 4.0 seconds.), retrying request
# wandb: 429 encountered (Filestream rate limit exceeded, retrying in 8.9 seconds.), retrying request
# wandb: 429 encountered (Filestream rate limit exceeded, retrying in 18.8 seconds.), retrying request
# wandb: 429 encountered (Filestream rate limit exceeded, retrying in 38.5 seconds.), retrying request
# wandb: 429 encountered (Filestream rate limit exceeded, retrying in 66.4 seconds.), retrying request
# wandb: 429 encountered (Filestream rate limit exceeded, retrying in 151.5 seconds.), retrying request
# {'loss': 0.0989, 'grad_norm': 0.49329954385757446, 'learning_rate': 1.99288e-05, 'epoch': 0.0}
# {'loss': 0.0785, 'grad_norm': 4.125942707061768, 'learning_rate': 1.9928e-05, 'epoch': 0.0}
# {'loss': 0.0893, 'grad_norm': 0.5031408071517944, 'learning_rate': 1.99272e-05, 'epoch': 0.0}
# {'loss': 0.0918, 'grad_norm': 1.6843091249465942, 'learning_rate': 1.9926400000000003e-05, 'epoch': 0.0}
# {'loss': 0.09, 'grad_norm': 0.264239639043808, 'learning_rate': 1.99256e-05, 'epoch': 0.0}
# {'loss': 0.0811, 'grad_norm': 2.119865894317627, 'learning_rate': 1.9924800000000003e-05, 'epoch': 0.0}
# {'loss': 0.0921, 'grad_norm': 0.9816790819168091, 'learning_rate': 1.9924e-05, 'epoch': 0.0}
# {'loss': 0.0858, 'grad_norm': 0.18175910413265228, 'learning_rate': 1.9923200000000003e-05, 'epoch': 0.0}
# {'loss': 0.0981, 'grad_norm': 6.538459777832031, 'learning_rate': 1.99224e-05, 'epoch': 0.0}
# {'loss': 0.0828, 'grad_norm': 0.7483553290367126, 'learning_rate': 1.9921600000000003e-05, 'epoch': 0.0}
# {'loss': 0.0782, 'grad_norm': 3.773745536804199, 'learning_rate': 1.99208e-05, 'epoch': 0.0}
# {'loss': 0.094, 'grad_norm': 0.48785579204559326, 'learning_rate': 1.9920000000000002e-05, 'epoch': 0.0}
# {'loss': 0.0909, 'grad_norm': 2.7550697326660156, 'learning_rate': 1.99192e-05, 'epoch': 0.0}
# {'loss': 0.0888, 'grad_norm': 0.701461672782898, 'learning_rate': 1.9918400000000002e-05, 'epoch': 0.0}
# {'loss': 0.0959, 'grad_norm': 0.49132320284843445, 'learning_rate': 1.99176e-05, 'epoch': 0.0}
# {'loss': 0.0854, 'grad_norm': 0.8704651594161987, 'learning_rate': 1.9916800000000002e-05, 'epoch': 0.0}
# {'loss': 0.0886, 'grad_norm': 1.1213754415512085, 'learning_rate': 1.9916e-05, 'epoch': 0.0}
# {'loss': 0.0897, 'grad_norm': 1.7788504362106323, 'learning_rate': 1.9915200000000002e-05, 'epoch': 0.0}
# {'loss': 0.0749, 'grad_norm': 1.402925968170166, 'learning_rate': 1.9914400000000004e-05, 'epoch': 0.0}
# {'loss': 0.0892, 'grad_norm': 0.43345558643341064, 'learning_rate': 1.9913600000000002e-05, 'epoch': 0.0}
# {'loss': 0.0856, 'grad_norm': 0.45320117473602295, 'learning_rate': 1.99128e-05, 'epoch': 0.0}
# {'loss': 0.0888, 'grad_norm': 0.6553112864494324, 'learning_rate': 1.9912000000000002e-05, 'epoch': 0.0}
# {'loss': 0.0863, 'grad_norm': 0.33558177947998047, 'learning_rate': 1.99112e-05, 'epoch': 0.0}
# {'loss': 0.0864, 'grad_norm': 3.2738184928894043, 'learning_rate': 1.99104e-05, 'epoch': 0.0}
# {'loss': 0.0953, 'grad_norm': 2.5208964347839355, 'learning_rate': 1.9909600000000003e-05, 'epoch': 0.0}
# {'loss': 0.0827, 'grad_norm': 1.1465048789978027, 'learning_rate': 1.99088e-05, 'epoch': 0.0}
# {'loss': 0.0878, 'grad_norm': 1.657470703125, 'learning_rate': 1.9908e-05, 'epoch': 0.0}
# {'loss': 0.0866, 'grad_norm': 0.8877092599868774, 'learning_rate': 1.99072e-05, 'epoch': 0.0}
# {'loss': 0.0953, 'grad_norm': 2.3125531673431396, 'learning_rate': 1.99064e-05, 'epoch': 0.0}
# {'loss': 0.0848, 'grad_norm': 1.0024480819702148, 'learning_rate': 1.99056e-05, 'epoch': 0.0}
# {'loss': 0.0807, 'grad_norm': 0.38106679916381836, 'learning_rate': 1.9904800000000003e-05, 'epoch': 0.0}
# {'loss': 0.1021, 'grad_norm': 1.1066105365753174, 'learning_rate': 1.9904e-05, 'epoch': 0.0}
# {'loss': 0.083, 'grad_norm': 0.39502593874931335, 'learning_rate': 1.9903200000000003e-05, 'epoch': 0.0}
# {'loss': 0.0831, 'grad_norm': 0.006163346581161022, 'learning_rate': 1.99024e-05, 'epoch': 0.0}
# {'loss': 0.0827, 'grad_norm': 3.031498908996582, 'learning_rate': 1.99016e-05, 'epoch': 0.0}
# {'loss': 0.087, 'grad_norm': 0.3811946511268616, 'learning_rate': 1.99008e-05, 'epoch': 0.0}
# {'loss': 0.082, 'grad_norm': 0.7064069509506226, 'learning_rate': 1.9900000000000003e-05, 'epoch': 0.01}
# {'loss': 0.0786, 'grad_norm': 3.343064069747925, 'learning_rate': 1.98992e-05, 'epoch': 0.01}
# {'loss': 0.0767, 'grad_norm': 0.9204462170600891, 'learning_rate': 1.9898400000000002e-05, 'epoch': 0.01}
# {'loss': 0.0938, 'grad_norm': 0.6461649537086487, 'learning_rate': 1.98976e-05, 'epoch': 0.01}
# {'loss': 0.0789, 'grad_norm': 2.638557195663452, 'learning_rate': 1.98968e-05, 'epoch': 0.01}
# {'loss': 0.0952, 'grad_norm': 0.787715494632721, 'learning_rate': 1.9896e-05, 'epoch': 0.01}
# {'loss': 0.0956, 'grad_norm': 1.9461159706115723, 'learning_rate': 1.9895200000000002e-05, 'epoch': 0.01}
# {'loss': 0.0851, 'grad_norm': 0.9839295148849487, 'learning_rate': 1.9894400000000004e-05, 'epoch': 0.01}
# {'loss': 0.0797, 'grad_norm': 2.1001174449920654, 'learning_rate': 1.9893600000000002e-05, 'epoch': 0.01}
# {'loss': 0.0747, 'grad_norm': 3.7252488136291504, 'learning_rate': 1.98928e-05, 'epoch': 0.01}
# {'loss': 0.0718, 'grad_norm': 4.765319347381592, 'learning_rate': 1.9892000000000002e-05, 'epoch': 0.01}
# {'loss': 0.0846, 'grad_norm': 1.1588715314865112, 'learning_rate': 1.98912e-05, 'epoch': 0.01}
# {'loss': 0.0829, 'grad_norm': 1.9019724130630493, 'learning_rate': 1.9890400000000002e-05, 'epoch': 0.01}
# {'loss': 0.0839, 'grad_norm': 2.4844043254852295, 'learning_rate': 1.9889600000000004e-05, 'epoch': 0.01}
# {'loss': 0.0818, 'grad_norm': 7.714366912841797, 'learning_rate': 1.9888800000000002e-05, 'epoch': 0.01}
# {'loss': 0.0882, 'grad_norm': 1.7231141328811646, 'learning_rate': 1.9888e-05, 'epoch': 0.01}
# {'loss': 0.097, 'grad_norm': 0.4469497799873352, 'learning_rate': 1.98872e-05, 'epoch': 0.01}
# {'loss': 0.0867, 'grad_norm': 1.1290916204452515, 'learning_rate': 1.98864e-05, 'epoch': 0.01}
# {'loss': 0.0872, 'grad_norm': 0.6194567084312439, 'learning_rate': 1.98856e-05, 'epoch': 0.01}
# {'loss': 0.0842, 'grad_norm': 0.7033308148384094, 'learning_rate': 1.9884800000000003e-05, 'epoch': 0.01}
# {'loss': 0.0817, 'grad_norm': 1.2630164623260498, 'learning_rate': 1.9884e-05, 'epoch': 0.01}
# {'loss': 0.087, 'grad_norm': 0.2216314673423767, 'learning_rate': 1.9883200000000003e-05, 'epoch': 0.01}
# {'loss': 0.0852, 'grad_norm': 1.369900107383728, 'learning_rate': 1.98824e-05, 'epoch': 0.01}
# {'loss': 0.0841, 'grad_norm': 0.5798447132110596, 'learning_rate': 1.98816e-05, 'epoch': 0.01}
# {'loss': 0.089, 'grad_norm': 0.2155815064907074, 'learning_rate': 1.98808e-05, 'epoch': 0.01}
# {'loss': 0.0867, 'grad_norm': 2.463897943496704, 'learning_rate': 1.9880000000000003e-05, 'epoch': 0.01}
# {'loss': 0.0732, 'grad_norm': 0.531271755695343, 'learning_rate': 1.98792e-05, 'epoch': 0.01}
# {'loss': 0.0716, 'grad_norm': 0.6061621904373169, 'learning_rate': 1.9878400000000003e-05, 'epoch': 0.01}
# {'loss': 0.0854, 'grad_norm': 0.45419690012931824, 'learning_rate': 1.98776e-05, 'epoch': 0.01}
# {'loss': 0.0807, 'grad_norm': 0.6842675805091858, 'learning_rate': 1.98768e-05, 'epoch': 0.01}
# {'loss': 0.0864, 'grad_norm': 2.9795165061950684, 'learning_rate': 1.9876e-05, 'epoch': 0.01}
# {'loss': 0.0749, 'grad_norm': 1.025601863861084, 'learning_rate': 1.9875200000000002e-05, 'epoch': 0.01}
# {'loss': 0.081, 'grad_norm': 0.9976598620414734, 'learning_rate': 1.9874400000000004e-05, 'epoch': 0.01}
# {'loss': 0.0823, 'grad_norm': 1.820642352104187, 'learning_rate': 1.9873600000000002e-05, 'epoch': 0.01}
# {'loss': 0.0789, 'grad_norm': 0.5540792942047119, 'learning_rate': 1.98728e-05, 'epoch': 0.01}
# {'loss': 0.0892, 'grad_norm': 0.5524898171424866, 'learning_rate': 1.9872000000000002e-05, 'epoch': 0.01}
# {'loss': 0.0843, 'grad_norm': 0.154519721865654, 'learning_rate': 1.98712e-05, 'epoch': 0.01}
# {'loss': 0.0806, 'grad_norm': 3.456918716430664, 'learning_rate': 1.9870400000000002e-05, 'epoch': 0.01}
# {'loss': 0.0794, 'grad_norm': 2.687344789505005, 'learning_rate': 1.9869600000000004e-05, 'epoch': 0.01}
# {'loss': 0.0839, 'grad_norm': 2.8040921688079834, 'learning_rate': 1.9868800000000002e-05, 'epoch': 0.01}
# {'loss': 0.0918, 'grad_norm': 5.091470718383789, 'learning_rate': 1.9868e-05, 'epoch': 0.01}
# {'loss': 0.0776, 'grad_norm': 0.6684181690216064, 'learning_rate': 1.9867200000000002e-05, 'epoch': 0.01}
# {'loss': 0.0833, 'grad_norm': 1.6346449851989746, 'learning_rate': 1.98664e-05, 'epoch': 0.01}
# {'loss': 0.0795, 'grad_norm': 3.5596847534179688, 'learning_rate': 1.9865600000000002e-05, 'epoch': 0.01}
# {'loss': 0.0885, 'grad_norm': 0.5687695741653442, 'learning_rate': 1.9864800000000003e-05, 'epoch': 0.01}
# {'loss': 0.083, 'grad_norm': 1.9722493886947632, 'learning_rate': 1.9864e-05, 'epoch': 0.01}
# {'loss': 0.0845, 'grad_norm': 0.9276267290115356, 'learning_rate': 1.9863200000000003e-05, 'epoch': 0.01}
# {'loss': 0.0805, 'grad_norm': 0.8471152782440186, 'learning_rate': 1.98624e-05, 'epoch': 0.01}
# {'loss': 0.0846, 'grad_norm': 4.6845173835754395, 'learning_rate': 1.98616e-05, 'epoch': 0.01}
# {'loss': 0.0854, 'grad_norm': 0.43732312321662903, 'learning_rate': 1.98608e-05, 'epoch': 0.01}
# {'loss': 0.084, 'grad_norm': 0.7355659008026123, 'learning_rate': 1.9860000000000003e-05, 'epoch': 0.01}
# {'loss': 0.0889, 'grad_norm': 0.5589942932128906, 'learning_rate': 1.98592e-05, 'epoch': 0.01}
# {'loss': 0.079, 'grad_norm': 0.40399283170700073, 'learning_rate': 1.9858400000000003e-05, 'epoch': 0.01}
# {'loss': 0.0886, 'grad_norm': 0.8030721545219421, 'learning_rate': 1.98576e-05, 'epoch': 0.01}
# {'loss': 0.0939, 'grad_norm': 0.29643839597702026, 'learning_rate': 1.98568e-05, 'epoch': 0.01}
# {'loss': 0.078, 'grad_norm': 0.270417183637619, 'learning_rate': 1.9856e-05, 'epoch': 0.01}
# {'loss': 0.0932, 'grad_norm': 0.36425095796585083, 'learning_rate': 1.9855200000000003e-05, 'epoch': 0.01}
# {'loss': 0.0817, 'grad_norm': 0.5637849569320679, 'learning_rate': 1.9854400000000004e-05, 'epoch': 0.01}
# {'loss': 0.0776, 'grad_norm': 2.614439010620117, 'learning_rate': 1.9853600000000002e-05, 'epoch': 0.01}
# {'loss': 0.0846, 'grad_norm': 0.44424697756767273, 'learning_rate': 1.98528e-05, 'epoch': 0.01}
# {'loss': 0.0869, 'grad_norm': 0.17014040052890778, 'learning_rate': 1.9852000000000002e-05, 'epoch': 0.01}
# {'loss': 0.0848, 'grad_norm': 2.7347168922424316, 'learning_rate': 1.98512e-05, 'epoch': 0.01}
# {'loss': 0.0761, 'grad_norm': 0.6295880079269409, 'learning_rate': 1.9850400000000002e-05, 'epoch': 0.01}
# {'loss': 0.0878, 'grad_norm': 1.4977846145629883, 'learning_rate': 1.9849600000000004e-05, 'epoch': 0.01}
# {'loss': 0.0775, 'grad_norm': 1.94245183467865, 'learning_rate': 1.9848800000000002e-05, 'epoch': 0.01}
# {'loss': 0.0833, 'grad_norm': 0.40981781482696533, 'learning_rate': 1.9848e-05, 'epoch': 0.01}
# {'loss': 0.0761, 'grad_norm': 0.9353693127632141, 'learning_rate': 1.9847200000000002e-05, 'epoch': 0.01}
# {'loss': 0.0793, 'grad_norm': 0.8722253441810608, 'learning_rate': 1.98464e-05, 'epoch': 0.01}
# {'loss': 0.0819, 'grad_norm': 0.5308172106742859, 'learning_rate': 1.9845600000000002e-05, 'epoch': 0.01}
# {'loss': 0.0825, 'grad_norm': 1.293738603591919, 'learning_rate': 1.9844800000000004e-05, 'epoch': 0.01}
# {'loss': 0.0797, 'grad_norm': 1.4478304386138916, 'learning_rate': 1.9844000000000002e-05, 'epoch': 0.01}
# {'loss': 0.0794, 'grad_norm': 3.1566102504730225, 'learning_rate': 1.9843200000000003e-05, 'epoch': 0.01}
# {'loss': 0.0847, 'grad_norm': 2.1823291778564453, 'learning_rate': 1.98424e-05, 'epoch': 0.01}
# {'loss': 0.08, 'grad_norm': 2.5040533542633057, 'learning_rate': 1.98416e-05, 'epoch': 0.01}
# {'loss': 0.0763, 'grad_norm': 3.2600700855255127, 'learning_rate': 1.98408e-05, 'epoch': 0.01}
# {'loss': 0.0925, 'grad_norm': 0.7200675010681152, 'learning_rate': 1.9840000000000003e-05, 'epoch': 0.01}
# {'loss': 0.0768, 'grad_norm': 2.535041332244873, 'learning_rate': 1.98392e-05, 'epoch': 0.01}
# {'loss': 0.0822, 'grad_norm': 1.6659332513809204, 'learning_rate': 1.9838400000000003e-05, 'epoch': 0.01}
# {'loss': 0.0813, 'grad_norm': 0.09677692502737045, 'learning_rate': 1.98376e-05, 'epoch': 0.01}
# {'loss': 0.0845, 'grad_norm': 0.4878136217594147, 'learning_rate': 1.9836800000000003e-05, 'epoch': 0.01}
# {'loss': 0.0815, 'grad_norm': 0.9763071537017822, 'learning_rate': 1.9836e-05, 'epoch': 0.01}
# {'loss': 0.085, 'grad_norm': 1.7410718202590942, 'learning_rate': 1.9835200000000003e-05, 'epoch': 0.01}
# {'loss': 0.0812, 'grad_norm': 1.8527052402496338, 'learning_rate': 1.98344e-05, 'epoch': 0.01}
# {'loss': 0.0814, 'grad_norm': 0.9487847089767456, 'learning_rate': 1.9833600000000003e-05, 'epoch': 0.01}
# {'loss': 0.0847, 'grad_norm': 1.5990214347839355, 'learning_rate': 1.98328e-05, 'epoch': 0.01}
# {'loss': 0.0808, 'grad_norm': 0.534866452217102, 'learning_rate': 1.9832000000000003e-05, 'epoch': 0.01}
# {'loss': 0.0831, 'grad_norm': 0.5718116164207458, 'learning_rate': 1.98312e-05, 'epoch': 0.01}
# {'loss': 0.0747, 'grad_norm': 2.0256295204162598, 'learning_rate': 1.9830400000000002e-05, 'epoch': 0.01}
# {'loss': 0.0808, 'grad_norm': 0.27333274483680725, 'learning_rate': 1.98296e-05, 'epoch': 0.01}
# {'loss': 0.0743, 'grad_norm': 1.5929299592971802, 'learning_rate': 1.9828800000000002e-05, 'epoch': 0.01}
# {'loss': 0.0871, 'grad_norm': 3.823453664779663, 'learning_rate': 1.9828e-05, 'epoch': 0.01}
# {'loss': 0.0854, 'grad_norm': 1.9058681726455688, 'learning_rate': 1.9827200000000002e-05, 'epoch': 0.01}
# {'loss': 0.0733, 'grad_norm': 3.3600246906280518, 'learning_rate': 1.98264e-05, 'epoch': 0.01}
# {'loss': 0.081, 'grad_norm': 1.47291100025177, 'learning_rate': 1.9825600000000002e-05, 'epoch': 0.01}
# {'loss': 0.0873, 'grad_norm': 0.8500998020172119, 'learning_rate': 1.98248e-05, 'epoch': 0.01}
# {'loss': 0.0813, 'grad_norm': 4.049737930297852, 'learning_rate': 1.9824000000000002e-05, 'epoch': 0.01}
# {'loss': 0.0719, 'grad_norm': 2.595839262008667, 'learning_rate': 1.9823200000000004e-05, 'epoch': 0.01}
# {'loss': 0.0857, 'grad_norm': 0.6239618062973022, 'learning_rate': 1.9822400000000002e-05, 'epoch': 0.01}
# {'loss': 0.0878, 'grad_norm': 0.3274669647216797, 'learning_rate': 1.98216e-05, 'epoch': 0.01}
# {'loss': 0.0757, 'grad_norm': 3.164156198501587, 'learning_rate': 1.9820800000000002e-05, 'epoch': 0.01}
# {'loss': 0.0863, 'grad_norm': 0.2631264626979828, 'learning_rate': 1.982e-05, 'epoch': 0.01}
# {'loss': 0.0829, 'grad_norm': 0.7723803520202637, 'learning_rate': 1.98192e-05, 'epoch': 0.01}
# {'loss': 0.0961, 'grad_norm': 0.18053409457206726, 'learning_rate': 1.9818400000000003e-05, 'epoch': 0.01}
# {'loss': 0.0764, 'grad_norm': 0.7984219193458557, 'learning_rate': 1.98176e-05, 'epoch': 0.01}
# {'loss': 0.0799, 'grad_norm': 0.28610366582870483, 'learning_rate': 1.9816800000000003e-05, 'epoch': 0.01}
# {'loss': 0.0749, 'grad_norm': 2.414944887161255, 'learning_rate': 1.9816e-05, 'epoch': 0.01}
# {'loss': 0.0821, 'grad_norm': 3.187591791152954, 'learning_rate': 1.98152e-05, 'epoch': 0.01}
# {'loss': 0.0824, 'grad_norm': 1.055737018585205, 'learning_rate': 1.98144e-05, 'epoch': 0.01}
# {'loss': 0.0773, 'grad_norm': 2.034315586090088, 'learning_rate': 1.9813600000000003e-05, 'epoch': 0.01}
# {'loss': 0.0774, 'grad_norm': 0.056867945939302444, 'learning_rate': 1.98128e-05, 'epoch': 0.01}
# {'loss': 0.0722, 'grad_norm': 0.8558516502380371, 'learning_rate': 1.9812000000000003e-05, 'epoch': 0.01}
# {'loss': 0.0776, 'grad_norm': 0.5963809490203857, 'learning_rate': 1.98112e-05, 'epoch': 0.01}
# {'loss': 0.0766, 'grad_norm': 2.2576329708099365, 'learning_rate': 1.98104e-05, 'epoch': 0.01}
# {'loss': 0.0842, 'grad_norm': 1.7135089635849, 'learning_rate': 1.98096e-05, 'epoch': 0.01}
# {'loss': 0.0781, 'grad_norm': 1.9959689378738403, 'learning_rate': 1.9808800000000003e-05, 'epoch': 0.01}
# {'loss': 0.0793, 'grad_norm': 0.29625141620635986, 'learning_rate': 1.9808e-05, 'epoch': 0.01}
# {'loss': 0.0817, 'grad_norm': 0.38800105452537537, 'learning_rate': 1.9807200000000002e-05, 'epoch': 0.01}
# {'loss': 0.0819, 'grad_norm': 0.6379688382148743, 'learning_rate': 1.98064e-05, 'epoch': 0.01}
# {'loss': 0.0759, 'grad_norm': 0.9054060578346252, 'learning_rate': 1.9805600000000002e-05, 'epoch': 0.01}
# {'loss': 0.084, 'grad_norm': 0.3952544629573822, 'learning_rate': 1.98048e-05, 'epoch': 0.01}
# {'loss': 0.0844, 'grad_norm': 0.22117187082767487, 'learning_rate': 1.9804000000000002e-05, 'epoch': 0.01}
# {'loss': 0.079, 'grad_norm': 1.0936009883880615, 'learning_rate': 1.9803200000000004e-05, 'epoch': 0.01}
# {'loss': 0.0819, 'grad_norm': 0.7311853170394897, 'learning_rate': 1.9802400000000002e-05, 'epoch': 0.01}
# {'loss': 0.0805, 'grad_norm': 0.18990889191627502, 'learning_rate': 1.98016e-05, 'epoch': 0.01}
# {'loss': 0.0705, 'grad_norm': 0.648890495300293, 'learning_rate': 1.9800800000000002e-05, 'epoch': 0.01}
# {'loss': 0.0835, 'grad_norm': 2.9612836837768555, 'learning_rate': 1.98e-05, 'epoch': 0.01}
# {'loss': 0.0817, 'grad_norm': 0.07928008586168289, 'learning_rate': 1.9799200000000002e-05, 'epoch': 0.01}
# {'loss': 0.0856, 'grad_norm': 0.746222734451294, 'learning_rate': 1.9798400000000003e-05, 'epoch': 0.01}
# {'loss': 0.0843, 'grad_norm': 0.6047323942184448, 'learning_rate': 1.97976e-05, 'epoch': 0.01}
# {'loss': 0.0739, 'grad_norm': 0.19065773487091064, 'learning_rate': 1.9796800000000003e-05, 'epoch': 0.01}
# {'loss': 0.0768, 'grad_norm': 5.078758716583252, 'learning_rate': 1.9796e-05, 'epoch': 0.01}
# {'loss': 0.074, 'grad_norm': 3.5276520252227783, 'learning_rate': 1.97952e-05, 'epoch': 0.01}
# {'loss': 0.0768, 'grad_norm': 0.40882548689842224, 'learning_rate': 1.97944e-05, 'epoch': 0.01}
# {'loss': 0.083, 'grad_norm': 0.30588072538375854, 'learning_rate': 1.9793600000000003e-05, 'epoch': 0.01}
# {'loss': 0.0878, 'grad_norm': 1.7025045156478882, 'learning_rate': 1.97928e-05, 'epoch': 0.01}
# {'loss': 0.0774, 'grad_norm': 0.3947487473487854, 'learning_rate': 1.9792000000000003e-05, 'epoch': 0.01}
# {'loss': 0.0822, 'grad_norm': 1.2508984804153442, 'learning_rate': 1.97912e-05, 'epoch': 0.01}
# {'loss': 0.0835, 'grad_norm': 0.4252771735191345, 'learning_rate': 1.97904e-05, 'epoch': 0.01}
# {'loss': 0.0731, 'grad_norm': 0.7296393513679504, 'learning_rate': 1.97896e-05, 'epoch': 0.01}
# {'loss': 0.0831, 'grad_norm': 1.1487271785736084, 'learning_rate': 1.9788800000000003e-05, 'epoch': 0.01}
# {'loss': 0.0797, 'grad_norm': 2.3267910480499268, 'learning_rate': 1.9788e-05, 'epoch': 0.01}
# {'loss': 0.0761, 'grad_norm': 0.053664445877075195, 'learning_rate': 1.9787200000000003e-05, 'epoch': 0.01}
# {'loss': 0.0844, 'grad_norm': 0.6402259469032288, 'learning_rate': 1.97864e-05, 'epoch': 0.01}
# {'loss': 0.0789, 'grad_norm': 1.422893762588501, 'learning_rate': 1.9785600000000002e-05, 'epoch': 0.01}
# {'loss': 0.0781, 'grad_norm': 0.5573852062225342, 'learning_rate': 1.97848e-05, 'epoch': 0.01}
# {'loss': 0.0857, 'grad_norm': 1.5110113620758057, 'learning_rate': 1.9784000000000002e-05, 'epoch': 0.01}
# {'loss': 0.0711, 'grad_norm': 0.3226838707923889, 'learning_rate': 1.9783200000000004e-05, 'epoch': 0.01}
# {'loss': 0.0713, 'grad_norm': 1.0161844491958618, 'learning_rate': 1.9782400000000002e-05, 'epoch': 0.01}
# {'loss': 0.0832, 'grad_norm': 0.85859215259552, 'learning_rate': 1.97816e-05, 'epoch': 0.01}
# {'loss': 0.0783, 'grad_norm': 0.7887800335884094, 'learning_rate': 1.9780800000000002e-05, 'epoch': 0.01}
# {'loss': 0.0844, 'grad_norm': 1.331489086151123, 'learning_rate': 1.978e-05, 'epoch': 0.01}
# {'loss': 0.0803, 'grad_norm': 1.1617586612701416, 'learning_rate': 1.9779200000000002e-05, 'epoch': 0.01}
# {'loss': 0.0864, 'grad_norm': 2.0364761352539062, 'learning_rate': 1.9778400000000004e-05, 'epoch': 0.01}
# {'loss': 0.0772, 'grad_norm': 1.110764980316162, 'learning_rate': 1.9777600000000002e-05, 'epoch': 0.01}
# {'loss': 0.0807, 'grad_norm': 0.27260923385620117, 'learning_rate': 1.9776800000000004e-05, 'epoch': 0.01}
# {'loss': 0.073, 'grad_norm': 4.636648178100586, 'learning_rate': 1.9776000000000002e-05, 'epoch': 0.01}
# {'loss': 0.0765, 'grad_norm': 1.0100551843643188, 'learning_rate': 1.97752e-05, 'epoch': 0.01}
# {'loss': 0.0737, 'grad_norm': 1.8222047090530396, 'learning_rate': 1.97744e-05, 'epoch': 0.01}
# {'loss': 0.0781, 'grad_norm': 1.5594645738601685, 'learning_rate': 1.9773600000000003e-05, 'epoch': 0.01}
# {'loss': 0.0687, 'grad_norm': 1.6028437614440918, 'learning_rate': 1.97728e-05, 'epoch': 0.01}
# {'loss': 0.0779, 'grad_norm': 0.8127254247665405, 'learning_rate': 1.9772000000000003e-05, 'epoch': 0.01}
# {'loss': 0.0743, 'grad_norm': 1.7236380577087402, 'learning_rate': 1.97712e-05, 'epoch': 0.01}
# {'loss': 0.0751, 'grad_norm': 0.8261565566062927, 'learning_rate': 1.97704e-05, 'epoch': 0.01}
# {'loss': 0.074, 'grad_norm': 0.8003330230712891, 'learning_rate': 1.97696e-05, 'epoch': 0.01}
# {'loss': 0.073, 'grad_norm': 0.33739084005355835, 'learning_rate': 1.9768800000000003e-05, 'epoch': 0.01}
# {'loss': 0.0808, 'grad_norm': 0.44435057044029236, 'learning_rate': 1.9768e-05, 'epoch': 0.01}
# {'loss': 0.0764, 'grad_norm': 0.965682327747345, 'learning_rate': 1.9767200000000003e-05, 'epoch': 0.01}
# {'loss': 0.0775, 'grad_norm': 1.5732640027999878, 'learning_rate': 1.97664e-05, 'epoch': 0.01}
# {'loss': 0.0722, 'grad_norm': 0.2881346344947815, 'learning_rate': 1.9765600000000003e-05, 'epoch': 0.01}
# {'loss': 0.0842, 'grad_norm': 1.1734144687652588, 'learning_rate': 1.97648e-05, 'epoch': 0.01}
# {'loss': 0.0754, 'grad_norm': 0.5641802549362183, 'learning_rate': 1.9764000000000003e-05, 'epoch': 0.01}
# {'loss': 0.0904, 'grad_norm': 1.356110692024231, 'learning_rate': 1.97632e-05, 'epoch': 0.01}
# {'loss': 0.0801, 'grad_norm': 6.744734287261963, 'learning_rate': 1.9762400000000002e-05, 'epoch': 0.01}
# {'loss': 0.0723, 'grad_norm': 1.2094107866287231, 'learning_rate': 1.97616e-05, 'epoch': 0.01}
# {'loss': 0.074, 'grad_norm': 2.834526300430298, 'learning_rate': 1.9760800000000002e-05, 'epoch': 0.01}
# {'loss': 0.0761, 'grad_norm': 0.7328769564628601, 'learning_rate': 1.976e-05, 'epoch': 0.01}
# {'loss': 0.0803, 'grad_norm': 1.6847267150878906, 'learning_rate': 1.9759200000000002e-05, 'epoch': 0.01}
# {'loss': 0.0736, 'grad_norm': 0.8338537216186523, 'learning_rate': 1.97584e-05, 'epoch': 0.01}
# {'loss': 0.0707, 'grad_norm': 2.1682608127593994, 'learning_rate': 1.9757600000000002e-05, 'epoch': 0.01}
# {'loss': 0.0764, 'grad_norm': 4.7361907958984375, 'learning_rate': 1.9756800000000004e-05, 'epoch': 0.01}
# {'loss': 0.0771, 'grad_norm': 1.1642683744430542, 'learning_rate': 1.9756000000000002e-05, 'epoch': 0.01}
# {'loss': 0.0703, 'grad_norm': 0.52336585521698, 'learning_rate': 1.97552e-05, 'epoch': 0.01}
# {'loss': 0.0688, 'grad_norm': 0.48099133372306824, 'learning_rate': 1.9754400000000002e-05, 'epoch': 0.01}
# {'loss': 0.0722, 'grad_norm': 0.756322979927063, 'learning_rate': 1.97536e-05, 'epoch': 0.01}
# {'loss': 0.0757, 'grad_norm': 0.7436162829399109, 'learning_rate': 1.9752800000000002e-05, 'epoch': 0.01}
# {'loss': 0.0815, 'grad_norm': 0.06159564107656479, 'learning_rate': 1.9752000000000003e-05, 'epoch': 0.01}
# {'loss': 0.0726, 'grad_norm': 0.2669999599456787, 'learning_rate': 1.97512e-05, 'epoch': 0.01}
# {'loss': 0.0847, 'grad_norm': 0.3622570335865021, 'learning_rate': 1.97504e-05, 'epoch': 0.01}
# {'loss': 0.0693, 'grad_norm': 1.1184706687927246, 'learning_rate': 1.97496e-05, 'epoch': 0.01}
# {'loss': 0.0786, 'grad_norm': 0.7624789476394653, 'learning_rate': 1.97488e-05, 'epoch': 0.01}
# {'loss': 0.0672, 'grad_norm': 0.18487021327018738, 'learning_rate': 1.9748e-05, 'epoch': 0.01}
# {'loss': 0.0702, 'grad_norm': 1.2654443979263306, 'learning_rate': 1.9747200000000003e-05, 'epoch': 0.01}
# {'loss': 0.083, 'grad_norm': 2.9807329177856445, 'learning_rate': 1.97464e-05, 'epoch': 0.01}
# {'loss': 0.0685, 'grad_norm': 0.2300833761692047, 'learning_rate': 1.9745600000000003e-05, 'epoch': 0.01}
# {'loss': 0.0765, 'grad_norm': 0.6514264345169067, 'learning_rate': 1.97448e-05, 'epoch': 0.01}
# {'loss': 0.0837, 'grad_norm': 4.617380142211914, 'learning_rate': 1.9744e-05, 'epoch': 0.01}
# {'loss': 0.0825, 'grad_norm': 0.8761747479438782, 'learning_rate': 1.97432e-05, 'epoch': 0.01}
# {'loss': 0.0683, 'grad_norm': 2.9210197925567627, 'learning_rate': 1.9742400000000003e-05, 'epoch': 0.01}
# {'loss': 0.0719, 'grad_norm': 0.6155757904052734, 'learning_rate': 1.97416e-05, 'epoch': 0.01}
# {'loss': 0.0751, 'grad_norm': 1.0876139402389526, 'learning_rate': 1.9740800000000002e-05, 'epoch': 0.01}
# {'loss': 0.079, 'grad_norm': 0.6827265024185181, 'learning_rate': 1.974e-05, 'epoch': 0.01}
# {'loss': 0.0805, 'grad_norm': 0.7223740816116333, 'learning_rate': 1.97392e-05, 'epoch': 0.01}
# {'loss': 0.0825, 'grad_norm': 2.0361499786376953, 'learning_rate': 1.97384e-05, 'epoch': 0.01}
# {'loss': 0.0883, 'grad_norm': 1.725305199623108, 'learning_rate': 1.9737600000000002e-05, 'epoch': 0.01}
# {'loss': 0.0708, 'grad_norm': 2.5878889560699463, 'learning_rate': 1.9736800000000004e-05, 'epoch': 0.01}
# {'loss': 0.0786, 'grad_norm': 0.26967260241508484, 'learning_rate': 1.9736000000000002e-05, 'epoch': 0.01}
# {'loss': 0.0753, 'grad_norm': 0.5368378162384033, 'learning_rate': 1.97352e-05, 'epoch': 0.01}
# {'loss': 0.0778, 'grad_norm': 0.7475789785385132, 'learning_rate': 1.9734400000000002e-05, 'epoch': 0.01}
# {'loss': 0.0736, 'grad_norm': 0.5661773085594177, 'learning_rate': 1.97336e-05, 'epoch': 0.01}
# {'loss': 0.0721, 'grad_norm': 0.4401382803916931, 'learning_rate': 1.9732800000000002e-05, 'epoch': 0.01}
# {'loss': 0.0673, 'grad_norm': 1.8490099906921387, 'learning_rate': 1.9732000000000004e-05, 'epoch': 0.01}
# {'loss': 0.0731, 'grad_norm': 3.8403306007385254, 'learning_rate': 1.9731200000000002e-05, 'epoch': 0.01}
# {'loss': 0.0697, 'grad_norm': 0.32002928853034973, 'learning_rate': 1.97304e-05, 'epoch': 0.01}
# {'loss': 0.0762, 'grad_norm': 1.6617975234985352, 'learning_rate': 1.97296e-05, 'epoch': 0.01}
# {'loss': 0.0711, 'grad_norm': 2.2473556995391846, 'learning_rate': 1.97288e-05, 'epoch': 0.01}
# {'loss': 0.0686, 'grad_norm': 0.5115019083023071, 'learning_rate': 1.9728e-05, 'epoch': 0.01}
# {'loss': 0.0713, 'grad_norm': 1.278855562210083, 'learning_rate': 1.9727200000000003e-05, 'epoch': 0.01}
# {'loss': 0.079, 'grad_norm': 0.8071601986885071, 'learning_rate': 1.97264e-05, 'epoch': 0.01}
# {'loss': 0.071, 'grad_norm': 0.22137998044490814, 'learning_rate': 1.9725600000000003e-05, 'epoch': 0.01}
# {'loss': 0.0694, 'grad_norm': 1.8108280897140503, 'learning_rate': 1.97248e-05, 'epoch': 0.01}
# {'loss': 0.0783, 'grad_norm': 0.7180079221725464, 'learning_rate': 1.9724e-05, 'epoch': 0.01}
# {'loss': 0.0807, 'grad_norm': 0.49629533290863037, 'learning_rate': 1.97232e-05, 'epoch': 0.01}
# {'loss': 0.0759, 'grad_norm': 0.23278050124645233, 'learning_rate': 1.9722400000000003e-05, 'epoch': 0.01}
# {'loss': 0.0746, 'grad_norm': 1.5111424922943115, 'learning_rate': 1.97216e-05, 'epoch': 0.01}
# {'loss': 0.0853, 'grad_norm': 0.7011160850524902, 'learning_rate': 1.9720800000000003e-05, 'epoch': 0.01}
# {'loss': 0.082, 'grad_norm': 3.95572829246521, 'learning_rate': 1.972e-05, 'epoch': 0.01}
# {'loss': 0.076, 'grad_norm': 2.1728675365448, 'learning_rate': 1.97192e-05, 'epoch': 0.01}
# {'loss': 0.0812, 'grad_norm': 0.08219704777002335, 'learning_rate': 1.97184e-05, 'epoch': 0.01}
# {'loss': 0.0684, 'grad_norm': 1.4558151960372925, 'learning_rate': 1.9717600000000002e-05, 'epoch': 0.01}
# {'loss': 0.0708, 'grad_norm': 0.9243653416633606, 'learning_rate': 1.9716800000000004e-05, 'epoch': 0.01}
# {'loss': 0.0748, 'grad_norm': 0.19787639379501343, 'learning_rate': 1.9716000000000002e-05, 'epoch': 0.01}
# {'loss': 0.0703, 'grad_norm': 0.3944372534751892, 'learning_rate': 1.97152e-05, 'epoch': 0.01}
# {'loss': 0.0869, 'grad_norm': 3.5142574310302734, 'learning_rate': 1.9714400000000002e-05, 'epoch': 0.01}
# {'loss': 0.0721, 'grad_norm': 2.860356330871582, 'learning_rate': 1.97136e-05, 'epoch': 0.01}
# {'loss': 0.068, 'grad_norm': 0.8934309482574463, 'learning_rate': 1.9712800000000002e-05, 'epoch': 0.01}
# {'loss': 0.0852, 'grad_norm': 1.1329753398895264, 'learning_rate': 1.9712000000000004e-05, 'epoch': 0.01}
# {'loss': 0.074, 'grad_norm': 1.2502007484436035, 'learning_rate': 1.9711200000000002e-05, 'epoch': 0.01}
# {'loss': 0.0658, 'grad_norm': 0.7317808270454407, 'learning_rate': 1.97104e-05, 'epoch': 0.01}
# {'loss': 0.0864, 'grad_norm': 1.3569937944412231, 'learning_rate': 1.9709600000000002e-05, 'epoch': 0.01}
# {'loss': 0.0719, 'grad_norm': 1.7344578504562378, 'learning_rate': 1.97088e-05, 'epoch': 0.01}
# {'loss': 0.0701, 'grad_norm': 0.6722838282585144, 'learning_rate': 1.9708000000000002e-05, 'epoch': 0.01}
# {'loss': 0.079, 'grad_norm': 0.33344656229019165, 'learning_rate': 1.9707200000000003e-05, 'epoch': 0.01}
# {'loss': 0.0682, 'grad_norm': 0.36515888571739197, 'learning_rate': 1.97064e-05, 'epoch': 0.01}
# {'loss': 0.0725, 'grad_norm': 0.18279148638248444, 'learning_rate': 1.9705600000000003e-05, 'epoch': 0.01}
# {'loss': 0.0808, 'grad_norm': 1.2403674125671387, 'learning_rate': 1.97048e-05, 'epoch': 0.01}
# {'loss': 0.0663, 'grad_norm': 2.225325584411621, 'learning_rate': 1.9704e-05, 'epoch': 0.01}
# {'loss': 0.0755, 'grad_norm': 0.08026206493377686, 'learning_rate': 1.97032e-05, 'epoch': 0.01}
# {'loss': 0.0693, 'grad_norm': 1.7540597915649414, 'learning_rate': 1.9702400000000003e-05, 'epoch': 0.01}
# {'loss': 0.0721, 'grad_norm': 0.6504795551300049, 'learning_rate': 1.97016e-05, 'epoch': 0.01}
# {'loss': 0.0718, 'grad_norm': 0.6487812399864197, 'learning_rate': 1.9700800000000003e-05, 'epoch': 0.01}
# {'loss': 0.0739, 'grad_norm': 0.8645198345184326, 'learning_rate': 1.97e-05, 'epoch': 0.01}
# {'loss': 0.0829, 'grad_norm': 0.3514878749847412, 'learning_rate': 1.96992e-05, 'epoch': 0.02}
# {'loss': 0.0767, 'grad_norm': 2.749221086502075, 'learning_rate': 1.96984e-05, 'epoch': 0.02}
# {'loss': 0.0755, 'grad_norm': 0.5151417255401611, 'learning_rate': 1.9697600000000003e-05, 'epoch': 0.02}
# {'loss': 0.0746, 'grad_norm': 0.4902273416519165, 'learning_rate': 1.9696800000000004e-05, 'epoch': 0.02}
# {'loss': 0.0762, 'grad_norm': 7.676520347595215, 'learning_rate': 1.9696000000000003e-05, 'epoch': 0.02}
# {'loss': 0.0654, 'grad_norm': 2.6890969276428223, 'learning_rate': 1.96952e-05, 'epoch': 0.02}
# {'loss': 0.0754, 'grad_norm': 0.13339528441429138, 'learning_rate': 1.9694400000000002e-05, 'epoch': 0.02}
# {'loss': 0.0734, 'grad_norm': 0.5098809599876404, 'learning_rate': 1.96936e-05, 'epoch': 0.02}
# {'loss': 0.0728, 'grad_norm': 2.98891019821167, 'learning_rate': 1.9692800000000002e-05, 'epoch': 0.02}
# {'loss': 0.0862, 'grad_norm': 4.1453471183776855, 'learning_rate': 1.9692000000000004e-05, 'epoch': 0.02}
# {'loss': 0.0744, 'grad_norm': 1.8484505414962769, 'learning_rate': 1.9691200000000002e-05, 'epoch': 0.02}
# {'loss': 0.0761, 'grad_norm': 2.1075947284698486, 'learning_rate': 1.96904e-05, 'epoch': 0.02}
# {'loss': 0.0747, 'grad_norm': 1.0260297060012817, 'learning_rate': 1.9689600000000002e-05, 'epoch': 0.02}
# {'loss': 0.0736, 'grad_norm': 1.1145776510238647, 'learning_rate': 1.96888e-05, 'epoch': 0.02}
# {'loss': 0.0767, 'grad_norm': 2.5485429763793945, 'learning_rate': 1.9688000000000002e-05, 'epoch': 0.02}
# {'loss': 0.0774, 'grad_norm': 0.6147054433822632, 'learning_rate': 1.9687200000000004e-05, 'epoch': 0.02}
# {'loss': 0.0719, 'grad_norm': 2.457087993621826, 'learning_rate': 1.9686400000000002e-05, 'epoch': 0.02}
# {'loss': 0.0783, 'grad_norm': 1.2415220737457275, 'learning_rate': 1.9685600000000003e-05, 'epoch': 0.02}
# {'loss': 0.0699, 'grad_norm': 1.2570613622665405, 'learning_rate': 1.96848e-05, 'epoch': 0.02}
# {'loss': 0.0686, 'grad_norm': 0.549601674079895, 'learning_rate': 1.9684e-05, 'epoch': 0.02}
# {'loss': 0.0738, 'grad_norm': 1.9925378561019897, 'learning_rate': 1.96832e-05, 'epoch': 0.02}
# {'loss': 0.0714, 'grad_norm': 0.21684354543685913, 'learning_rate': 1.9682400000000003e-05, 'epoch': 0.02}
# {'loss': 0.0698, 'grad_norm': 1.4707961082458496, 'learning_rate': 1.96816e-05, 'epoch': 0.02}
# {'loss': 0.0712, 'grad_norm': 0.24049529433250427, 'learning_rate': 1.9680800000000003e-05, 'epoch': 0.02}
# {'loss': 0.0847, 'grad_norm': 2.400592088699341, 'learning_rate': 1.968e-05, 'epoch': 0.02}
# {'loss': 0.0759, 'grad_norm': 0.5817655920982361, 'learning_rate': 1.96792e-05, 'epoch': 0.02}
# {'loss': 0.074, 'grad_norm': 0.052443575114011765, 'learning_rate': 1.96784e-05, 'epoch': 0.02}
# {'loss': 0.0679, 'grad_norm': 0.8516955375671387, 'learning_rate': 1.9677600000000003e-05, 'epoch': 0.02}
# {'loss': 0.0751, 'grad_norm': 1.9851486682891846, 'learning_rate': 1.96768e-05, 'epoch': 0.02}
# {'loss': 0.0709, 'grad_norm': 0.869486391544342, 'learning_rate': 1.9676000000000003e-05, 'epoch': 0.02}
# {'loss': 0.0737, 'grad_norm': 0.8845471143722534, 'learning_rate': 1.96752e-05, 'epoch': 0.02}
# {'loss': 0.0704, 'grad_norm': 5.424951553344727, 'learning_rate': 1.9674400000000003e-05, 'epoch': 0.02}
# {'loss': 0.0695, 'grad_norm': 0.1624719202518463, 'learning_rate': 1.96736e-05, 'epoch': 0.02}
# {'loss': 0.0783, 'grad_norm': 0.008517026901245117, 'learning_rate': 1.9672800000000002e-05, 'epoch': 0.02}
# {'loss': 0.0734, 'grad_norm': 0.45552387833595276, 'learning_rate': 1.9672e-05, 'epoch': 0.02}
# {'loss': 0.0722, 'grad_norm': 0.9975087642669678, 'learning_rate': 1.9671200000000002e-05, 'epoch': 0.02}
# {'loss': 0.0698, 'grad_norm': 0.32414567470550537, 'learning_rate': 1.96704e-05, 'epoch': 0.02}
# {'loss': 0.0775, 'grad_norm': 0.4859655499458313, 'learning_rate': 1.9669600000000002e-05, 'epoch': 0.02}
# {'loss': 0.0739, 'grad_norm': 0.2649167478084564, 'learning_rate': 1.96688e-05, 'epoch': 0.02}
# {'loss': 0.0731, 'grad_norm': 0.4028216302394867, 'learning_rate': 1.9668000000000002e-05, 'epoch': 0.02}
# {'loss': 0.0678, 'grad_norm': 0.6040725708007812, 'learning_rate': 1.96672e-05, 'epoch': 0.02}
# {'loss': 0.0699, 'grad_norm': 1.0924407243728638, 'learning_rate': 1.9666400000000002e-05, 'epoch': 0.02}
# {'loss': 0.0804, 'grad_norm': 2.1136038303375244, 'learning_rate': 1.9665600000000004e-05, 'epoch': 0.02}
# {'loss': 0.0764, 'grad_norm': 4.596435070037842, 'learning_rate': 1.9664800000000002e-05, 'epoch': 0.02}
# {'loss': 0.0762, 'grad_norm': 0.04843525588512421, 'learning_rate': 1.9664e-05, 'epoch': 0.02}
# {'loss': 0.0737, 'grad_norm': 0.7585908770561218, 'learning_rate': 1.9663200000000002e-05, 'epoch': 0.02}
# {'loss': 0.0717, 'grad_norm': 0.8723220825195312, 'learning_rate': 1.96624e-05, 'epoch': 0.02}
# {'loss': 0.0677, 'grad_norm': 0.6058341860771179, 'learning_rate': 1.96616e-05, 'epoch': 0.02}
# {'loss': 0.0682, 'grad_norm': 1.0038264989852905, 'learning_rate': 1.9660800000000003e-05, 'epoch': 0.02}
# {'loss': 0.0817, 'grad_norm': 2.3571219444274902, 'learning_rate': 1.966e-05, 'epoch': 0.02}
# {'loss': 0.0821, 'grad_norm': 0.2425871044397354, 'learning_rate': 1.96592e-05, 'epoch': 0.02}
# {'loss': 0.0695, 'grad_norm': 0.3863367438316345, 'learning_rate': 1.96584e-05, 'epoch': 0.02}
# {'loss': 0.0841, 'grad_norm': 3.7514119148254395, 'learning_rate': 1.96576e-05, 'epoch': 0.02}
# {'loss': 0.0782, 'grad_norm': 0.6874364018440247, 'learning_rate': 1.96568e-05, 'epoch': 0.02}
# {'loss': 0.0726, 'grad_norm': 0.2240624576807022, 'learning_rate': 1.9656000000000003e-05, 'epoch': 0.02}
# {'loss': 0.0858, 'grad_norm': 3.0266950130462646, 'learning_rate': 1.96552e-05, 'epoch': 0.02}
# {'loss': 0.0728, 'grad_norm': 1.3853271007537842, 'learning_rate': 1.9654400000000003e-05, 'epoch': 0.02}
# {'loss': 0.0746, 'grad_norm': 0.8767351508140564, 'learning_rate': 1.96536e-05, 'epoch': 0.02}
# {'loss': 0.0738, 'grad_norm': 2.59881591796875, 'learning_rate': 1.96528e-05, 'epoch': 0.02}
# {'loss': 0.0699, 'grad_norm': 2.771657943725586, 'learning_rate': 1.9652e-05, 'epoch': 0.02}
# {'loss': 0.0763, 'grad_norm': 2.5633020401000977, 'learning_rate': 1.9651200000000003e-05, 'epoch': 0.02}
# {'loss': 0.0727, 'grad_norm': 0.3375907242298126, 'learning_rate': 1.96504e-05, 'epoch': 0.02}
# {'loss': 0.0733, 'grad_norm': 4.165733814239502, 'learning_rate': 1.9649600000000002e-05, 'epoch': 0.02}
# {'loss': 0.0743, 'grad_norm': 1.463981032371521, 'learning_rate': 1.96488e-05, 'epoch': 0.02}
# {'loss': 0.0587, 'grad_norm': 0.31135278940200806, 'learning_rate': 1.9648000000000002e-05, 'epoch': 0.02}
# {'loss': 0.0725, 'grad_norm': 4.851743698120117, 'learning_rate': 1.96472e-05, 'epoch': 0.02}
# {'loss': 0.0729, 'grad_norm': 0.9283764958381653, 'learning_rate': 1.9646400000000002e-05, 'epoch': 0.02}
# {'loss': 0.0682, 'grad_norm': 0.5457904934883118, 'learning_rate': 1.9645600000000004e-05, 'epoch': 0.02}
# {'loss': 0.0823, 'grad_norm': 1.0872910022735596, 'learning_rate': 1.9644800000000002e-05, 'epoch': 0.02}
# {'loss': 0.0784, 'grad_norm': 1.186560869216919, 'learning_rate': 1.9644e-05, 'epoch': 0.02}
# {'loss': 0.068, 'grad_norm': 0.48524752259254456, 'learning_rate': 1.9643200000000002e-05, 'epoch': 0.02}
# {'loss': 0.0808, 'grad_norm': 0.07617153227329254, 'learning_rate': 1.96424e-05, 'epoch': 0.02}
# {'loss': 0.079, 'grad_norm': 0.502501904964447, 'learning_rate': 1.9641600000000002e-05, 'epoch': 0.02}
# {'loss': 0.077, 'grad_norm': 3.274764060974121, 'learning_rate': 1.9640800000000003e-05, 'epoch': 0.02}
# {'loss': 0.0675, 'grad_norm': 0.647943377494812, 'learning_rate': 1.9640000000000002e-05, 'epoch': 0.02}
# {'loss': 0.0779, 'grad_norm': 1.9070953130722046, 'learning_rate': 1.9639200000000003e-05, 'epoch': 0.02}
# {'loss': 0.0752, 'grad_norm': 1.82980477809906, 'learning_rate': 1.96384e-05, 'epoch': 0.02}
# {'loss': 0.071, 'grad_norm': 0.14450736343860626, 'learning_rate': 1.96376e-05, 'epoch': 0.02}
# {'loss': 0.0657, 'grad_norm': 0.3372040092945099, 'learning_rate': 1.96368e-05, 'epoch': 0.02}
# {'loss': 0.0644, 'grad_norm': 1.598273515701294, 'learning_rate': 1.9636000000000003e-05, 'epoch': 0.02}
# {'loss': 0.0773, 'grad_norm': 0.7187181115150452, 'learning_rate': 1.96352e-05, 'epoch': 0.02}
# {'loss': 0.0714, 'grad_norm': 1.247131586074829, 'learning_rate': 1.9634400000000003e-05, 'epoch': 0.02}
# {'loss': 0.0616, 'grad_norm': 0.383147656917572, 'learning_rate': 1.96336e-05, 'epoch': 0.02}
# {'loss': 0.073, 'grad_norm': 2.629704236984253, 'learning_rate': 1.96328e-05, 'epoch': 0.02}
# ...
# {'loss': 0.0524, 'grad_norm': 0.6364720463752747, 'learning_rate': 1.7891200000000002e-05, 'epoch': 1.01}
# {'loss': 0.0514, 'grad_norm': 1.0648940801620483, 'learning_rate': 1.78904e-05, 'epoch': 1.01}
# {'loss': 0.0524, 'grad_norm': 0.5061707496643066, 'learning_rate': 1.7889600000000002e-05, 'epoch': 1.01}
# {'loss': 0.0491, 'grad_norm': 5.609196186065674, 'learning_rate': 1.78888e-05, 'epoch': 1.01}
# {'loss': 0.0559, 'grad_norm': 0.2871055006980896, 'learning_rate': 1.7888000000000002e-05, 'epoch': 1.01}
# {'loss': 0.0617, 'grad_norm': 0.7404999732971191, 'learning_rate': 1.7887200000000004e-05, 'epoch': 1.01}
# {'loss': 0.054, 'grad_norm': 0.6712121963500977, 'learning_rate': 1.7886400000000002e-05, 'epoch': 1.01}
# {'loss': 0.0557, 'grad_norm': 0.4504486620426178, 'learning_rate': 1.78856e-05, 'epoch': 1.01}
# {'loss': 0.052, 'grad_norm': 0.6155147552490234, 'learning_rate': 1.7884800000000002e-05, 'epoch': 1.01}
# {'loss': 0.052, 'grad_norm': 0.6152170896530151, 'learning_rate': 1.7884e-05, 'epoch': 1.01}
# {'loss': 0.0575, 'grad_norm': 0.0425790436565876, 'learning_rate': 1.7883200000000002e-05, 'epoch': 1.01}
# {'loss': 0.053, 'grad_norm': 0.27654358744621277, 'learning_rate': 1.7882400000000003e-05, 'epoch': 1.01}
# {'loss': 0.0499, 'grad_norm': 0.514009952545166, 'learning_rate': 1.7881600000000002e-05, 'epoch': 1.01}
# {'loss': 0.0564, 'grad_norm': 0.5520055890083313, 'learning_rate': 1.78808e-05, 'epoch': 1.01}
# {'loss': 0.0526, 'grad_norm': 0.8057409524917603, 'learning_rate': 1.788e-05, 'epoch': 1.01}
# {'loss': 0.0465, 'grad_norm': 0.12578368186950684, 'learning_rate': 1.78792e-05, 'epoch': 1.01}
# {'loss': 0.0464, 'grad_norm': 1.3876397609710693, 'learning_rate': 1.78784e-05, 'epoch': 1.01}
# {'loss': 0.0549, 'grad_norm': 0.27704066038131714, 'learning_rate': 1.7877600000000003e-05, 'epoch': 1.01}
# {'loss': 0.0537, 'grad_norm': 0.4218207895755768, 'learning_rate': 1.78768e-05, 'epoch': 1.01}
# {'loss': 0.0559, 'grad_norm': 1.0025330781936646, 'learning_rate': 1.7876000000000003e-05, 'epoch': 1.01}
# {'loss': 0.0478, 'grad_norm': 0.4804247319698334, 'learning_rate': 1.78752e-05, 'epoch': 1.01}
# {'loss': 0.0506, 'grad_norm': 0.29076874256134033, 'learning_rate': 1.78744e-05, 'epoch': 1.01}
# {'loss': 0.0544, 'grad_norm': 0.5036803483963013, 'learning_rate': 1.78736e-05, 'epoch': 1.01}
# {'loss': 0.0515, 'grad_norm': 0.5049964189529419, 'learning_rate': 1.7872800000000003e-05, 'epoch': 1.01}
# {'loss': 0.0563, 'grad_norm': 0.46570339798927307, 'learning_rate': 1.7872e-05, 'epoch': 1.01}
# {'loss': 0.054, 'grad_norm': 0.0895356610417366, 'learning_rate': 1.7871200000000003e-05, 'epoch': 1.01}
# {'loss': 0.0517, 'grad_norm': 1.9650132656097412, 'learning_rate': 1.78704e-05, 'epoch': 1.01}
# {'loss': 0.0494, 'grad_norm': 0.14101064205169678, 'learning_rate': 1.7869600000000003e-05, 'epoch': 1.01}
# {'loss': 0.0578, 'grad_norm': 0.4523256719112396, 'learning_rate': 1.78688e-05, 'epoch': 1.01}
# {'loss': 0.0584, 'grad_norm': 2.4936599731445312, 'learning_rate': 1.7868000000000002e-05, 'epoch': 1.01}
# {'loss': 0.0478, 'grad_norm': 1.0907689332962036, 'learning_rate': 1.78672e-05, 'epoch': 1.01}
# {'loss': 0.0508, 'grad_norm': 0.2530633211135864, 'learning_rate': 1.7866400000000002e-05, 'epoch': 1.01}
# {'loss': 0.0486, 'grad_norm': 0.9195374250411987, 'learning_rate': 1.78656e-05, 'epoch': 1.01}
# {'loss': 0.0546, 'grad_norm': 0.5173097848892212, 'learning_rate': 1.7864800000000002e-05, 'epoch': 1.01}
# {'loss': 0.0551, 'grad_norm': 0.0965307354927063, 'learning_rate': 1.7864e-05, 'epoch': 1.01}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 25
#       1 training_args = Seq2SeqTrainingArguments(
#       2     output_dir=f"../../models/final-model/",
#       3     auto_find_batch_size=True,
#    (...)
#      10     max_steps=12500000
#      11 )
#      13 trainer = Seq2SeqTrainer(
#      14     model=model,
#      15     args=training_args,
#    (...)
#      22     callbacks=[early_stop]
#      23 )
# ---> 25 trainer.train()
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer.py:1932, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1930         hf_hub_utils.enable_progress_bars()
#    1931 else:
# -> 1932     return inner_training_loop(
#    1933         args=args,
#    1934         resume_from_checkpoint=resume_from_checkpoint,
#    1935         trial=trial,
#    1936         ignore_keys_for_eval=ignore_keys_for_eval,
#    1937     )
#
# File ~/.local/lib/python3.10/site-packages/accelerate/utils/memory.py:146, in find_executable_batch_size.<locals>.decorator(*args, **kwargs)
#     144     raise RuntimeError("No executable batch size found, reached zero.")
#     145 try:
# --> 146     return function(batch_size, *args, **kwargs)
#     147 except Exception as e:
#     148     if should_reduce_batch_size(e):
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer.py:2268, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2265     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    2267 with self.accelerator.accumulate(model):
# -> 2268     tr_loss_step = self.training_step(model, inputs)
#    2270 if (
#    2271     args.logging_nan_inf_filter
#    2272     and not is_torch_xla_available()
#    2273     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2274 ):
#    2275     # if loss is nan or inf simply add the average of previous logged losses
#    2276     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer.py:3307, in Trainer.training_step(self, model, inputs)
#    3304     return loss_mb.reduce_mean().detach().to(self.args.device)
#    3306 with self.compute_loss_context_manager():
# -> 3307     loss = self.compute_loss(model, inputs)
#    3309 del inputs
#    3311 kwargs = {}
#
# File ~/.local/lib/python3.10/site-packages/transformers/trainer.py:3338, in Trainer.compute_loss(self, model, inputs, return_outputs)
#    3336 else:
#    3337     labels = None
# -> 3338 outputs = model(**inputs)
#    3339 # Save past state if it exists
#    3340 # TODO: this needs to be fixed and made cleaner later.
#    3341 if self.args.past_index >= 0:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:1739, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1736         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1738 # Decode
# -> 1739 decoder_outputs = self.decoder(
#    1740     input_ids=decoder_input_ids,
#    1741     attention_mask=decoder_attention_mask,
#    1742     inputs_embeds=decoder_inputs_embeds,
#    1743     past_key_values=past_key_values,
#    1744     encoder_hidden_states=hidden_states,
#    1745     encoder_attention_mask=attention_mask,
#    1746     head_mask=decoder_head_mask,
#    1747     cross_attn_head_mask=cross_attn_head_mask,
#    1748     use_cache=use_cache,
#    1749     output_attentions=output_attentions,
#    1750     output_hidden_states=output_hidden_states,
#    1751     return_dict=return_dict,
#    1752 )
#    1754 sequence_output = decoder_outputs[0]
#    1756 # Set device for model parallelism
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:1106, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1091     layer_outputs = self._gradient_checkpointing_func(
#    1092         layer_module.forward,
#    1093         hidden_states,
#    (...)
#    1103         output_attentions,
#    1104     )
#    1105 else:
# -> 1106     layer_outputs = layer_module(
#    1107         hidden_states,
#    1108         attention_mask=extended_attention_mask,
#    1109         position_bias=position_bias,
#    1110         encoder_hidden_states=encoder_hidden_states,
#    1111         encoder_attention_mask=encoder_extended_attention_mask,
#    1112         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1113         layer_head_mask=layer_head_mask,
#    1114         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1115         past_key_value=past_key_value,
#    1116         use_cache=use_cache,
#    1117         output_attentions=output_attentions,
#    1118     )
#    1120 # layer_outputs is a tuple with:
#    1121 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1122 if use_cache is False:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:686, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     683 else:
#     684     self_attn_past_key_value, cross_attn_past_key_value = None, None
# --> 686 self_attention_outputs = self.layer[0](
#     687     hidden_states,
#     688     attention_mask=attention_mask,
#     689     position_bias=position_bias,
#     690     layer_head_mask=layer_head_mask,
#     691     past_key_value=self_attn_past_key_value,
#     692     use_cache=use_cache,
#     693     output_attentions=output_attentions,
#     694 )
#     695 hidden_states, present_key_value_state = self_attention_outputs[:2]
#     696 attention_outputs = self_attention_outputs[2:]  # Keep self-attention outputs and relative position weights
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:593, in T5LayerSelfAttention.forward(self, hidden_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, output_attentions)
#     582 def forward(
#     583     self,
#     584     hidden_states,
#    (...)
#     590     output_attentions=False,
#     591 ):
#     592     normed_hidden_states = self.layer_norm(hidden_states)
# --> 593     attention_output = self.SelfAttention(
#     594         normed_hidden_states,
#     595         mask=attention_mask,
#     596         position_bias=position_bias,
#     597         layer_head_mask=layer_head_mask,
#     598         past_key_value=past_key_value,
#     599         use_cache=use_cache,
#     600         output_attentions=output_attentions,
#     601     )
#     602     hidden_states = hidden_states + self.dropout(attention_output[0])
#     603     outputs = (hidden_states,) + attention_output[1:]  # add attentions if we output them
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:523, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions)
#     518 value_states = project(
#     519     hidden_states, self.v, key_value_states, past_key_value[1] if past_key_value is not None else None
#     520 )
#     522 # compute scores
# --> 523 scores = torch.matmul(
#     524     query_states, key_states.transpose(3, 2)
#     525 )  # equivalent of torch.einsum("bnqd,bnkd->bnqk", query_states, key_states), compatible with onnx op>9
#     527 if position_bias is None:
#     528     if not self.has_relative_attention_bias:
#
# KeyboardInterrupt:
