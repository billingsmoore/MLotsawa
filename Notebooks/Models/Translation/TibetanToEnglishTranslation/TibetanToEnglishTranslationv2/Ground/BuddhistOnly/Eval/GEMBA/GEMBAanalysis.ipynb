# %%
small = [85, 75, 80, 45, 70, 60, 85, 80, 70, 65, 70, 80, 75, 85, 70, 80, 85, 75, 85, 80, 75, 85, 80, 85, 85, 80, 75, 80, 85, 80, 75, 85, 80, 75, 85, 80, 85, 80, 75, 80, 85, 80, 75, 80, 25, 70, 80, 85, 75, 80, 75, 70, 95, 85, 80, 70, 85, 75, 60, 65, 80, 75, 100, 85, 80, 85, 75, 80, 70, 75, 80, 85, 80, 75, 70, 85, 90, 40, 75, 70, 80, 85, 75, 70, 90, 95, 75, 35, 45, 80, 85, 80, 85, 75, 80, 70, 85, 90, 80, 70, 25, 75, 70, 15, 85, 90, 25, 20, 75, 10, 95, 85, 60, 75, 25, 70, 80, 30, 85, 75, 80, 75, 20, 85, 90, 30, 85, 60, 95, 85, 25, 85, 65, 75, 90, 80, 35, 75, 90, 90, 85, 100, 20, 75, 70, 75, 70, 85, 75, 70, 85, 80, 85, 70, 75, 80, 85, 70, 80, 75, 85, 80, 75, 85, 80, 75, 65, 80, 85, 75, 80, 85, 70, 80, 85, 75, 85, 85, 75, 85, 60, 70, 70, 75, 80, 85, 70, 80, 75, 85, 80, 85, 70, 80, 75, 65, 80, 75, 80, 75, 70, 75, 70, 85, 80, 15, 75, 45, 25, 60, 85, 85, 95, 70, 80, 85, 80, 95, 95, 70, 40, 85, 75, 85, 30, 85, 75, 80, 85, 95, 75, 85, 80, 70, 85, 60, 65, 85, 85, 70, 80, 75, 85, 80, 75, 80, 85, 75, 70, 80, 75, 85, 80, 75, 70, 75, 85, 80, 70, 85, 60, 65, 80, 85, 70, 75, 80, 85, 80, 85, 70, 80, 75, 70, 75, 80, 75, 70, 80, 75, 85, 75, 80, 88, 82, 92, 90, 85, 80, 88, 85, 78, 85, 88, 85, 75, 82, 90, 85, 80, 88, 85, 88, 85, 78, 88, 85, 88, 85, 75, 90, 70, 80, 60, 65, 85, 80, 85, 85, 40, 80, 85, 80, 75, 70, 85, 85, 75, 80, 85, 75, 85, 75, 95, 70, 60, 95, 80, 65, 70, 85, 80, 85, 70, 85, 95, 80, 70, 75, 80, 85, 70, 75, 60, 85, 80, 70, 75, 65, 80, 75, 85, 70, 80, 75, 80, 70, 85, 75, 80, 70, 85, 75, 80, 85, 70, 80, 75, 70, 80, 75, 60, 75, 82, 65, 92, 70, 85, 78, 85, 88, 70, 88, 92, 78, 85, 88, 85, 78, 85, 75, 80, 85, 78, 82, 85, 75, 88, 85, 80, 75, 92, 82, 85, 78, 80, 82, 88, 85, 75, 80, 78, 85, 82, 85, 78, 80, 82, 88, 85, 78, 75, 85, 95, 75, 90, 70, 80, 75, 85, 80, 70, 75, 80, 85, 90, 75, 80, 85, 80, 85, 90, 85, 85, 85, 80, 85, 85, 85, 85, 60, 80, 75, 75, 85, 80, 85, 70, 60, 80, 70, 75, 75, 60, 85, 70, 60, 85, 80, 75, 85, 80, 85, 80, 75, 75, 85, 80, 75, 80, 85, 80, 40, 75, 75, 85, 65, 80, 85, 85, 80, 85, 15, 85, 70, 75, 95, 80, 85, 85, 80, 75, 60, 80, 10, 75, 80, 85, 75, 85, 70, 75, 60, 85, 20, 85, 85, 80, 85, 85, 90, 70, 20]
small = small[-500:]

# %%
base = [75, 80, 75, 40, 65, 65, 80, 75, 65, 60, 65, 75, 70, 80, 65, 75, 80, 70, 80, 75, 70, 80, 75, 80, 80, 75, 70, 75, 80, 75, 70, 80, 75, 70, 80, 75, 80, 75, 70, 75, 80, 75, 70, 75, 20, 65, 75, 80, 70, 75, 70, 75, 95, 80, 75, 75, 90, 70, 65, 70, 75, 70, 100, 80, 85, 90, 70, 85, 75, 80, 75, 85, 85, 80, 85, 75, 85, 35, 70, 65, 75, 80, 70, 65, 85, 95, 70, 30, 40, 75, 80, 75, 80, 70, 75, 65, 80, 85, 75, 65, 20, 70, 65, 25, 80, 85, 35, 25, 80, 20, 90, 80, 70, 75, 30, 65, 85, 35, 90, 80, 85, 80, 25, 90, 85, 35, 80, 65, 95, 80, 30, 80, 70, 80, 85, 85, 40, 75, 85, 85, 90, 100, 25, 80, 75, 70, 75, 88, 70, 65, 80, 75, 88, 75, 70, 75, 85, 60, 85, 80, 88, 85, 80, 85, 85, 80, 50, 85, 85, 80, 85, 88, 75, 85, 88, 80, 88, 88, 80, 85, 65, 65, 60, 75, 85, 85, 75, 75, 70, 85, 80, 85, 75, 80, 80, 70, 75, 80, 80, 80, 75, 80, 75, 85, 85, 20, 70, 35, 85, 50, 80, 40, 90, 75, 75, 85, 80, 95, 95, 65, 25, 80, 75, 85, 25, 80, 70, 75, 80, 95, 80, 90, 85, 65, 90, 65, 70, 90, 90, 75, 85, 80, 90, 85, 80, 85, 90, 80, 75, 85, 80, 90, 85, 80, 75, 80, 88, 85, 65, 88, 65, 60, 85, 88, 75, 80, 85, 88, 85, 88, 75, 85, 80, 75, 80, 85, 80, 75, 85, 80, 88, 78, 75, 85, 80, 90, 88, 88, 78, 85, 88, 82, 88, 85, 88, 80, 85, 88, 88, 82, 85, 88, 85, 88, 82, 85, 88, 85, 70, 80, 85, 65, 75, 55, 60, 80, 75, 85, 85, 45, 75, 80, 75, 70, 65, 80, 80, 70, 75, 80, 70, 80, 70, 95, 75, 65, 95, 85, 70, 75, 80, 75, 80, 65, 80, 95, 75, 65, 70, 75, 80, 65, 70, 55, 80, 75, 65, 70, 60, 75, 70, 80, 65, 75, 70, 75, 65, 80, 70, 75, 65, 80, 70, 75, 80, 65, 75, 70, 65, 75, 70, 55, 85, 88, 72, 92, 82, 88, 85, 88, 90, 78, 90, 92, 85, 88, 90, 88, 85, 88, 82, 85, 88, 85, 88, 88, 82, 90, 88, 85, 82, 92, 88, 88, 85, 85, 88, 90, 88, 82, 85, 85, 88, 88, 88, 85, 85, 88, 90, 88, 85, 82, 80, 95, 70, 85, 65, 75, 70, 80, 75, 65, 70, 75, 80, 85, 70, 75, 80, 75, 80, 85, 80, 80, 80, 75, 80, 80, 80, 80, 40, 75, 70, 70, 80, 85, 85, 65, 65, 75, 75, 80, 70, 55, 80, 65, 55, 80, 75, 70, 80, 75, 80, 75, 70, 70, 80, 75, 70, 75, 80, 75, 35, 70, 70, 80, 60, 75, 80, 80, 75, 80, 25, 85, 75, 80, 90, 75, 85, 85, 75, 75, 65, 75, 10, 80, 75, 85, 80, 80, 75, 80, 65, 85, 20, 85, 85, 80, 85, 85, 90, 75, 25]
base = base[-500:]

# %%
len(small)
# Out:
# 500

# %%
import numpy as np

print(f'Small: f{np.mean(small)}')
print(f'Base: f{np.mean(base)}')
# Out:
# Small: f76.426
# Base: f76.002

# %%
import matplotlib.pyplot as plt
import numpy as np

# Your score lists
small_scores = small[:500]
base_scores =base[:500]

# Create figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Box plot comparison
ax1.boxplot([small_scores, base_scores], labels=['Small Predictions', 'Base Predictions'])
ax1.set_title('Box Plot Comparison')
ax1.set_ylabel('Translation Quality Score')
ax1.grid(True, alpha=0.3)

# Histogram comparison
ax2.hist(small_scores, alpha=0.7, bins=15, label='Small Predictions', color='skyblue')
ax2.hist(base_scores, alpha=0.7, bins=15, label='Base Predictions', color='lightcoral')
ax2.set_title('Distribution Comparison')
ax2.set_xlabel('Translation Quality Score')
ax2.set_ylabel('Frequency')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Print summary statistics
print("Summary Statistics:")
print(f"Small Predictions - Mean: {np.mean(small_scores):.2f}, Median: {np.median(small_scores):.2f}, Std: {np.std(small_scores):.2f}")
print(f"Base Predictions - Mean: {np.mean(base_scores):.2f}, Median: {np.median(base_scores):.2f}, Std: {np.std(base_scores):.2f}")
print(f"Difference in means: {np.mean(base_scores) - np.mean(small_scores):.2f}")
# Out:
# /tmp/ipykernel_29340/153792498.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax1.boxplot([small_scores, base_scores], labels=['Small Predictions', 'Base Predictions'])
# Summary Statistics:
# Small Predictions - Mean: 76.43, Median: 80.00, Std: 14.14
# Base Predictions - Mean: 76.00, Median: 80.00, Std: 14.14
# Difference in means: -0.42

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import math

def margin_of_error(std_dev, n, confidence_level=0.95):
    """Calculate margin of error for a given sample size"""
    z_score = stats.norm.ppf((1 + confidence_level) / 2)
    return z_score * std_dev / math.sqrt(n)

def required_sample_size(std_dev, desired_margin, confidence_level=0.95):
    """Calculate required sample size for desired precision"""
    z_score = stats.norm.ppf((1 + confidence_level) / 2)
    return math.ceil((z_score * std_dev / desired_margin) ** 2)

def simulate_sampling_distribution(true_mean, true_std, sample_size, n_simulations=10000):
    """Simulate what happens when you repeatedly sample from the population"""
    sample_means = []
    for _ in range(n_simulations):
        sample = np.random.normal(true_mean, true_std, sample_size)
        sample_means.append(np.mean(sample))
    return np.array(sample_means)

# Your current small model data
small_scores = small[:500]

# Current estimates (these are our best estimates of the true parameters)
current_mean = np.mean(small_scores)
current_std = np.std(small_scores, ddof=1)  # Sample standard deviation
current_n = len(small_scores)

print("=== CURRENT SAMPLE ESTIMATES ===")
print(f"Sample size: {current_n}")
print(f"Sample mean: {current_mean:.2f}")
print(f"Sample std dev: {current_std:.2f}")

# Current precision
current_margin = margin_of_error(current_std, current_n)
print(f"Current 95% margin of error: ±{current_margin:.2f} points")
print(f"95% Confidence Interval: [{current_mean - current_margin:.2f}, {current_mean + current_margin:.2f}]")

print("\n=== PRECISION ANALYSIS FOR n=500 ===")

# What precision would n=500 give us?
n_500_margin = margin_of_error(current_std, 500)
print(f"With n=500, margin of error: ±{n_500_margin:.2f} points")
print(f"95% CI would be: [{current_mean - n_500_margin:.2f}, {current_mean + n_500_margin:.2f}]")

# Compare different sample sizes
sample_sizes = [30, 50, 100, 200, 500, 1000, 2000]
margins = [margin_of_error(current_std, n) for n in sample_sizes]

print(f"\nPrecision at different sample sizes:")
for n, margin in zip(sample_sizes, margins):
    print(f"n={n:4d}: ±{margin:.2f} points (CI width: {2*margin:.2f})")

print("\n=== SAMPLE SIZE REQUIREMENTS ===")

# What sample size is needed for different levels of precision?
desired_precisions = [0.5, 1.0, 1.5, 2.0, 3.0, 5.0]
required_ns = [required_sample_size(current_std, precision) for precision in desired_precisions]

print("Sample size needed for different precision levels:")
for precision, n in zip(desired_precisions, required_ns):
    print(f"±{precision:.1f} points: n={n:4d}")

print(f"\n500 samples gives you ±{n_500_margin:.2f} point precision")
if n_500_margin <= 2.0:
    print("✓ This is quite good precision for most practical purposes")
else:
    print("⚠ Consider if this precision meets your needs")

# Visualization
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))

# 1. Sample size vs margin of error
ax1.plot(sample_sizes, margins, 'bo-', linewidth=2, markersize=8)
ax1.axhline(y=2.0, color='red', linestyle='--', alpha=0.7, label='±2 point target')
ax1.axhline(y=1.0, color='green', linestyle='--', alpha=0.7, label='±1 point target')
ax1.axvline(x=500, color='orange', linestyle='--', alpha=0.7, label='n=500')
ax1.set_xlabel('Sample Size')
ax1.set_ylabel('Margin of Error (±points)')
ax1.set_title('Precision vs Sample Size')
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_xscale('log')

# 2. Confidence interval width vs sample size
ci_widths = [2 * margin for margin in margins]
ax2.plot(sample_sizes, ci_widths, 'ro-', linewidth=2, markersize=8)
ax2.axhline(y=4.0, color='red', linestyle='--', alpha=0.7, label='4 point CI width')
ax2.axhline(y=2.0, color='green', linestyle='--', alpha=0.7, label='2 point CI width')
ax2.axvline(x=500, color='orange', linestyle='--', alpha=0.7, label='n=500')
ax2.set_xlabel('Sample Size')
ax2.set_ylabel('95% CI Width (points)')
ax2.set_title('Confidence Interval Width vs Sample Size')
ax2.legend()
ax2.grid(True, alpha=0.3)
ax2.set_xscale('log')

# 3. Simulate sampling distribution for n=500
simulated_means_500 = simulate_sampling_distribution(current_mean, current_std, 500, 1000)
ax3.hist(simulated_means_500, bins=30, alpha=0.7, density=True, color='skyblue')
ax3.axvline(current_mean, color='red', linestyle='-', linewidth=2, label=f'True mean ≈ {current_mean:.1f}')
ax3.axvline(current_mean - n_500_margin, color='orange', linestyle='--', label=f'95% CI bounds')
ax3.axvline(current_mean + n_500_margin, color='orange', linestyle='--')
ax3.set_xlabel('Sample Mean')
ax3.set_ylabel('Density')
ax3.set_title('Distribution of Sample Means (n=500)')
ax3.legend()
ax3.grid(True, alpha=0.3)

# 4. Show how estimate improves with sample size
np.random.seed(42)  # For reproducibility
true_population = np.random.normal(current_mean, current_std, 10000)
cumulative_means = []
cumulative_margins = []

for i in range(10, min(2000, len(true_population))):
    sample = true_population[:i]
    cum_mean = np.mean(sample)
    cum_std = np.std(sample, ddof=1)
    cum_margin = margin_of_error(cum_std, i)
    cumulative_means.append(cum_mean)
    cumulative_margins.append(cum_margin)

sample_range = range(10, len(cumulative_means) + 10)
ax4.plot(sample_range, cumulative_means, 'b-', linewidth=2, label='Cumulative Mean')
ax4.fill_between(sample_range, 
                np.array(cumulative_means) - np.array(cumulative_margins),
                np.array(cumulative_means) + np.array(cumulative_margins),
                alpha=0.3, color='blue', label='95% CI')
ax4.axhline(current_mean, color='red', linestyle='--', alpha=0.7, label='True Mean')
ax4.axvline(500, color='orange', linestyle='--', alpha=0.7, label='n=500')
ax4.set_xlabel('Sample Size')
ax4.set_ylabel('Estimated Mean')
ax4.set_title('Mean Estimate Convergence')
ax4.legend()
ax4.grid(True, alpha=0.3)
ax4.set_ylim(current_mean - 10, current_mean + 10)

plt.tight_layout()
plt.show()

print("\n=== ASSESSMENT FOR n=500 ===")

# Calculate what percentage of the standard deviation our margin represents
precision_as_pct_of_std = (n_500_margin / current_std) * 100

print(f"With n=500:")
print(f"• Margin of error: ±{n_500_margin:.2f} points")
print(f"• This is {precision_as_pct_of_std:.1f}% of the standard deviation")
print(f"• 95% confidence interval width: {2*n_500_margin:.2f} points")

if n_500_margin <= 1.5:
    assessment = "EXCELLENT"
elif n_500_margin <= 2.5:
    assessment = "GOOD"
elif n_500_margin <= 4.0:
    assessment = "ADEQUATE"
else:
    assessment = "CONSIDER MORE SAMPLES"

print(f"• Assessment: {assessment} precision")

print(f"\nContext:")
print(f"• Your scores range from {min(small_scores)} to {max(small_scores)} (range: {max(small_scores) - min(small_scores)})")
print(f"• A ±{n_500_margin:.1f} point margin is {(n_500_margin/(max(small_scores) - min(small_scores)))*100:.1f}% of your score range")

print(f"\n=== RECOMMENDATION ===")
if n_500_margin <= 2.0:
    print("✓ 500 samples should give you excellent precision for estimating the true mean")
    print("✓ This level of precision is sufficient for most research and practical applications")
else:
    print("⚠ Consider whether ±{:.1f} point precision meets your requirements".format(n_500_margin))
    print(f"⚠ For better precision, consider n={required_sample_size(current_std, 2.0)}")

print(f"\nNote: These calculations assume your current sample is representative of the population.")
print(f"The true population standard deviation might differ from your sample estimate.")
# Out:
# === CURRENT SAMPLE ESTIMATES ===
# Sample size: 500
# Sample mean: 76.43
# Sample std dev: 14.15
# Current 95% margin of error: ±1.24 points
# 95% Confidence Interval: [75.19, 77.67]
#
# === PRECISION ANALYSIS FOR n=500 ===
# With n=500, margin of error: ±1.24 points
# 95% CI would be: [75.19, 77.67]
#
# Precision at different sample sizes:
# n=  30: ±5.06 points (CI width: 10.13)
# n=  50: ±3.92 points (CI width: 7.84)
# n= 100: ±2.77 points (CI width: 5.55)
# n= 200: ±1.96 points (CI width: 3.92)
# n= 500: ±1.24 points (CI width: 2.48)
# n=1000: ±0.88 points (CI width: 1.75)
# n=2000: ±0.62 points (CI width: 1.24)
#
# === SAMPLE SIZE REQUIREMENTS ===
# Sample size needed for different precision levels:
# ±0.5 points: n=3077
# ±1.0 points: n= 770
# ±1.5 points: n= 342
# ±2.0 points: n= 193
# ±3.0 points: n=  86
# ±5.0 points: n=  31
#
# 500 samples gives you ±1.24 point precision
# ✓ This is quite good precision for most practical purposes
# === ASSESSMENT FOR n=500 ===
# With n=500:
# • Margin of error: ±1.24 points
# • This is 8.8% of the standard deviation
# • 95% confidence interval width: 2.48 points
# • Assessment: EXCELLENT precision
#
# Context:
# • Your scores range from 10 to 100 (range: 90)
# • A ±1.2 point margin is 1.4% of your score range
#
# === RECOMMENDATION ===
# ✓ 500 samples should give you excellent precision for estimating the true mean
# ✓ This level of precision is sufficient for most research and practical applications
#
# Note: These calculations assume your current sample is representative of the population.
# The true population standard deviation might differ from your sample estimate.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import math

def margin_of_error(std_dev, n, confidence_level=0.95):
    """Calculate margin of error for a given sample size"""
    z_score = stats.norm.ppf((1 + confidence_level) / 2)
    return z_score * std_dev / math.sqrt(n)

def required_sample_size(std_dev, desired_margin, confidence_level=0.95):
    """Calculate required sample size for desired precision"""
    z_score = stats.norm.ppf((1 + confidence_level) / 2)
    return math.ceil((z_score * std_dev / desired_margin) ** 2)

def simulate_sampling_distribution(true_mean, true_std, sample_size, n_simulations=10000):
    """Simulate what happens when you repeatedly sample from the population"""
    sample_means = []
    for _ in range(n_simulations):
        sample = np.random.normal(true_mean, true_std, sample_size)
        sample_means.append(np.mean(sample))
    return np.array(sample_means)

# Your current small model data
small_scores = base[:500]

# Current estimates (these are our best estimates of the true parameters)
current_mean = np.mean(small_scores)
current_std = np.std(small_scores, ddof=1)  # Sample standard deviation
current_n = len(small_scores)

print("=== CURRENT SAMPLE ESTIMATES ===")
print(f"Sample size: {current_n}")
print(f"Sample mean: {current_mean:.2f}")
print(f"Sample std dev: {current_std:.2f}")

# Current precision
current_margin = margin_of_error(current_std, current_n)
print(f"Current 95% margin of error: ±{current_margin:.2f} points")
print(f"95% Confidence Interval: [{current_mean - current_margin:.2f}, {current_mean + current_margin:.2f}]")

print("\n=== PRECISION ANALYSIS FOR n=500 ===")

# What precision would n=500 give us?
n_500_margin = margin_of_error(current_std, 500)
print(f"With n=500, margin of error: ±{n_500_margin:.2f} points")
print(f"95% CI would be: [{current_mean - n_500_margin:.2f}, {current_mean + n_500_margin:.2f}]")

# Compare different sample sizes
sample_sizes = [30, 50, 100, 200, 500, 1000, 2000]
margins = [margin_of_error(current_std, n) for n in sample_sizes]

print(f"\nPrecision at different sample sizes:")
for n, margin in zip(sample_sizes, margins):
    print(f"n={n:4d}: ±{margin:.2f} points (CI width: {2*margin:.2f})")

print("\n=== SAMPLE SIZE REQUIREMENTS ===")

# What sample size is needed for different levels of precision?
desired_precisions = [0.5, 1.0, 1.5, 2.0, 3.0, 5.0]
required_ns = [required_sample_size(current_std, precision) for precision in desired_precisions]

print("Sample size needed for different precision levels:")
for precision, n in zip(desired_precisions, required_ns):
    print(f"±{precision:.1f} points: n={n:4d}")

print(f"\n500 samples gives you ±{n_500_margin:.2f} point precision")
if n_500_margin <= 2.0:
    print("✓ This is quite good precision for most practical purposes")
else:
    print("⚠ Consider if this precision meets your needs")

# Visualization
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))

# 1. Sample size vs margin of error
ax1.plot(sample_sizes, margins, 'bo-', linewidth=2, markersize=8)
ax1.axhline(y=2.0, color='red', linestyle='--', alpha=0.7, label='±2 point target')
ax1.axhline(y=1.0, color='green', linestyle='--', alpha=0.7, label='±1 point target')
ax1.axvline(x=500, color='orange', linestyle='--', alpha=0.7, label='n=500')
ax1.set_xlabel('Sample Size')
ax1.set_ylabel('Margin of Error (±points)')
ax1.set_title('Precision vs Sample Size')
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_xscale('log')

# 2. Confidence interval width vs sample size
ci_widths = [2 * margin for margin in margins]
ax2.plot(sample_sizes, ci_widths, 'ro-', linewidth=2, markersize=8)
ax2.axhline(y=4.0, color='red', linestyle='--', alpha=0.7, label='4 point CI width')
ax2.axhline(y=2.0, color='green', linestyle='--', alpha=0.7, label='2 point CI width')
ax2.axvline(x=500, color='orange', linestyle='--', alpha=0.7, label='n=500')
ax2.set_xlabel('Sample Size')
ax2.set_ylabel('95% CI Width (points)')
ax2.set_title('Confidence Interval Width vs Sample Size')
ax2.legend()
ax2.grid(True, alpha=0.3)
ax2.set_xscale('log')

# 3. Simulate sampling distribution for n=500
simulated_means_500 = simulate_sampling_distribution(current_mean, current_std, 500, 1000)
ax3.hist(simulated_means_500, bins=30, alpha=0.7, density=True, color='skyblue')
ax3.axvline(current_mean, color='red', linestyle='-', linewidth=2, label=f'True mean ≈ {current_mean:.1f}')
ax3.axvline(current_mean - n_500_margin, color='orange', linestyle='--', label=f'95% CI bounds')
ax3.axvline(current_mean + n_500_margin, color='orange', linestyle='--')
ax3.set_xlabel('Sample Mean')
ax3.set_ylabel('Density')
ax3.set_title('Distribution of Sample Means (n=500)')
ax3.legend()
ax3.grid(True, alpha=0.3)

# 4. Show how estimate improves with sample size
np.random.seed(42)  # For reproducibility
true_population = np.random.normal(current_mean, current_std, 10000)
cumulative_means = []
cumulative_margins = []

for i in range(10, min(2000, len(true_population))):
    sample = true_population[:i]
    cum_mean = np.mean(sample)
    cum_std = np.std(sample, ddof=1)
    cum_margin = margin_of_error(cum_std, i)
    cumulative_means.append(cum_mean)
    cumulative_margins.append(cum_margin)

sample_range = range(10, len(cumulative_means) + 10)
ax4.plot(sample_range, cumulative_means, 'b-', linewidth=2, label='Cumulative Mean')
ax4.fill_between(sample_range, 
                np.array(cumulative_means) - np.array(cumulative_margins),
                np.array(cumulative_means) + np.array(cumulative_margins),
                alpha=0.3, color='blue', label='95% CI')
ax4.axhline(current_mean, color='red', linestyle='--', alpha=0.7, label='True Mean')
ax4.axvline(500, color='orange', linestyle='--', alpha=0.7, label='n=500')
ax4.set_xlabel('Sample Size')
ax4.set_ylabel('Estimated Mean')
ax4.set_title('Mean Estimate Convergence')
ax4.legend()
ax4.grid(True, alpha=0.3)
ax4.set_ylim(current_mean - 10, current_mean + 10)

plt.tight_layout()
plt.show()

print("\n=== ASSESSMENT FOR n=500 ===")

# Calculate what percentage of the standard deviation our margin represents
precision_as_pct_of_std = (n_500_margin / current_std) * 100

print(f"With n=500:")
print(f"• Margin of error: ±{n_500_margin:.2f} points")
print(f"• This is {precision_as_pct_of_std:.1f}% of the standard deviation")
print(f"• 95% confidence interval width: {2*n_500_margin:.2f} points")

if n_500_margin <= 1.5:
    assessment = "EXCELLENT"
elif n_500_margin <= 2.5:
    assessment = "GOOD"
elif n_500_margin <= 4.0:
    assessment = "ADEQUATE"
else:
    assessment = "CONSIDER MORE SAMPLES"

print(f"• Assessment: {assessment} precision")

print(f"\nContext:")
print(f"• Your scores range from {min(small_scores)} to {max(small_scores)} (range: {max(small_scores) - min(small_scores)})")
print(f"• A ±{n_500_margin:.1f} point margin is {(n_500_margin/(max(small_scores) - min(small_scores)))*100:.1f}% of your score range")

print(f"\n=== RECOMMENDATION ===")
if n_500_margin <= 2.0:
    print("✓ 500 samples should give you excellent precision for estimating the true mean")
    print("✓ This level of precision is sufficient for most research and practical applications")
else:
    print("⚠ Consider whether ±{:.1f} point precision meets your requirements".format(n_500_margin))
    print(f"⚠ For better precision, consider n={required_sample_size(current_std, 2.0)}")

print(f"\nNote: These calculations assume your current sample is representative of the population.")
print(f"The true population standard deviation might differ from your sample estimate.")
# Out:
# === CURRENT SAMPLE ESTIMATES ===
# Sample size: 500
# Sample mean: 76.00
# Sample std dev: 14.16
# Current 95% margin of error: ±1.24 points
# 95% Confidence Interval: [74.76, 77.24]
#
# === PRECISION ANALYSIS FOR n=500 ===
# With n=500, margin of error: ±1.24 points
# 95% CI would be: [74.76, 77.24]
#
# Precision at different sample sizes:
# n=  30: ±5.07 points (CI width: 10.13)
# n=  50: ±3.92 points (CI width: 7.85)
# n= 100: ±2.77 points (CI width: 5.55)
# n= 200: ±1.96 points (CI width: 3.92)
# n= 500: ±1.24 points (CI width: 2.48)
# n=1000: ±0.88 points (CI width: 1.75)
# n=2000: ±0.62 points (CI width: 1.24)
#
# === SAMPLE SIZE REQUIREMENTS ===
# Sample size needed for different precision levels:
# ±0.5 points: n=3080
# ±1.0 points: n= 770
# ±1.5 points: n= 343
# ±2.0 points: n= 193
# ±3.0 points: n=  86
# ±5.0 points: n=  31
#
# 500 samples gives you ±1.24 point precision
# ✓ This is quite good precision for most practical purposes
# === ASSESSMENT FOR n=500 ===
# With n=500:
# • Margin of error: ±1.24 points
# • This is 8.8% of the standard deviation
# • 95% confidence interval width: 2.48 points
# • Assessment: EXCELLENT precision
#
# Context:
# • Your scores range from 10 to 100 (range: 90)
# • A ±1.2 point margin is 1.4% of your score range
#
# === RECOMMENDATION ===
# ✓ 500 samples should give you excellent precision for estimating the true mean
# ✓ This level of precision is sufficient for most research and practical applications
#
# Note: These calculations assume your current sample is representative of the population.
# The true population standard deviation might differ from your sample estimate.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import pearsonr, spearmanr
import seaborn as sns

# Your score data
small_scores = small[:500]
base_scores = base[:500]

# Ensure same length
assert len(small_scores) == len(base_scores), "Score arrays must be same length"
n = len(small_scores)

# Calculate correlations
pearson_r, pearson_p = pearsonr(small_scores, base_scores)
spearman_rho, spearman_p = spearmanr(small_scores, base_scores)

# Calculate differences
differences = np.array(base_scores) - np.array(small_scores)
mean_diff = np.mean(differences)
std_diff = np.std(differences, ddof=1)

# Agreement analysis (how often they agree within certain ranges)
def agreement_within_range(scores1, scores2, tolerance):
    """Calculate percentage of scores that agree within tolerance"""
    diff = np.abs(np.array(scores1) - np.array(scores2))
    return np.mean(diff <= tolerance) * 100

agreement_ranges = [1, 2, 5, 10, 15]
agreements = [agreement_within_range(small_scores, base_scores, tol) for tol in agreement_ranges]

print("=== CORRELATION ANALYSIS ===")
print(f"Sample size: {n}")
print(f"Pearson correlation: r = {pearson_r:.4f} (p = {pearson_p:.4f})")
print(f"Spearman correlation: ρ = {spearman_rho:.4f} (p = {spearman_p:.4f})")

# Interpret correlation strength
if abs(pearson_r) >= 0.9:
    strength = "Very Strong"
elif abs(pearson_r) >= 0.7:
    strength = "Strong"
elif abs(pearson_r) >= 0.5:
    strength = "Moderate"
elif abs(pearson_r) >= 0.3:
    strength = "Weak"
else:
    strength = "Very Weak"

print(f"Correlation strength: {strength}")

if pearson_p < 0.001:
    significance = "highly significant (p < 0.001)"
elif pearson_p < 0.01:
    significance = "very significant (p < 0.01)"
elif pearson_p < 0.05:
    significance = "significant (p < 0.05)"
else:
    significance = "not significant (p ≥ 0.05)"

print(f"Statistical significance: {significance}")

print(f"\n=== DIFFERENCE ANALYSIS ===")
print(f"Mean difference (Base - Small): {mean_diff:.2f} points")
print(f"Standard deviation of differences: {std_diff:.2f} points")
print(f"95% of differences fall within: ±{1.96 * std_diff:.2f} points")

print(f"\n=== AGREEMENT ANALYSIS ===")
print("Percentage of scores agreeing within:")
for tol, agreement in zip(agreement_ranges, agreements):
    print(f"  ±{tol:2d} points: {agreement:5.1f}%")

# Calculate R-squared (explained variance)
r_squared = pearson_r ** 2
print(f"\nR² (explained variance): {r_squared:.3f} ({r_squared*100:.1f}%)")
print(f"Unexplained variance: {(1-r_squared)*100:.1f}%")

# Create comprehensive visualizations
fig = plt.figure(figsize=(16, 12))

# 1. Scatter plot with regression line
ax1 = plt.subplot(2, 3, 1)
plt.scatter(small_scores, base_scores, alpha=0.7, s=60, color='steelblue')

# Add regression line
slope, intercept, _, _, _ = stats.linregress(small_scores, base_scores)
line_x = np.array([min(small_scores), max(small_scores)])
line_y = slope * line_x + intercept
plt.plot(line_x, line_y, 'r--', linewidth=2, alpha=0.8)

# Add perfect correlation line for reference
perfect_line = np.linspace(min(min(small_scores), min(base_scores)), 
                          max(max(small_scores), max(base_scores)), 100)
plt.plot(perfect_line, perfect_line, 'k:', alpha=0.5, label='Perfect correlation')

plt.xlabel('Small Model Score')
plt.ylabel('Base Model Score')
plt.title(f'Correlation: r = {pearson_r:.3f}')
plt.grid(True, alpha=0.3)
plt.legend()

# Add correlation equation
plt.text(0.05, 0.95, f'y = {slope:.2f}x + {intercept:.1f}', 
         transform=ax1.transAxes, bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

# 2. Bland-Altman plot (difference vs average)
ax2 = plt.subplot(2, 3, 2)
averages = [(s + b) / 2 for s, b in zip(small_scores, base_scores)]
plt.scatter(averages, differences, alpha=0.7, s=60, color='green')
plt.axhline(mean_diff, color='red', linestyle='-', label=f'Mean diff: {mean_diff:.2f}')
plt.axhline(mean_diff + 1.96*std_diff, color='red', linestyle='--', alpha=0.7, 
           label=f'±1.96 SD: {mean_diff + 1.96*std_diff:.1f}')
plt.axhline(mean_diff - 1.96*std_diff, color='red', linestyle='--', alpha=0.7,
           label=f'±1.96 SD: {mean_diff - 1.96*std_diff:.1f}')
plt.axhline(0, color='black', linestyle=':', alpha=0.5)
plt.xlabel('Average Score')
plt.ylabel('Difference (Base - Small)')
plt.title('Bland-Altman Plot')
plt.legend(fontsize=8)
plt.grid(True, alpha=0.3)

# 3. Residuals plot
ax3 = plt.subplot(2, 3, 3)
predicted = slope * np.array(small_scores) + intercept
residuals = np.array(base_scores) - predicted
plt.scatter(predicted, residuals, alpha=0.7, s=60, color='purple')
plt.axhline(0, color='red', linestyle='-')
plt.xlabel('Predicted Base Score')
plt.ylabel('Residuals')
plt.title('Residuals Plot')
plt.grid(True, alpha=0.3)

# 4. Distribution of differences
ax4 = plt.subplot(2, 3, 4)
plt.hist(differences, bins=15, alpha=0.7, color='orange', edgecolor='black')
plt.axvline(mean_diff, color='red', linestyle='-', linewidth=2, label=f'Mean: {mean_diff:.2f}')
plt.axvline(0, color='black', linestyle=':', alpha=0.7, label='No difference')
plt.xlabel('Difference (Base - Small)')
plt.ylabel('Frequency')
plt.title('Distribution of Differences')
plt.legend()
plt.grid(True, alpha=0.3)

# 5. Sample-by-sample comparison
ax5 = plt.subplot(2, 3, 5)
sample_indices = range(1, n+1)
plt.plot(sample_indices, small_scores, 'b-o', label='Small Model', alpha=0.7, markersize=4)
plt.plot(sample_indices, base_scores, 'r-s', label='Base Model', alpha=0.7, markersize=4)
plt.xlabel('Sample Number')
plt.ylabel('Score')
plt.title('Sample-by-Sample Comparison')
plt.legend()
plt.grid(True, alpha=0.3)

# 6. Agreement analysis
ax6 = plt.subplot(2, 3, 6)
plt.bar(range(len(agreement_ranges)), agreements, alpha=0.7, color='teal')
plt.xlabel('Agreement Tolerance (±points)')
plt.ylabel('Agreement Percentage')
plt.title('Agreement Within Different Tolerances')
plt.xticks(range(len(agreement_ranges)), [f'±{r}' for r in agreement_ranges])
plt.grid(True, alpha=0.3, axis='y')

# Add percentage labels on bars
for i, agreement in enumerate(agreements):
    plt.text(i, agreement + 1, f'{agreement:.1f}%', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# Additional analysis
print(f"\n=== DETAILED ANALYSIS ===")

# Find cases of largest disagreement
abs_differences = np.abs(differences)
worst_disagreements = np.argsort(abs_differences)[-5:]  # Top 5 worst

print(f"Cases with largest disagreements:")
for i, idx in enumerate(reversed(worst_disagreements)):
    print(f"{i+1}. Sample {idx+1}: Small={small_scores[idx]}, Base={base_scores[idx]}, "
          f"Diff={differences[idx]:+.0f}")

# Systematic bias analysis
print(f"\nSystematic bias analysis:")
print(f"Base model scores higher: {np.sum(differences > 0)} times ({np.sum(differences > 0)/n*100:.1f}%)")
print(f"Scores exactly equal: {np.sum(differences == 0)} times ({np.sum(differences == 0)/n*100:.1f}%)")
print(f"Small model scores higher: {np.sum(differences < 0)} times ({np.sum(differences < 0)/n*100:.1f}%)")

# Performance ranges analysis
def categorize_performance(scores):
    low = np.sum(np.array(scores) < 50)
    medium = np.sum((np.array(scores) >= 50) & (np.array(scores) < 80))
    high = np.sum(np.array(scores) >= 80)
    return low, medium, high

small_low, small_med, small_high = categorize_performance(small_scores)
base_low, base_med, base_high = categorize_performance(base_scores)

print(f"\nPerformance distribution:")
print(f"{'Category':<10} {'Small':<8} {'Base':<8}")
print(f"{'Low (<50)':<10} {small_low:<8} {base_low:<8}")
print(f"{'Med (50-79)':<10} {small_med:<8} {base_med:<8}")
print(f"{'High (≥80)':<10} {small_high:<8} {base_high:<8}")

print(f"\n=== INTERPRETATION ===")
if pearson_r >= 0.8:
    print("✓ STRONG correlation - Models show very similar ranking behavior")
elif pearson_r >= 0.6:
    print("✓ MODERATE-STRONG correlation - Models generally agree on quality ranking")
elif pearson_r >= 0.4:
    print("⚠ MODERATE correlation - Some agreement but notable differences")
else:
    print("⚠ WEAK correlation - Models often disagree on quality assessment")

if abs(mean_diff) <= 2:
    print("✓ Small systematic bias between models")
elif abs(mean_diff) <= 5:
    print("⚠ Moderate systematic bias - one model consistently scores higher")
else:
    print("⚠ Large systematic bias - significant difference in scoring patterns")

print(f"\nKey takeaways:")
print(f"• Models explain {r_squared*100:.1f}% of variance in each other")
print(f"• {agreements[2]:.1f}% of scores agree within ±5 points")
print(f"• Average difference is {mean_diff:+.1f} points (Base vs Small)")
# Out:
# === CORRELATION ANALYSIS ===
# Sample size: 500
# Pearson correlation: r = 0.9084 (p = 0.0000)
# Spearman correlation: ρ = 0.8028 (p = 0.0000)
# Correlation strength: Very Strong
# Statistical significance: highly significant (p < 0.001)
#
# === DIFFERENCE ANALYSIS ===
# Mean difference (Base - Small): -0.42 points
# Standard deviation of differences: 6.06 points
# 95% of differences fall within: ±11.87 points
#
# === AGREEMENT ANALYSIS ===
# Percentage of scores agreeing within:
#   ± 1 points:  10.2%
#   ± 2 points:  12.6%
#   ± 5 points:  92.0%
#   ±10 points:  98.4%
#   ±15 points:  99.4%
#
# R² (explained variance): 0.825 (82.5%)
# Unexplained variance: 17.5%
# === DETAILED ANALYSIS ===
# Cases with largest disagreements:
# 1. Sample 176: Small=25, Base=85, Diff=+60
# 2. Sample 179: Small=85, Base=40, Diff=-45
# 3. Sample 428: Small=60, Base=40, Diff=-20
# 4. Sample 42: Small=70, Base=85, Diff=+15
# 5. Sample 276: Small=85, Base=70, Diff=-15
#
# Systematic bias analysis:
# Base model scores higher: 207 times (41.4%)
# Scores exactly equal: 51 times (10.2%)
# Small model scores higher: 242 times (48.4%)
#
# Performance distribution:
# Category   Small    Base
# Low (<50)  27       28
# Med (50-79) 188      194
# High (≥80) 285      278
#
# === INTERPRETATION ===
# ✓ STRONG correlation - Models show very similar ranking behavior
# ✓ Small systematic bias between models
#
# Key takeaways:
# • Models explain 82.5% of variance in each other
# • 92.0% of scores agree within ±5 points
# • Average difference is -0.4 points (Base vs Small)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import pearsonr, spearmanr
import seaborn as sns

# Your score data
small_scores = small
base_scores = base

# Ensure same length
assert len(small_scores) == len(base_scores), "Score arrays must be same length"
n = len(small_scores)

# Calculate correlations
pearson_r, pearson_p = pearsonr(small_scores, base_scores)
spearman_rho, spearman_p = spearmanr(small_scores, base_scores)

# Calculate differences
differences = np.array(base_scores) - np.array(small_scores)
mean_diff = np.mean(differences)
std_diff = np.std(differences, ddof=1)

# Agreement analysis (how often they agree within certain ranges)
def agreement_within_range(scores1, scores2, tolerance):
    """Calculate percentage of scores that agree within tolerance"""
    diff = np.abs(np.array(scores1) - np.array(scores2))
    return np.mean(diff <= tolerance) * 100

agreement_ranges = [1, 2, 5, 10, 15]
agreements = [agreement_within_range(small_scores, base_scores, tol) for tol in agreement_ranges]

print("=== CORRELATION ANALYSIS ===")
print(f"Sample size: {n}")
print(f"Pearson correlation: r = {pearson_r:.4f} (p = {pearson_p:.4f})")
print(f"Spearman correlation: ρ = {spearman_rho:.4f} (p = {spearman_p:.4f})")

# Interpret correlation strength
if abs(pearson_r) >= 0.9:
    strength = "Very Strong"
elif abs(pearson_r) >= 0.7:
    strength = "Strong"
elif abs(pearson_r) >= 0.5:
    strength = "Moderate"
elif abs(pearson_r) >= 0.3:
    strength = "Weak"
else:
    strength = "Very Weak"

print(f"Correlation strength: {strength}")

if pearson_p < 0.001:
    significance = "highly significant (p < 0.001)"
elif pearson_p < 0.01:
    significance = "very significant (p < 0.01)"
elif pearson_p < 0.05:
    significance = "significant (p < 0.05)"
else:
    significance = "not significant (p ≥ 0.05)"

print(f"Statistical significance: {significance}")

print(f"\n=== DIFFERENCE ANALYSIS ===")
print(f"Mean difference (Base - Small): {mean_diff:.2f} points")
print(f"Standard deviation of differences: {std_diff:.2f} points")
print(f"95% of differences fall within: ±{1.96 * std_diff:.2f} points")

print(f"\n=== AGREEMENT ANALYSIS ===")
print("Percentage of scores agreeing within:")
for tol, agreement in zip(agreement_ranges, agreements):
    print(f"  ±{tol:2d} points: {agreement:5.1f}%")

# Calculate R-squared (explained variance)
r_squared = pearson_r ** 2
print(f"\nR² (explained variance): {r_squared:.3f} ({r_squared*100:.1f}%)")
print(f"Unexplained variance: {(1-r_squared)*100:.1f}%")

# Create simplified visualizations
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# 1. Scatter plot with regression line
plt.subplot(1, 2, 1)
plt.scatter(small_scores, base_scores, alpha=0.7, s=60, color='steelblue')

# Add regression line
slope, intercept, _, _, _ = stats.linregress(small_scores, base_scores)
line_x = np.array([min(small_scores), max(small_scores)])
line_y = slope * line_x + intercept
plt.plot(line_x, line_y, 'r--', linewidth=2, alpha=0.8, label=f'Regression line')

# Add perfect correlation line for reference
perfect_line = np.linspace(min(min(small_scores), min(base_scores)), 
                          max(max(small_scores), max(base_scores)), 100)
plt.plot(perfect_line, perfect_line, 'k:', alpha=0.5, label='Perfect correlation')

plt.xlabel('Small Model Score')
plt.ylabel('Base Model Score')
plt.title(f'Model Correlation: r = {pearson_r:.3f}')
plt.grid(True, alpha=0.3)
plt.legend()

# Add correlation info box
plt.text(0.05, 0.95, f'r = {pearson_r:.3f}\nR² = {pearson_r**2:.3f}', 
         transform=plt.gca().transAxes, bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))

# 2. Distribution of differences
plt.subplot(1, 2, 2)
plt.hist(differences, bins=20, alpha=0.7, color='orange', edgecolor='black')
plt.axvline(mean_diff, color='red', linestyle='-', linewidth=2, label=f'Mean: {mean_diff:.2f}')
plt.axvline(0, color='black', linestyle=':', alpha=0.7, label='No difference')
plt.xlabel('Difference (Base - Small)')
plt.ylabel('Frequency')
plt.title('Distribution of Score Differences')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Additional analysis
print(f"\n=== DETAILED ANALYSIS ===")

# Find cases of largest disagreement
abs_differences = np.abs(differences)
worst_disagreements = np.argsort(abs_differences)[-5:]  # Top 5 worst

print(f"Cases with largest disagreements:")
for i, idx in enumerate(reversed(worst_disagreements)):
    print(f"{i+1}. Sample {idx+1}: Small={small_scores[idx]}, Base={base_scores[idx]}, "
          f"Diff={differences[idx]:+.0f}")

# Systematic bias analysis
print(f"\nSystematic bias analysis:")
print(f"Base model scores higher: {np.sum(differences > 0)} times ({np.sum(differences > 0)/n*100:.1f}%)")
print(f"Scores exactly equal: {np.sum(differences == 0)} times ({np.sum(differences == 0)/n*100:.1f}%)")
print(f"Small model scores higher: {np.sum(differences < 0)} times ({np.sum(differences < 0)/n*100:.1f}%)")

# Performance ranges analysis
def categorize_performance(scores):
    low = np.sum(np.array(scores) < 50)
    medium = np.sum((np.array(scores) >= 50) & (np.array(scores) < 80))
    high = np.sum(np.array(scores) >= 80)
    return low, medium, high

small_low, small_med, small_high = categorize_performance(small_scores)
base_low, base_med, base_high = categorize_performance(base_scores)

print(f"\nPerformance distribution:")
print(f"{'Category':<10} {'Small':<8} {'Base':<8}")
print(f"{'Low (<50)':<10} {small_low:<8} {base_low:<8}")
print(f"{'Med (50-79)':<10} {small_med:<8} {base_med:<8}")
print(f"{'High (≥80)':<10} {small_high:<8} {base_high:<8}")

print(f"\n=== INTERPRETATION ===")
if pearson_r >= 0.8:
    print("✓ STRONG correlation - Models show very similar ranking behavior")
elif pearson_r >= 0.6:
    print("✓ MODERATE-STRONG correlation - Models generally agree on quality ranking")
elif pearson_r >= 0.4:
    print("⚠ MODERATE correlation - Some agreement but notable differences")
else:
    print("⚠ WEAK correlation - Models often disagree on quality assessment")

if abs(mean_diff) <= 2:
    print("✓ Small systematic bias between models")
elif abs(mean_diff) <= 5:
    print("⚠ Moderate systematic bias - one model consistently scores higher")
else:
    print("⚠ Large systematic bias - significant difference in scoring patterns")

print(f"\nKey takeaways:")
print(f"• Models explain {r_squared*100:.1f}% of variance in each other")
print(f"• {agreements[2]:.1f}% of scores agree within ±5 points")
print(f"• Average difference is {mean_diff:+.1f} points (Base vs Small)")
# Out:
# === CORRELATION ANALYSIS ===
# Sample size: 500
# Pearson correlation: r = 0.9084 (p = 0.0000)
# Spearman correlation: ρ = 0.8028 (p = 0.0000)
# Correlation strength: Very Strong
# Statistical significance: highly significant (p < 0.001)
#
# === DIFFERENCE ANALYSIS ===
# Mean difference (Base - Small): -0.42 points
# Standard deviation of differences: 6.06 points
# 95% of differences fall within: ±11.87 points
#
# === AGREEMENT ANALYSIS ===
# Percentage of scores agreeing within:
#   ± 1 points:  10.2%
#   ± 2 points:  12.6%
#   ± 5 points:  92.0%
#   ±10 points:  98.4%
#   ±15 points:  99.4%
#
# R² (explained variance): 0.825 (82.5%)
# Unexplained variance: 17.5%
# === DETAILED ANALYSIS ===
# Cases with largest disagreements:
# 1. Sample 176: Small=25, Base=85, Diff=+60
# 2. Sample 179: Small=85, Base=40, Diff=-45
# 3. Sample 428: Small=60, Base=40, Diff=-20
# 4. Sample 42: Small=70, Base=85, Diff=+15
# 5. Sample 276: Small=85, Base=70, Diff=-15
#
# Systematic bias analysis:
# Base model scores higher: 207 times (41.4%)
# Scores exactly equal: 51 times (10.2%)
# Small model scores higher: 242 times (48.4%)
#
# Performance distribution:
# Category   Small    Base
# Low (<50)  27       28
# Med (50-79) 188      194
# High (≥80) 285      278
#
# === INTERPRETATION ===
# ✓ STRONG correlation - Models show very similar ranking behavior
# ✓ Small systematic bias between models
#
# Key takeaways:
# • Models explain 82.5% of variance in each other
# • 92.0% of scores agree within ±5 points
# • Average difference is -0.4 points (Base vs Small)
