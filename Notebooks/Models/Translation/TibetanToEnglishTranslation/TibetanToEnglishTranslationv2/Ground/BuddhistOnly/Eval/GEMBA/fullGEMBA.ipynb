# %%
from datasets import load_from_disk

ds = load_from_disk('base-gemba-ds')
ds
# Out:
# Dataset({
#     features: ['bo', 'en', 'small_predictions', 'base_predictions'],
#     num_rows: 1000
# })

# %%
prompt= """Score each of the following translations from Tibetan to English with respect to the human reference on a continuous scale from 0 to 100, where a score of zero means "no meaning preserved" and score of one hundred means "perfect meaning and grammar". Provide only an overall score for each with no additional output. Provide your scores as two lists, for small and base predictions respectively."""

# %%
list(ds.select(range(0,50)))
# Out:
# [{'bo': 'ཕྱི་ཟླ་༥་ཚེས་༢༥་ཉིན་དགུང་ལོ་སུམ་ཅུ་སོ་ལྔའི་སྟེང་དུ་མངོན་པར་རྫོགས་པའི་སངས་རྒྱས་ཀྱི་གོ་འཕང་ཐོབ།།',
#   'en': 'By the next morning, the morning of May 25, when he was thirty-five, he had attained the Awakening, and became a supreme Buddha.',
#   'small_predictions': 'On the twenty-fifth day of the fifth month, in his thirty-fifth year, he attained the state of complete buddhahood.',
#   'base_predictions': 'On February 25, he attained full enlightenment at the age of thirty-five.'},
#  {'bo': 'ལུས་ལྷ་ངག་སྔགས་སེམས་གྱི་འཕྲོ་འདུ་ཀུན།། ཡེ་ཤེས་ཆེན་པོར་ལམ་དུ་ཁྱེར་བ་དང་།།',
#   'en': 'Integrate everything into the path: body as deity, speech as mantra, And all movements of mind as great primordial wisdom.',
#   'small_predictions': 'Integrate all the movements of body, speech, mantra, and mind into the path as great wisdom.',
#   'base_predictions': 'Integrate all the radiation and reabsorption of body, speech, and mind into the path as great primordial wisdom.'},
# ...

# %%
small_0a = [85, 75, 80, 45, 70, 60, 85, 80, 70, 65, 70, 80, 75, 85, 70, 80, 85, 75, 85, 80, 75, 85, 80, 85, 85, 80, 75, 80, 85, 80, 75, 85, 80, 75, 85, 80, 85, 80, 75, 80, 85, 80, 75, 80, 25, 70, 80, 85, 75, 80]
base_0a = [75, 80, 75, 40, 65, 65, 80, 75, 65, 60, 65, 75, 70, 80, 65, 75, 80, 70, 80, 75, 70, 80, 75, 80, 80, 75, 70, 75, 80, 75, 70, 80, 75, 70, 80, 75, 80, 75, 70, 75, 80, 75, 70, 75, 20, 65, 75, 80, 70, 75]

# %%
list(ds.select(range(50,75)))
# Out:
# [{'bo': 'བྱང་ཆུབ་ཏུ་ཐུགས་བསྐྱེད་ཅིང་གཞན་དོན་དུ་སེམས་དཔའ་རྒྱལ་བའི་སྲས་སུ་གྱུར་པ་དུས་གསུམ་དུ་གཤེགས་ཤིང་བཞུགས་པ་ཐམས་ཅད་ལའོ།། ཚུལ་ཇི་ལྟར་ན་སྒོ་གསུམ་གུས་ཤིང་དད་པའི་ཚུལ་གྱིས་སོ།། དགོས་པ་གང་གི་ཕྱིར་ན། རྒྱུད་ལ་བསོད་ནམས་ཀྱི་ཚོགས་འཕེལ་ཞིང་བར་ཆད་ཞི་བས་རྩོམ་པའི་བྱ་བ་མཐར་ཕྱིན་པར་འགྱུར་བ་དང་། འཕྲལ་ཡུན་གྱི་བདེ་བ་མངོན་མཐོ་དང་ངེས་པར་ལེགས་པའི་ཕུན་ཚོགས་འཐོབ་པར་འགྱུར་བ་སྟེ། རྒྱལ་བའི་ཡུམ་ལས། རིགས་ཀྱི་བུའམ་རིགས་ཀྱི་བུ་མོ་གང་ལ་ལ་ཞིག་གིས་དེ་བཞིན་གཤེགས་པ་ལ་ཕྱག་འཚལ་ལོ་ཞེས་བརྗོད་ན། དེ་ཐམས་ཅད་སྡུག་བསྔལ་གྱི་མཐར་ཕྱིན་པར་འགྱུར་རོ་ཞེས་གསུངས་སོ།། གསུམ་པ་༼བརྩམ་པར་དམ་བཅའ་བ་༽ ནི། ཐོས་དང་བསམ་ལ་རབ་བརྟེན་ནས།། སྒོམ་པའི་ཚུལ་ལ་སྦྱོར་བའི་ཕྱིར།། བདག་ཉིད་དབེན་པར་འདུགསྤྲ་ན།། ཚུལ་འདི་སྣང་བ་བརྗོད་པར་བྱ།། ཞེས་གསུངས་ཏེ། རྗེ་ཉིད་ངེས་དོན་དུ་སངས་རྒྱས་ཀྱི་རྣམ་ཐར་འཛིན་པ་ཡིན་ཀྱང་གདུལ་བྱ་བྱིས་པའི་སྐྱེ་བོ་རྗེས་སུ་བཟུང་བའི་སླད་དུ་སོ་སྐྱེའི་གང་ཟག་ལྟར་བསྟན་ཏེ།',
# ...

# %%
small_0b = [75, 70, 95, 85, 80, 70, 85, 75, 60, 65, 80, 75, 100, 85, 80, 85, 75, 80, 70, 75, 80, 85, 80, 75, 70]
base_0b = [70, 75, 95, 80, 75, 75, 90, 70, 65, 70, 75, 70, 100, 80, 85, 90, 70, 85, 75, 80, 75, 85, 85, 80, 85]

# %%
list(ds.select(range(75,100)))
# Out:
# [{'bo': ' དོན་གྱི་དབང་འདི་གཟིགས་ནས་ས་ར་ཧས། གཉིས་སུ་མི་བྱ་གཅིག་ཏུ་བྱ་བ་སྟེ།། རིག་ག་ས་ལ་བྱེ་བྲག་དག་ཏུ་མ་འབྱེད་པ་ར།།',
#   'en': " Seeing the implication of this, Saraha said in an Enlightenment Song: Don't take it as two, take it as one; Don't distinguish the various specific clans.",
#   'small_predictions': 'Having seen this power of meaning, Saraha said: Do not divide it into two, make it one; Do not distinguish between the levels of knowledge.',
#   'base_predictions': 'Having seen this power of meaning, Saraha said: Do not be two, do not be one, Do not distinguish different types of science.'},
#  {'bo': 'ཀུན་ཀྱང་ཕན་ཚུན་དགྲ་དང་གསོད་པ་ཡིན།།',
#   'en': 'All of you are mutual enemies and murderers.',
#   'small_predictions': 'All of them are enemies and killers.',
#   'base_predictions': 'They are all mutual enemies and killers.'},
# ...

# %%
small_0c = [85, 90, 40, 75, 70, 80, 85, 75, 70, 90, 95, 75, 35, 45, 80, 85, 80, 85, 75, 80, 70, 85, 90, 80, 70, 25, 75, 70]
base_0c = [75, 85, 35, 70, 65, 75, 80, 70, 65, 85, 95, 70, 30, 40, 75, 80, 75, 80, 70, 75, 65, 80, 85, 75, 65, 20, 70, 65]

# %%
small_0 = small_0a + small_0b + small_0c
base_0 = base_0a + base_0b + base_0c

# %%
len(small_0)
# Out:
# 103

# %%
list(ds.select(range(100,125)))
# Out:
# [{'bo': 'མི་ལྡན་པ་དང་གཞན་ལ་ལྡན་པ་རྣམ་པར་གཅོད་པའི་ཚུལ་གཉིས་ལས། སྒྲ་མི་རྟག་པར་བསྒྲུབ་པའི་ཚེན། སྒྲ་ཁོ་ན་མི་རྟག་ཅེས་པའི་ཚུལ་དུ་མི་རྟག་པ་དེ་ཉིད་སྒྲ་ལས་གཞན་ལ། ལྡན་པ་རྣམ་པར་གཅོད་པའི་སྒོ་ནས་མི་སྒྲུབ་ཀྱི། སྒྲ་ཡང་མི་རྟག་པ་ཅེས་པའི་ཚུལ་དུ་སྒྲ་ལི་རྟག་པ་མི་ལྡན་པ་གཅོད་པ་ཙམ་ཡིན་པའི་ཕྱིར།',
#   'en': 'The second] also has two: those who are certain that a third possibility [beyond] sound being permanent or impermanent is a direct contradiction, and those who are uncertain.',
# ...

# %% [markdown]
# FINE

# %%
small_1 = [15, 85, 90, 25, 20, 75, 10, 95, 85, 60, 75, 25, 70, 80, 30, 85, 75, 80, 75, 20, 85, 90, 30, 85]
base_1 = [25, 80, 85, 35, 25, 80, 20, 90, 80, 70, 75, 30, 65, 85, 35, 90, 80, 85, 80, 25, 90, 85, 35, 80]

# %%
len(base_1)
# Out:
# 24

# %%
list(ds.select(range(125,145)))
# Out:
# [{'bo': 'ནང་གི་ལུས་ནི་ཡུལ་དུ་རུང་བ་མིན་པར་བསྒྲིབས་པས་ཆོད་པའི་ཕྱིར།',
#   'en': 'The inside of our body is cut off by an obstruction, making it unsuitable as an object [of sight].',
#   'small_predictions': 'The internal body is obstructed because it is obstructed because it is not suitable as an object.',
#   'base_predictions': 'The internal body is obscured by obscurations to inappropriate objects.'},
#  {'bo': 'རྣམ་རྟོག་རང་ངོས་ནས་ཡལ་འགྲོ།',
#   'en': 'Conceptuality dissipates by itself.',
#   'small_predictions': 'Thoughts vanish by themselves.',
#   'base_predictions': 'Thoughts vanish of their own accord.'},
#  {'bo': 'དཔེར་ན་སྐོམ་པའི་སྡུག་བསྔལ་ཞི་བ་ལ་ཐོབ་འདོད་བྱུང་བ་དེ་སྐོམ་པས་གདུངས་པ་ལ་མི་འདོད་པའི་རྣམ་པར་མཐོང་བ་ལ་རག་ལས་པ་བཞིན་དུ།',
#   'en': 'The desire to relieve the suffering of thirst is based on seeing that you do not want to be tormented by thirst.',
# ...

# %% [markdown]
# FINE

# %%
small_2 = [60, 95, 85, 25, 85, 65, 75, 90, 80, 35, 75, 90, 90, 85, 100, 20, 75, 70, 75, 70]
base_2 = [65, 95, 80, 30, 80, 70, 80, 85, 85, 40, 75, 85, 85, 90, 100, 25, 80, 75, 70, 75]

# %%
len(base_2)
# Out:
# 20

# %%
list(ds.select(range(145,175)))
# Out:
# [{'bo': 'དེ་ལྟར་ཕུང་པོ་མི་རྟག་སོགས་སུ་འཛིན་པའི་རྟོག་པ་ནི་སྣང་ཡུལ་ལ་འཁྲུལ་ཡང་ངེས་པའི་འཛིན་སྟངས་ལ་ཚད་མའི་གནོད་པ་མེད་པས་ཕྱིན་ཅི་མ་ལོག་པའམ་མ་འཁྲུལ་བ་ཞེས་བྱ་ལ།',
#   'en': 'Accordingly, the conception that adheres to the impermanence of personality aggregates, etc. is the grasping pattern of certainty regarding the error in the appearing realm and is not opposed by authority therefore, it is called “nonwayward” or “not mistaken.”',
#   'small_predictions': 'The conceptual thought that apprehends the aggregates to be impermanent and so on is mistaken with regard to its appearing object, but the mode of apprehension of certainty is not invalidated by valid cognition, so it is called unmistaken or unmistaken.',
# ...

# %% [markdown]
# FINE

# %%
small_3 = [85, 75, 70, 85, 80, 85, 70, 75, 80, 85, 70, 80, 75, 85, 80, 75, 85, 80, 75, 65, 80, 85, 75, 80, 85, 70, 80, 85, 75, 85, 85]
base_3 = [88, 70, 65, 80, 75, 88, 75, 70, 75, 85, 60, 85, 80, 88, 85, 80, 85, 85, 80, 50, 85, 85, 80, 85, 88, 75, 85, 88, 80, 88, 88]

# %%
len(base_3)
# Out:
# 31

# %%
list(ds.select(range(175,200)))
# Out:
# [{'bo': 'དེ་འདྲ་བའི་རྫོགས་རིམ་གྱིས་སྙིང་གའི་རྩ་མདུད་རྫོགས་པར་མ་གྲོལ་བར་སེམས་དབེན་དངོས་སམ་དེའི་དོད་ཐུབ་པའི་རྫོགས་རིམ་སྐྱེ་མི་རུང་བའི་ཕྱིར།',
#   'en': 'For you cannot generate actual mental isolation or an equivalent completion-stage practice without completely releasing the channel knots at the heart by such a completion-stage practice.',
#   'small_predictions': 'This is because it is not suitable to generate the actual mind isolation or the completion stage that substitutes that mind isolation without completing the channel knots at the heart by such completion stage.',
#   'base_predictions': 'This is because without having completely released the channel knots at the heart through such a completion stage, you cannot generate the actual mind isolation or the completion stage that is the substitute for it.'},
#  {'bo': 'རང་དང་ཕྱག་རྒྱ་གཉིས་ཀ་གང་ཟག་དབང་པོ་རབ་ཏུ་གྱུར་པ། རྣམ་པར་དག་པའི་དབང་བསྐུར་བ་ཐོབ་ནས།',
# ...

# %% [markdown]
# FINE

# %%
small_4 = [75, 85, 60, 70, 70, 75, 80, 85, 70, 80, 75, 85, 80, 85, 70, 80, 75, 65, 80, 75, 80, 75, 70, 75, 70, 85, 80]
base_4 = [80, 85, 65, 65, 60, 75, 85, 85, 75, 75, 70, 85, 80, 85, 75, 80, 80, 70, 75, 80, 80, 80, 75, 80, 75, 85, 85]

# %%
len(base_4)
# Out:
# 27

# %%
list(ds.select(range(200,225)))
# Out:
# [{'bo': 'བླུན་རྨོངས་གཅན་གཟན་གཏུམ་པོའི་འཚོ་བ་བཞིན།།',
#   'en': 'You spread the excellent tradition of pure vegetarianism',
#   'small_predictions': 'It is like the life of a fool or a ferocious beast.',
#   'base_predictions': 'They are like fools who live in a state of stupidity and savage beasts.'},
#  {'bo': 'ཡངས་དོག་གཉིས་མེད་རིག་པ་མཁའ་ལྟར་དག། དམིགས་པས་སྤྲོ་བསྡུ་བྲལ་བའི་ཀློང་ཉིད་དུ།།',
#   'en': 'As pure presence, it is clear like the sky, nonspatial, nondual; As the vast matrix itself, it is beyond pulsating thought and image.',
#   'small_predictions': 'Within the spacious and spacious state of pure awareness, pure like space, there is no reference point in the matrix that is free of the proliferation and resolution of concepts.',
#   'base_predictions': 'With no duality of spacious versus narrow, awareness is pure like the sky.'},
#  {'bo': 'དེ་ལ་བདག་ཏུ་འཛིན་པ་ལ་དགྲར་བལྟས་པ་ནི། ལེ་འན་ཐམས་ཅད་གཅིག་ལ་གདའ།།',
# ...

# %% [markdown]
# FINE

# %%
small_5 = [15, 75, 45, 25, 60, 85, 85, 95, 70, 80, 85, 80, 95, 95, 70, 40, 85, 75, 85, 30, 85, 75, 80, 85, 95]
base_5 = [20, 70, 35, 85, 50, 80, 40, 90, 75, 75, 85, 80, 95, 95, 65, 25, 80, 75, 85, 25, 80, 70, 75, 80, 95]

# %%
len(base_5)
# Out:
# 25

# %%
list(ds.select(range(225,250)))
# Out:
# [{'bo': 'འདི་ལྟར་ཏིང་ངེ་འཛིན་གྱི་ཡོན་ཏན་དག་ལ་མངོན་པར་ཡིད་ཆེས་པའི་མཚན་ཉིད་དང་ལྡན་པའི་དད་པ་རྣལ་འབྱོར་པ་རྣམས་དེ་ལ་འདོད་པ་སྐྱེའོ།། དེ་ནས་འདོད་པས་བརྩོན་འགྲུས་རྩོམ་མོ། དེ་བརྩོན་འགྲུས་ཀྱི་སྟོབས་ཀྱིས་ལུས་དང་སེམས་ལས་སུ་རུང་བ་ཉིད་བྱེད་དོ།། དེ་བས་ན་དད་པ་ལ་སོགས་པ་ནི་ལེ་ལོ་སྤང་བའི་ཕྱིར་བསྒོམ་མོ།། དྲན་པ་ནི་དམིགས་པ་བརྗེད་པའི་གཉེན་པོའོ།།',
# ...

# %% [markdown]
# FINE

# %%
small_6 = [75, 85, 80, 70, 85, 60, 65, 85, 85, 70, 80, 75, 85, 80, 75, 80, 85, 75, 70, 80, 75, 85, 80, 75, 70]
base_6 = [80, 90, 85, 65, 90, 65, 70, 90, 90, 75, 85, 80, 90, 85, 80, 85, 90, 80, 75, 85, 80, 90, 85, 80, 75]

# %%
len(base_6)
# Out:
# 25

# %%
list(ds.select(range(225,250)))
# Out:
# [{'bo': 'འདི་ལྟར་ཏིང་ངེ་འཛིན་གྱི་ཡོན་ཏན་དག་ལ་མངོན་པར་ཡིད་ཆེས་པའི་མཚན་ཉིད་དང་ལྡན་པའི་དད་པ་རྣལ་འབྱོར་པ་རྣམས་དེ་ལ་འདོད་པ་སྐྱེའོ།། དེ་ནས་འདོད་པས་བརྩོན་འགྲུས་རྩོམ་མོ། དེ་བརྩོན་འགྲུས་ཀྱི་སྟོབས་ཀྱིས་ལུས་དང་སེམས་ལས་སུ་རུང་བ་ཉིད་བྱེད་དོ།། དེ་བས་ན་དད་པ་ལ་སོགས་པ་ནི་ལེ་ལོ་སྤང་བའི་ཕྱིར་བསྒོམ་མོ།། དྲན་པ་ནི་དམིགས་པ་བརྗེད་པའི་གཉེན་པོའོ།།',
# ...

# %% [markdown]
# FINE

# %%
small_7 = [75, 85, 80, 70, 85, 60, 65, 80, 85, 70, 75, 80, 85, 80, 85, 70, 80, 75, 70, 75, 80, 75, 70, 80, 75]
base_7 = [80, 88, 85, 65, 88, 65, 60, 85, 88, 75, 80, 85, 88, 85, 88, 75, 85, 80, 75, 80, 85, 80, 75, 85, 80]

# %%
len(base_7)
# Out:
# 25

# %%
list(ds.select(range(250,275)))
# Out:
# [{'bo': 'ཚེ་བསོད་དཔལ་འབྱོར་ཡེ་ཤེས་ཡོན་ཏན་ཀུན།\xa0།',
#   'en': 'And all the longevity, merit, wealth, wisdom and qualities',
#   'small_predictions': 'Long life, merit, prosperity, wisdom, and qualities',
#   'base_predictions': 'Increase our long life, merit, prosperity, wisdom and qualities,'},
#  {'bo': 'མེད་དགག་གཏན་ཚིགས་སུ་བཀོད་པ་གཅིག་དང་དུ་བྲལ་ལ་སོགས་གཏན་ཚིགས་དང་རིགས་པས་བསྒྲུབས་པས་བསྒྲུབ་བྱ་སྒྱུ་མ་ལ་སོགས་ཡོངས་དཔྱོད་མ་ཡིན་པར་དགག་པ་མ་ཡིན་ཅིང་བདེན་པའི་དངོས་པོ་བཀག་པ་ཙམ་གྱི་རྣམ་དཔྱད་མེད་དགག་བསྒྲུབས་པ་ཡིན་ཏེ། རིག་ཤེས་རྗེས་དཔགས་ཀྱི་རང་བཞིན་སྐྱེ་མེད་ནམ་མཁའ་ལྟ་བུ་སྤྲོས་བྲལ་དོན་དམ་བདེན་པའི་མཚན་ཉིད་དུ་དབུ་མ་རང་རྒྱུད་པའི་བཞེད་པ་ཡིན་ལ། འདིས་དོན་དམ་པར་མེད་ལ་ཀུན་རྫོབ་ཏུ་ཡོད་པར་བསྒྲུབས་པས་རྟག་ཆད་ཀྱི་སྐྱོན་གནས་ཤིང་བློས་དཔྱད་པའི་རིག་ཤེས་ཀྱི་སྤྲོས་བྲལ་མེད་དགག་ཙམ་རྟོགས་པའང་ངེས་པའི་དོན་དུ་མི་གནས་ལ་སྤྲོས་པ་འགོག་པའི་༄༅།། རིག་ཤེས་ཀྱང་སྤྲོས་པའི་བྱེ་བྲག་ལས་མི་འདའོ།། གཉིས་པ་ཐལ་འགྱུར་བ་ནི། བློ་འཁྲུལ་པ་དང་མ་འཁྲུལ་བ་གཉིས་ཀྱི་དབྱེ་བས་བདེན་པ་གཉིས་སུ་འབྱེད་དེ།',
# ...

# %% [markdown]
# FINE

# %%
small_8 = [85, 75, 80, 88, 82, 92, 90, 85, 80, 88, 85, 78, 85, 88, 85, 75, 82, 90, 85, 80, 88, 85, 88, 85, 78, 88, 85, 88]
base_8 = [88, 78, 75, 85, 80, 90, 88, 88, 78, 85, 88, 82, 88, 85, 88, 80, 85, 88, 88, 82, 85, 88, 85, 88, 82, 85, 88, 85]

# %%
len(base_8)
# Out:
# 28

# %%
list(ds.select(range(275,300)))
# Out:
# [{'bo': 'ཡང་ན་ལག་པ་གཉིས་ཀྱང་རུང་།།',
#   'en': 'Or do that with two hands.',
#   'small_predictions': 'Or with both hands.',
#   'base_predictions': 'Whether or not you have two arms.'},
#  {'bo': 'ཞེས་གསུངས་པ་རྣམས་ཀྱང་འདི་པའི་ལུགས་ལ་ཟུར་ཟ་བར་སྣང་ངོ།།',
#   'en': 'These statements appear to be criticizing this system.',
#   'small_predictions': 'There seem to be some criticisms in this system.',
#   'base_predictions': 'These statements also seem to undermine this system.'},
#  {'bo': 'ཧོཿབརྡལ་ཁྱབ་ཐིག་ལེ་ཆེན་པོའི་དཀྱིལ་འཁོར་དུ༔',
#   'en': 'Hoḥ. In the maṇḍala of the great all-pervasive sphere,',
#   'small_predictions': 'Hoḥ. In the maṇḍala of the great all-encompassing sphere',
#   'base_predictions': 'Hoḥ. In this maṇḍala of the great all-encompassing bindu'},
# ...

# %% [markdown]
# FINE

# %%
small_9 = [85, 75, 90, 70, 80, 60, 65, 85, 80, 85, 85, 40, 80, 85, 80, 75, 70, 85, 85, 75, 80, 85, 75, 85]
base_9 = [70, 80, 85, 65, 75, 55, 60, 80, 75, 85, 85, 45, 75, 80, 75, 70, 65, 80, 80, 70, 75, 80, 70, 80]

# %%
len(base_9)
# Out:
# 24

# %%
list(ds.select(range(300,350)))
# Out:
# [{'bo': 'ཟབ་གསང་ཆོས་ཀྱི་བདུད་རྩིས་རྗེས་བཟུང་ནས།།',
#   'en': 'Be guided by the profound secret nectar of the Dharma',
#   'small_predictions': 'Look upon me with the nectar of the profound secret Dharma',
#   'base_predictions': 'Be cared for by the nectar of the profound and secret Dharma'},
#  {'bo': 'མི་ཚེ་ནི་ད་ལྟའི་སྐད་ཅིག་མའི་ཁྲོད་དུ་ཅི་ཞིག་འབྱུང་བཞིན་པ་དེ་ཡིན།',
#   'en': 'What is happening in the present moment is life.',
#   'small_predictions': 'Life is what is happening in the present moment.',
#   'base_predictions': 'Life is what is happening in the present moment.'},
#  {'bo': 'དེ་ནི་འདི་སྐད་དུ་རྐྱེན་མ་ཚང་བའི་ཕྱིར་མ་འོངས་པའི་ཆོས་རྣམས་གཏན་དུ་མི་སྐྱེ་བ་གང་ཡིན་པ་དེ་སོ་སོར་བརྟགས་པ་མ་ཡིན་པའི་འགོག་པའོ་ཞེས་བསྟན་པར་འགྱུར་རོ།།',
#   'en': 'That is, the nonanalytic cessation is the condition by which future entities are permanently obstructed from arising due to an insufficiency of necessary conditions.',
# ...

# %% [markdown]
# FINE

# %%
small_10 = [75, 95, 70, 60, 95, 80, 65, 70, 85, 80, 85, 70, 85, 95, 80, 70, 75, 80, 85, 70, 75, 60, 85, 80, 70, 75, 65, 80, 75, 85, 70, 80, 75, 80, 70, 85, 75, 80, 70, 85, 75, 80, 85, 70, 80, 75, 70, 80, 75, 60]
base_10 = [70, 95, 75, 65, 95, 85, 70, 75, 80, 75, 80, 65, 80, 95, 75, 65, 70, 75, 80, 65, 70, 55, 80, 75, 65, 70, 60, 75, 70, 80, 65, 75, 70, 75, 65, 80, 70, 75, 65, 80, 70, 75, 80, 65, 75, 70, 65, 75, 70, 55]

# %%
len(base_10)
# Out:
# 50

# %%
list(ds.select(range(350,400)))
# Out:
# [{'bo': 'ཕ་རྒྱུད་དང་མ་རྒྱུད་གཉིས་ཀར་རླུང་ཕྲ་མོ་དང་ཐིག་ལེ་སོགས་ལ་རྩེ་གཅིག་ཏུ་དམིགས་ཚུལ་གསུང་ཞིང་། རྩལ་འདོན་བྱ་ཡུལ་གྱི་ཁྱད་པར་མ་གཏོགས་ཁྱད་ཆོས་གཉིས་ཀ་རྒྱུད་སྡེ་གཉིས་ཀར་ཚང་ཡོད།',
#   'en': 'In both father and mother tantras, there is a focus on subde energy and on essences, and so, apart from a question of emphasis, both features are found in both classes of tantra.',
#   'small_predictions': 'Both father and mother tantras speak of the visualization of subtle energy and energy drops, and except for the differences in the focus of the practice, both characteristics are present in both tantras.',
#   'base_predictions': 'It is said in father tantra and mother tantra that one focuses on a subtle energy drop and so forth, with the exception of specific emphasis, both features are complete in both classes of tantra.'},
#  {'bo': 'རང་ཉིད་ལེགས་བཅོས་བྱེད་པའི་བྲེལ་བའི་དབང་གིས་མི་གཞན་ལ་སྐྱོན་བརྗོད་བྱ་ལོང་མེད་པ་བཟོས།',
# ...

# %% [markdown]
# FINE

# %%
small_11 = [75, 82, 65, 92, 70, 85, 78, 85, 88, 70, 88, 92, 78, 85, 88, 85, 78, 85, 75, 80, 85, 78, 82, 85, 75, 88, 85, 80, 75, 92, 82, 85, 78, 80, 82, 88, 85, 75, 80, 78, 85, 82, 85, 78, 80, 82, 88, 85, 78, 75]
base_11 = [85, 88, 72, 92, 82, 88, 85, 88, 90, 78, 90, 92, 85, 88, 90, 88, 85, 88, 82, 85, 88, 85, 88, 88, 82, 90, 88, 85, 82, 92, 88, 88, 85, 85, 88, 90, 88, 82, 85, 85, 88, 88, 88, 85, 85, 88, 90, 88, 85, 82]

# %%
len(base_11)
# Out:
# 50

# %%
list(ds.select(range(400,430)))
# Out:
# [{'bo': 'རྒྱལ་བའི་དགོངས་པ་ཇི་བཞིན་འཆད་པ་ལ།།',
#   'en': 'And as I expound upon the intent of the victorious buddhas',
#   'small_predictions': 'To explain the intent of the victorious ones exactly as it is',
#   'base_predictions': 'In order to explain the intent of the victorious ones'},
#  {'bo': 'ངོ་བོ་ཉིད་སྟོང་པ་ཉིད་ཀྱི་སྐྱེ་བ་མྱི་མཐོང་། འགག་པ་མྱི་མཐོང་། བླང་བ་མྱི་མཐོང་། དོར་བ་མྱི་མཐོང་། ཀུན་ནས་ཉོན་མོངས་པ་མྱི་མཐོང་། རྣམ་པར་བྱང་བ་མྱི་མཐོང་། སྩོགས་པ་མྱི་མཐོང་། འབྲི་བ་མྱི་མཐོང་། འགྲིབ་པ་མྱི་མཐོང་། འཕེལ་བ་མྱི་མཐོང་སྟེ།',
#   'en': 'They do not observe the arising, do not observe the cessation, do not observe the appropriation, do not observe the rejection, do not observe the defilement, do not observe the purification, do not observe the accumulation, do not observe the diminishing, do not observe the decrease, and do not observe the increase of the emptiness of essential nature.',
# ...

# %% [markdown]
# FINE

# %%
small_12 = [85, 95, 75, 90, 70, 80, 75, 85, 80, 70, 75, 80, 85, 90, 75, 80, 85, 80, 85, 90, 85, 85, 85, 80, 85, 85, 85, 85, 60, 80, 75]
base_12 = [80, 95, 70, 85, 65, 75, 70, 80, 75, 65, 70, 75, 80, 85, 70, 75, 80, 75, 80, 85, 80, 80, 80, 75, 80, 80, 80, 80, 40, 75, 70]

# %%
len(base_12)
# Out:
# 31

# %%
list(ds.select(range(430,470)))
# Out:
# [{'bo': 'དེ་བཞིན་གཤེགས་པས་ཇི་ལྟ་བ་བཞིན་གཟིགས་པ་མཐར་ཐུག་པའི་རྒྱུད་ཀྱི་དེ་བཞིན་ཉིད་ཕྱིན་ཅི་མ་ལོག་པ་སྤྲོས་པ་མེད་པ་ཉིད་ཀྱི་རབ་ཏུ་དབྱེ་བས་གནས་པའོ།། གཙོ་བོ་བྱང་ཆུབ་སེམས་དཔའ་འཕགས་པ་རྣམས་ཡིན་མོད་ཀྱི། འཕགས་པ་གཞན་ཡང་རིམ་པ་གཉིས་པའི་ནང་དུ་བསྡུ་བར་བྱའོ།། གཉིས་པ་ནི། དེ་བཞིན་གཤེགས་པའི་ཁམས་ལ་འཇུག་པའི་དབྱེ་བ་རྣམ་པ་གསུམ་ཐ་དད་པར་བསྟན་པར་རིག་པར་བྱ་སྟེ། གང་ལས་བསྟན་ན་ཤེས་རབ་ཀྱི་བ་རོལ་ཏུ་ཕྱིན་ལ་སོགས་པར་དེ་བཞིན་ཉིད་མངོན་སུམ་དུ་རྟོགས་པ་ལ་སོགས་པའི་རྣམ་པར་མི་རྟོག་པའི་ཡེ་ཤེས་ཀྱི་སྒོ་ལ་གདམས་པ་ལས་བརྩམས་ཏེའོ།། དེ་བཞིན་དུ་དོན་དམ་པའི་དབྱེ་བ་ཤེས་ཕྱིན་གྱི་མདོ་ལས་གསུངས་པར་བསྒྲུབས་པས་ཤེར་ཕྱིན་གྱི་མདོ་ལས་ཀུན་རྫོབ་རང་སྟོང་འབའ་ཞིག་བསྟན་གྱི། དོན་དམ་པའི་བདེན་པ་གཞན་སྟོང་མ་བསྟན་ཏོ་ཞེས་ཤེར་ཕྱིན་གྱི་མདོ་དང་བསྟན་བཅོས་འདི་རྩ་འགྲེལ་སུན་དབྱུང་བར་མ་བྱིའོ།། གང་ལ་བསྟན་ན་བྱང་ཆུབ་སེམས་དཔའ་རྣམས་ལའོ།། གཞི་གང་ལ་ཚུལ་ཇི་ལྟར་བསྟན་པ་ནི། ཆོས་ཐམས་ཅད་ཀྱི་དེ་བཞིན་ཉིད་རྣམ་པར་དག་པ་སྤྱིའི་མཚན་ཉིད་བསྟན་པ་རང་བཞིན་གྱིས་སྟོང་པ་གང་ཡིན་པ་དེ་ལ་ཞེས་པ་ནས། དེ་བཞིན་གཤེགས་པ་རྣམས་ཀྱི་ཞེས་སོ།།',
# ...

# %% [markdown]
# FINE

# %%
small_13 = [75, 85, 80, 85, 70, 60, 80, 70, 75, 75, 60, 85, 70, 60, 85, 80, 75, 85, 80, 85, 80, 75, 75, 85, 80, 75, 80, 85, 80, 40, 75, 75, 85, 65, 80, 85, 85, 80, 85]
base_13 = [70, 80, 85, 85, 65, 65, 75, 75, 80, 70, 55, 80, 65, 55, 80, 75, 70, 80, 75, 80, 75, 70, 70, 80, 75, 70, 75, 80, 75, 35, 70, 70, 80, 60, 75, 80, 80, 75, 80]

# %%
len(base_13)
# Out:
# 39

# %%
list(ds.select(range(470,500)))
# Out:
# [{'bo': 'བུམ་པ་མགོར་བཞག།',
#   'en': 'Place the vase on your head.',
#   'small_predictions': 'Place a vase on your head.',
#   'base_predictions': 'Place the vase on their heads.'},
#  {'bo': 'རིམས་ལ་སོགས་པའི་ནད་དང་གདོན་གྱིས་མི་ཚུགས་ཤིང་།',
#   'en': 'One passes beyond the reach of diseases and evil spirits.',
#   'small_predictions': 'You will not be affected by illnesses and malevolent forces, such as plagues.',
#   'base_predictions': 'You will be unassailable by epidemics and malevolent spirits.'},
#  {'bo': 'ཡིད་ཀྱི་དགུ་ལའང་སྲོག་གཅོད་མི་བསམ་མོ།། ཞེས་གསུངས་པ་ལྟར།',
#   'en': 'So think not of killing, even in the depths of your mind.',
#   'small_predictions': 'Even in the case of the nine mental states, do not think of killing.',
#   'base_predictions': 'Also for the nine mental activities, do not think about killing.'},
# ...

# %%
small_14 = [15, 85, 70, 75, 95, 80, 85, 85, 80, 75, 60, 80, 10, 75, 80, 85, 75, 85, 70, 75, 60, 85, 20, 85, 85, 80, 85, 85, 90, 70, 20]
base_14 = [25, 85, 75, 80, 90, 75, 85, 85, 75, 75, 65, 75, 10, 80, 75, 85, 80, 80, 75, 80, 65, 85, 20, 85, 85, 80, 85, 85, 90, 75, 25]

# %%
len(base_14)
# Out:
# 31

# %%
small = small_0 + small_1 + small_2 + small_3 + small_4 + small_5 + small_6 + small_7 + small_8 + small_9 + small_10 + small_11 + small_12 + small_13 + small_14
base = base_0 + base_1 + base_2 + base_3 + base_4 + base_5 + base_6 + base_7 + base_8 + base_9 + base_10 + base_11 + base_12 + base_13 + base_14

# %%
len(small)
# Out:
# 533

# %%
len(base)
# Out:
# 533

# %%
print(small)
# Out:
# [85, 75, 80, 45, 70, 60, 85, 80, 70, 65, 70, 80, 75, 85, 70, 80, 85, 75, 85, 80, 75, 85, 80, 85, 85, 80, 75, 80, 85, 80, 75, 85, 80, 75, 85, 80, 85, 80, 75, 80, 85, 80, 75, 80, 25, 70, 80, 85, 75, 80, 75, 70, 95, 85, 80, 70, 85, 75, 60, 65, 80, 75, 100, 85, 80, 85, 75, 80, 70, 75, 80, 85, 80, 75, 70, 85, 90, 40, 75, 70, 80, 85, 75, 70, 90, 95, 75, 35, 45, 80, 85, 80, 85, 75, 80, 70, 85, 90, 80, 70, 25, 75, 70, 15, 85, 90, 25, 20, 75, 10, 95, 85, 60, 75, 25, 70, 80, 30, 85, 75, 80, 75, 20, 85, 90, 30, 85, 60, 95, 85, 25, 85, 65, 75, 90, 80, 35, 75, 90, 90, 85, 100, 20, 75, 70, 75, 70, 85, 75, 70, 85, 80, 85, 70, 75, 80, 85, 70, 80, 75, 85, 80, 75, 85, 80, 75, 65, 80, 85, 75, 80, 85, 70, 80, 85, 75, 85, 85, 75, 85, 60, 70, 70, 75, 80, 85, 70, 80, 75, 85, 80, 85, 70, 80, 75, 65, 80, 75, 80, 75, 70, 75, 70, 85, 80, 15, 75, 45, 25, 60, 85, 85, 95, 70, 80, 85, 80, 95, 95, 70, 40, 85, 75, 85, 30, 85, 75, 80, 85, 95, 75, 85, 80, 70, 85, 60, 65, 85, 85, 70, 80, 75, 85, 80, 75, 80, 85, 75, 70,
# ...

# %%
print(base)
# Out:
# [75, 80, 75, 40, 65, 65, 80, 75, 65, 60, 65, 75, 70, 80, 65, 75, 80, 70, 80, 75, 70, 80, 75, 80, 80, 75, 70, 75, 80, 75, 70, 80, 75, 70, 80, 75, 80, 75, 70, 75, 80, 75, 70, 75, 20, 65, 75, 80, 70, 75, 70, 75, 95, 80, 75, 75, 90, 70, 65, 70, 75, 70, 100, 80, 85, 90, 70, 85, 75, 80, 75, 85, 85, 80, 85, 75, 85, 35, 70, 65, 75, 80, 70, 65, 85, 95, 70, 30, 40, 75, 80, 75, 80, 70, 75, 65, 80, 85, 75, 65, 20, 70, 65, 25, 80, 85, 35, 25, 80, 20, 90, 80, 70, 75, 30, 65, 85, 35, 90, 80, 85, 80, 25, 90, 85, 35, 80, 65, 95, 80, 30, 80, 70, 80, 85, 85, 40, 75, 85, 85, 90, 100, 25, 80, 75, 70, 75, 88, 70, 65, 80, 75, 88, 75, 70, 75, 85, 60, 85, 80, 88, 85, 80, 85, 85, 80, 50, 85, 85, 80, 85, 88, 75, 85, 88, 80, 88, 88, 80, 85, 65, 65, 60, 75, 85, 85, 75, 75, 70, 85, 80, 85, 75, 80, 80, 70, 75, 80, 80, 80, 75, 80, 75, 85, 85, 20, 70, 35, 85, 50, 80, 40, 90, 75, 75, 85, 80, 95, 95, 65, 25, 80, 75, 85, 25, 80, 70, 75, 80, 95, 80, 90, 85, 65, 90, 65, 70, 90, 90, 75, 85, 80, 90, 85, 80, 85, 90, 80, 75,
# ...

# %%
sub = list(ds)[-500:]

# %%
for _ in [176, 179, 428, 42, 276]:
    print(sub[_])
# Out:
# {'bo': 'ཁོས་ང་ལ་སློབ་འདོད་པའི་དངོས་པོ་ཡོད་ཚད་བཤད་པའམ་སྒྲུབ་ཚར་སྐབས་ཀྱང་། བསྡོམས་པས་སློབ་ཚན་གཙོ་བོ་དྲུག་ལས་མེད། འོན་ཀྱང་སློབ་ཚན་འདི་དག་ངའི་ཀླད་པའི་ནང་དུ་ལོ་སུམ་ཅུ་ལྷག་ལ་ཡང་དང་བསྐྱར་དུ་འཆར།', 'en': 'And when it was all said and done, there were only six main lessons, repeated over 30 years.', 'small_predictions': 'When he told me about everything he wanted to learn, he had only six main subjects, but these subjects were again and again in my head.', 'base_predictions': 'Even when he told me everything he’d wanted to learn, the lessons were only six; but these lessons often appeared in my brain for more than thirty years.'}
# {'bo': 'ཡན་ལག་ཤིང་རྟ་ཡིན་པ་འོག་ནས་འགོག་པའི་ཕྱིར།', 'en': 'It will be explained below that the parts of the chariot cannot be the chariot.', 'small_predictions': 'The reason is that the parts are the chariot is refuted below.', 'base_predictions': 'The following verse is stated to refute the notion that the chariot is the parts.'}
# ...
