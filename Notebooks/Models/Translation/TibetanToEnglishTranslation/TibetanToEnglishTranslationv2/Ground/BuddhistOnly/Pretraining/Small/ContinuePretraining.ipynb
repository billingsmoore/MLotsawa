# %% [markdown]
# # Continue Pretraining on T5

# %%
from datasets import load_from_disk

tokenized_dataset = load_from_disk('Data/tokenized-pretraining-ds')
# Out:
# Loading dataset from disk:   0%|          | 0/17 [00:00<?, ?it/s]

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('../Models/my_tokenizer')

# %% [markdown]
# ## Train the Model

# %%
# %env WANDB_PROJECT=english-v2
# Out:
# env: WANDB_PROJECT=english-v2

# %%
from transformers import TrainingArguments, Trainer, T5ForConditionalGeneration, EarlyStoppingCallback

model = T5ForConditionalGeneration.from_pretrained("google-t5/t5-small", device_map='cuda:0')
model.resize_token_embeddings(len(tokenizer))

training_args = TrainingArguments(
    output_dir="buddhist-small-pretrain",
    auto_find_batch_size=True,
    learning_rate=3e-4,
    num_train_epochs=1
    )

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset
)
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: billingsmoore. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.0
# Run data is saved locally in <code>/home/j/Desktop/MLotsawa/Notebooks/Models/TibetanToEnglishTranslation/TibetanToEnglishTranslationv2/BuddhistOnly/Pretraining/wandb/run-20250407_145400-zw87tl3p</code>
# Syncing run <strong><a href='https://wandb.ai/billingsmoore/english-v2/runs/zw87tl3p' target="_blank">buddhist-small-pretrain</a></strong> to <a href='https://wandb.ai/billingsmoore/english-v2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/billingsmoore/english-v2' target="_blank">https://wandb.ai/billingsmoore/english-v2</a>
#  View run at <a href='https://wandb.ai/billingsmoore/english-v2/runs/zw87tl3p' target="_blank">https://wandb.ai/billingsmoore/english-v2/runs/zw87tl3p</a>
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
#     <div>
#
#       <progress value='215355' max='215355' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [215355/215355 9:50:47, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.436400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.271500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.257900</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.238900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.231500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.229100</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.224800</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.219100</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.209400</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.205600</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.209200</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.204100</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.205300</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.201600</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.201500</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.202600</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.205500</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.198300</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.193800</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.195000</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.193800</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.196000</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.194100</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.193500</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.196000</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.189700</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.193400</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.189000</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.196800</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.198500</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.194500</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.189700</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.190900</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.184300</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.187600</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.188100</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.190600</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.190900</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.191300</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.182300</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.184300</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.183000</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>0.189000</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.180100</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>0.186400</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.179400</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>0.180900</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.181000</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>0.178100</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.184300</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>0.180400</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.184600</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>0.180000</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>0.177000</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>0.174700</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>0.173100</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>0.176400</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>0.185100</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>0.181200</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.183000</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>0.168700</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>0.173500</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>0.176600</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>0.173700</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>0.173600</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>0.172800</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>0.178200</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>0.175000</td>
#     </tr>
#     <tr>
#       <td>34500</td>
#       <td>0.174600</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>0.178800</td>
#     </tr>
#     <tr>
#       <td>35500</td>
#       <td>0.169100</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>0.170200</td>
#     </tr>
#     <tr>
#       <td>36500</td>
#       <td>0.169000</td>
#     </tr>
#     <tr>
#       <td>37000</td>
#       <td>0.171200</td>
#     </tr>
#     <tr>
#       <td>37500</td>
#       <td>0.166800</td>
#     </tr>
#     <tr>
#       <td>38000</td>
#       <td>0.163300</td>
#     </tr>
#     <tr>
#       <td>38500</td>
#       <td>0.167800</td>
#     </tr>
#     <tr>
#       <td>39000</td>
#       <td>0.166000</td>
#     </tr>
#     <tr>
#       <td>39500</td>
#       <td>0.171900</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>0.165800</td>
#     </tr>
#     <tr>
#       <td>40500</td>
#       <td>0.171600</td>
#     </tr>
#     <tr>
#       <td>41000</td>
#       <td>0.172500</td>
#     </tr>
#     <tr>
#       <td>41500</td>
#       <td>0.166600</td>
#     </tr>
#     <tr>
#       <td>42000</td>
#       <td>0.165100</td>
#     </tr>
#     <tr>
#       <td>42500</td>
#       <td>0.167300</td>
#     </tr>
#     <tr>
#       <td>43000</td>
#       <td>0.165200</td>
#     </tr>
#     <tr>
#       <td>43500</td>
#       <td>0.167400</td>
#     </tr>
#     <tr>
#       <td>44000</td>
#       <td>0.162100</td>
#     </tr>
#     <tr>
#       <td>44500</td>
#       <td>0.173400</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>0.166300</td>
#     </tr>
#     <tr>
#       <td>45500</td>
#       <td>0.168800</td>
#     </tr>
#     <tr>
#       <td>46000</td>
#       <td>0.167300</td>
#     </tr>
#     <tr>
#       <td>46500</td>
#       <td>0.162100</td>
#     </tr>
#     <tr>
#       <td>47000</td>
#       <td>0.167100</td>
#     </tr>
#     <tr>
#       <td>47500</td>
#       <td>0.165700</td>
#     </tr>
#     <tr>
#       <td>48000</td>
#       <td>0.166700</td>
#     </tr>
#     <tr>
#       <td>48500</td>
#       <td>0.154400</td>
#     </tr>
#     <tr>
#       <td>49000</td>
#       <td>0.159900</td>
#     </tr>
#     <tr>
#       <td>49500</td>
#       <td>0.167100</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>0.165700</td>
#     </tr>
#     <tr>
#       <td>50500</td>
#       <td>0.160600</td>
#     </tr>
#     <tr>
#       <td>51000</td>
#       <td>0.164900</td>
#     </tr>
#     <tr>
#       <td>51500</td>
#       <td>0.157400</td>
#     </tr>
#     <tr>
#       <td>52000</td>
#       <td>0.163100</td>
#     </tr>
#     <tr>
#       <td>52500</td>
#       <td>0.165400</td>
#     </tr>
#     <tr>
#       <td>53000</td>
#       <td>0.160200</td>
#     </tr>
#     <tr>
#       <td>53500</td>
#       <td>0.156500</td>
#     </tr>
#     <tr>
#       <td>54000</td>
#       <td>0.158200</td>
#     </tr>
#     <tr>
#       <td>54500</td>
#       <td>0.162900</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>0.161700</td>
#     </tr>
#     <tr>
#       <td>55500</td>
#       <td>0.163000</td>
#     </tr>
#     <tr>
#       <td>56000</td>
#       <td>0.156600</td>
#     </tr>
#     <tr>
#       <td>56500</td>
#       <td>0.152600</td>
#     </tr>
#     <tr>
#       <td>57000</td>
#       <td>0.165000</td>
#     </tr>
#     <tr>
#       <td>57500</td>
#       <td>0.158800</td>
#     </tr>
#     <tr>
#       <td>58000</td>
#       <td>0.160100</td>
#     </tr>
#     <tr>
#       <td>58500</td>
#       <td>0.154400</td>
#     </tr>
#     <tr>
#       <td>59000</td>
#       <td>0.160900</td>
#     </tr>
#     <tr>
#       <td>59500</td>
#       <td>0.157800</td>
#     </tr>
#     <tr>
#       <td>60000</td>
#       <td>0.158000</td>
# TrainOutput(global_step=215355, training_loss=0.1568586676080515, metrics={'train_runtime': 35454.4418, 'train_samples_per_second': 48.593, 'train_steps_per_second': 6.074, 'total_flos': 1.1658572859860582e+17, 'train_loss': 0.1568586676080515, 'epoch': 1.0})

# %%
model.save_pretrained('../Models/pretrained-small-model')
