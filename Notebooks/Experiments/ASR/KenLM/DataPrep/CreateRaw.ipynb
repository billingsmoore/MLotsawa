# %%
from datasets import load_from_disk

translation_ds = load_from_disk('/home/j/Desktop/MLotsawa/Notebooks/Models/TibetanToEnglishTranslation/TibetanToEnglishTranslationv2/Ground/BuddhistOnly/RawData/raw-ds')
trans_bo = list(translation_ds['train']['bo'])

# %%
from datasets import load_dataset

stt_ds = load_dataset('billingsmoore/tibetan-asr')
stt_bo = list(stt_ds['train']['transcription'])
stt_ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'transcription', 'speaker_id'],
#         num_rows: 15099
#     })
#     test: Dataset({
#         features: ['audio', 'transcription', 'speaker_id'],
#         num_rows: 1547
#     })
# })

# %%
ocr_ds = load_dataset('BDRC/KhyentseWangpo')

ocr_bo = list(ocr_ds['train']['transcription'])
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00003.parquet:   0%|          | 0.00/389M [00:00<?, ?B/s]
# data/train-00001-of-00003.parquet:   0%|          | 0.00/381M [00:00<?, ?B/s]
# data/train-00002-of-00003.parquet:   0%|          | 0.00/375M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/13527 [00:00<?, ? examples/s]

# %%
bo = trans_bo + stt_bo + ocr_bo

# %%
with open('../Data/all_sentences.txt', 'w', encoding='utf-8') as f:
    for line in bo:
        f.write(line.rstrip() + "\n")
