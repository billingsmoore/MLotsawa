# %% [markdown]
# # Tibetan to English Translation
# ## Setup

# %%
import random
import tensorflow as tf
from tensorflow import keras
import keras_nlp
import matplotlib.pyplot as plt
import pickle

TF_GPU_ALLOCATOR = 'cuda_malloc_async'
# Out:
# 2023-10-29 17:07:19.296169: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-29 17:07:19.296218: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-29 17:07:19.296263: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-29 17:07:19.307132: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using TensorFlow backend

# %%
MAX_SEQUENCE_LENGTH = 45
VOCAB_SIZE = 15000

EMBED_DIM = 256
INTERMEDIATE_DIM = 2048
NUM_HEADS = 8

AUTOTUNE = tf.data.AUTOTUNE

# %%
with open('/home/j/Documents/Projects/Iron-Bridge/lotsawa/tokenizers/tib-tokenizer.pickle', 'rb') as handle:
    tib_tokenizer = pickle.load(handle)

with open('/home/j/Documents/Projects/Iron-Bridge/lotsawa/tokenizers/eng-tokenizer.pickle', 'rb') as handle:
    eng_tokenizer = pickle.load(handle)
# Out:
# 2023-10-29 17:07:23.784124: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 17:07:23.791969: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 17:07:23.792432: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 17:07:23.793819: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 17:07:23.794130: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 17:07:23.794366: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 17:07:23.897439: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 17:07:23.897716: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 17:07:23.897957: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 17:07:23.898155: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1286 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# ### Load in Data

# %%
def load_data(text_file):
    with open(text_file) as f:
        lines = f.read().split("\n")[:-1]
    text_pairs = []
    for line in lines:
        try:
            tib, eng = line.split(",")[:2]
            eng = eng.lower()
            text_pairs.append((tib, eng))
        except:
            pass

    random.shuffle(text_pairs)
    num_val_samples = int(0.05 * len(text_pairs))
    num_train_samples = len(text_pairs) - num_val_samples
    train_pairs = text_pairs[:num_train_samples]
    val_pairs = text_pairs[num_train_samples :]

    print(f"{len(text_pairs)} total pairs")
    print(f"{len(train_pairs)} training pairs")
    print(f"{len(val_pairs)} validation pairs")

    return train_pairs, val_pairs

# %% [markdown]
# ### Data Preprocessing

# %%
def tib_eng_preprocess_batch(tib, eng):

    tib = tib_tokenizer(tib)
    eng = eng_tokenizer(eng)
    

    # add special tokens [start] and [end] and pad tib
    tib_start_end_packer = keras_nlp.layers.StartEndPacker(
        sequence_length = MAX_SEQUENCE_LENGTH,
        start_value = tib_tokenizer.token_to_id("[START]"),
        end_value = tib_tokenizer.token_to_id("[END]"),
        pad_value = tib_tokenizer.token_to_id("[PAD]")
    )

    tib = tib_start_end_packer(tib)

    # pad eng to max_sequence_length
    eng_start_end_packer = keras_nlp.layers.StartEndPacker(
        sequence_length=MAX_SEQUENCE_LENGTH+1,
        pad_value = eng_tokenizer.token_to_id("[PAD]"),
    )

    eng = eng_start_end_packer(eng)



    return (
        {
        "encoder_inputs": tib,
        "decoder_inputs": eng[:, :-1]
        },
        eng[:, 1:],
    )

def make_dataset(pairs, batch_size):
    tib_texts, eng_texts = zip(*pairs)
    tib_texts = list(tib_texts)
    eng_texts = list(eng_texts)
    dataset = tf.data.Dataset.from_tensor_slices((tib_texts, eng_texts))
    dataset=dataset.batch(batch_size)
    dataset = dataset.map(tib_eng_preprocess_batch, num_parallel_calls=AUTOTUNE)
    return dataset.shuffle(2048).prefetch(16).cache()

# %%
encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="encoder_inputs")

x = keras_nlp.layers.TokenAndPositionEmbedding(
    vocabulary_size=VOCAB_SIZE,
    sequence_length = MAX_SEQUENCE_LENGTH,
    embedding_dim=EMBED_DIM,
    mask_zero=True,
)(encoder_inputs)

encoder_outputs = keras_nlp.layers.TransformerEncoder(
    intermediate_dim = INTERMEDIATE_DIM, num_heads=NUM_HEADS
)(inputs=x)
encoder = keras.Model(encoder_inputs, encoder_outputs)

decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="decoder_inputs")
encoded_seq_inputs = keras.Input(shape=(None, EMBED_DIM), name="decoder_state_inputs")

x = keras_nlp.layers.TokenAndPositionEmbedding(
    vocabulary_size=VOCAB_SIZE,
    sequence_length=MAX_SEQUENCE_LENGTH,
    embedding_dim=EMBED_DIM,
    mask_zero=True,
)(decoder_inputs)

x = keras_nlp.layers.TransformerDecoder(
    intermediate_dim=INTERMEDIATE_DIM, num_heads=NUM_HEADS
)(decoder_sequence=x, encoder_sequence=encoded_seq_inputs)
x = keras.layers.Dropout(0.5)(x)
decoder_outputs = keras.layers.Dense(VOCAB_SIZE, activation="softmax")(x)
decoder = keras.Model(
    [
        decoder_inputs,
        encoded_seq_inputs
    ],
    decoder_outputs,
)
decoder_outputs = decoder([decoder_inputs, encoder_outputs])

tib_eng_translator = keras.Model(
    [encoder_inputs, decoder_inputs],
    decoder_outputs,
    name="tib_eng_translator",
)

# %%
tib_eng_translator = tf.keras.models.load_model("/home/j/Documents/Projects/Iron-Bridge/lotsawa/models/tib-eng-translator-0.4.1.30.keras")

tib_eng_translator.compile(
    "rmsprop", 
    loss="sparse_categorical_crossentropy", 
    metrics=["accuracy"]
)

loss_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)

# %%
def train(tib_eng_translator):
    for i in range(31): # range beginning updated because of crash
        
        print('TRAINING BATCH ' + str(i))

        # load in batch from training batches
        text_file = '/home/j/Documents/Projects/Iron-Bridge/lotsawa/data/training-batches/training-batch-'+str(i)+'.txt'
        train_pairs, val_pairs = load_data(text_file)
        
        for j in range(2, 6):
            # make datasets from loaded data
            batch_size = 16 * (2**j)
            print('BATCH SIZE ' + str(batch_size))
            tib_eng_train_ds = make_dataset(train_pairs, batch_size)
            tib_eng_val_ds = make_dataset(val_pairs, batch_size)
            
            # fit model to dataset batch
            tib_eng_translator.fit(
            tib_eng_train_ds, 
            epochs=100, 
            validation_data=tib_eng_val_ds,
            callbacks=[loss_callback]
            )

            # save the model
            tib_eng_translator.save('/home/j/Documents/Projects/Iron-Bridge/lotsawa/models/tib-eng-translator-0.4.1.'+str(i)+'.keras')

# %%
train(tib_eng_translator)
# Out:
# TRAINING BATCH 0
# 499972 total pairs
# 474974 training pairs
# 24998 validation pairs
# BATCH SIZE 64
# Epoch 1/100
# 7422/7422 [==============================] - 329s 43ms/step - loss: 0.9229 - accuracy: 0.8782 - val_loss: 0.7436 - val_accuracy: 0.9106
# Epoch 2/100
# 7422/7422 [==============================] - 305s 41ms/step - loss: 0.8834 - accuracy: 0.8854 - val_loss: 0.7299 - val_accuracy: 0.9145
# Epoch 3/100
# 7422/7422 [==============================] - 304s 41ms/step - loss: 0.8518 - accuracy: 0.8898 - val_loss: 0.7200 - val_accuracy: 0.9165
# Epoch 4/100
# 7422/7422 [==============================] - 304s 41ms/step - loss: 0.8309 - accuracy: 0.8928 - val_loss: 0.7009 - val_accuracy: 0.9181
# Epoch 5/100
# 7422/7422 [==============================] - 303s 41ms/step - loss: 0.8199 - accuracy: 0.8942 - val_loss: 0.6867 - val_accuracy: 0.9210
# Epoch 6/100
# 7422/7422 [==============================] - 301s 41ms/step - loss: 0.8054 - accuracy: 0.8961 - val_loss: 0.6796 - val_accuracy: 0.9212
# Epoch 7/100
# 7422/7422 [==============================] - 304s 41ms/step - loss: 0.8410 - accuracy: 0.8929 - val_loss: 0.6811 - val_accuracy: 0.9214
# Epoch 8/100
# 7422/7422 [==============================] - 304s 41ms/step - loss: 0.7943 - accuracy: 0.8977 - val_loss: 0.6710 - val_accuracy: 0.9230
# Epoch 9/100
# 7422/7422 [==============================] - 303s 41ms/step - loss: 0.7844 - accuracy: 0.8989 - val_loss: 0.6512 - val_accuracy: 0.9240
# Epoch 10/100
# 7422/7422 [==============================] - 305s 41ms/step - loss: 0.7838 - accuracy: 0.8990 - val_loss: 0.7463 - val_accuracy: 0.9166
# Epoch 11/100
# 7422/7422 [==============================] - 304s 41ms/step - loss: 0.7784 - accuracy: 0.8999 - val_loss: 0.6502 - val_accuracy: 0.9253
# Epoch 12/100
# 7422/7422 [==============================] - 304s 41ms/step - loss: 0.7703 - accuracy: 0.9009 - val_loss: 0.6448 - val_accuracy: 0.9253
# Epoch 13/100
# 7422/7422 [==============================] - 303s 41ms/step - loss: 0.7834 - accuracy: 0.8998 - val_loss: 0.6444 - val_accuracy: 0.9267
# Epoch 14/100
# 7422/7422 [==============================] - 304s 41ms/step - loss: 0.7616 - accuracy: 0.9020 - val_loss: 0.6484 - val_accuracy: 0.9252
# Epoch 15/100
# 7422/7422 [==============================] - 304s 41ms/step - loss: 1.9888 - accuracy: 0.7269 - val_loss: 2.1371 - val_accuracy: 0.6802
# Epoch 16/100
# 7422/7422 [==============================] - 304s 41ms/step - loss: 2.3503 - accuracy: 0.6705 - val_loss: 1.7485 - val_accuracy: 0.7398
# Epoch 17/100
# 7422/7422 [==============================] - 303s 41ms/step - loss: 2.0484 - accuracy: 0.7164 - val_loss: 1.5914 - val_accuracy: 0.7745
# BATCH SIZE 128
# Epoch 1/100
# 2023-10-29 18:37:02.190506: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 329.59MiB (rounded to 345600000)requested by op tib_eng_translator/model_1/dense/Softmax
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-10-29 18:37:02.190587: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2023-10-29 18:37:02.190626: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 108, Chunks in use: 105. 27.0KiB allocated for chunks. 26.2KiB in use in bin. 443B client-requested in use in bin.
# 2023-10-29 18:37:02.190657: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-29 18:37:02.190688: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 121, Chunks in use: 121. 123.5KiB allocated for chunks. 123.5KiB in use in bin. 121.0KiB client-requested in use in bin.
# 2023-10-29 18:37:02.190717: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 1, Chunks in use: 0. 2.8KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-29 18:37:02.190747: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 3, Chunks in use: 2. 13.5KiB allocated for chunks. 9.0KiB in use in bin. 7.5KiB client-requested in use in bin.
# 2023-10-29 18:37:02.190776: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 10, Chunks in use: 10. 85.8KiB allocated for chunks. 85.8KiB in use in bin. 80.0KiB client-requested in use in bin.
# 2023-10-29 18:37:02.190804: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 14, Chunks in use: 14. 315.0KiB allocated for chunks. 315.0KiB in use in bin. 315.0KiB client-requested in use in bin.
# 2023-10-29 18:37:02.190831: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 13, Chunks in use: 13. 652.0KiB allocated for chunks. 652.0KiB in use in bin. 616.9KiB client-requested in use in bin.
# 2023-10-29 18:37:02.190860: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 3, Chunks in use: 3. 242.0KiB allocated for chunks. 242.0KiB in use in bin. 148.6KiB client-requested in use in bin.
# 2023-10-29 18:37:02.190885: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-29 18:37:02.190914: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 60, Chunks in use: 60. 15.77MiB allocated for chunks. 15.77MiB in use in bin. 15.00MiB client-requested in use in bin.
# 2023-10-29 18:37:02.190943: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 1, Chunks in use: 1. 1001.0KiB allocated for chunks. 1001.0KiB in use in bin. 1000.9KiB client-requested in use in bin.
# 2023-10-29 18:37:02.190971: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 2, Chunks in use: 2. 2.69MiB allocated for chunks. 2.69MiB in use in bin. 2.45MiB client-requested in use in bin.
# 2023-10-29 18:37:02.191000: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 20, Chunks in use: 20. 43.24MiB allocated for chunks. 43.24MiB in use in bin. 40.00MiB client-requested in use in bin.
# 2023-10-29 18:37:02.191030: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 31, Chunks in use: 30. 188.09MiB allocated for chunks. 182.46MiB in use in bin. 175.61MiB client-requested in use in bin.
# 2023-10-29 18:37:02.191064: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 14, Chunks in use: 14. 193.83MiB allocated for chunks. 193.83MiB in use in bin. 187.03MiB client-requested in use in bin.
# 2023-10-29 18:37:02.191095: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 3, Chunks in use: 3. 75.76MiB allocated for chunks. 75.76MiB in use in bin. 43.95MiB client-requested in use in bin.
# 2023-10-29 18:37:02.191126: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 2, Chunks in use: 2. 90.00MiB allocated for chunks. 90.00MiB in use in bin. 90.00MiB client-requested in use in bin.
# 2023-10-29 18:37:02.191154: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-29 18:37:02.191181: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-29 18:37:02.191212: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 2, Chunks in use: 2. 674.23MiB allocated for chunks. 674.23MiB in use in bin. 659.18MiB client-requested in use in bin.
# 2023-10-29 18:37:02.191242: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 329.59MiB was 256.00MiB, Chunk State:
# 2023-10-29 18:37:02.191267: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 1348468736
# 2023-10-29 18:37:02.191294: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea000000 of size 1025024 next 1
# 2023-10-29 18:37:02.191321: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea0fa400 of size 1280 next 2
# 2023-10-29 18:37:02.191345: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea0fa900 of size 1090048 next 3
# 2023-10-29 18:37:02.191370: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea204b00 of size 256 next 4
# 2023-10-29 18:37:02.191392: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea204c00 of size 256 next 5
# 2023-10-29 18:37:02.191436: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea204d00 of size 256 next 8
# 2023-10-29 18:37:02.191462: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea204e00 of size 1024 next 6
# 2023-10-29 18:37:02.191495: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea205200 of size 256 next 7
# 2023-10-29 18:37:02.191519: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea205300 of size 1024 next 9
# 2023-10-29 18:37:02.191543: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea205700 of size 1024 next 14
# 2023-10-29 18:37:02.191566: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea205b00 of size 1024 next 15
# 2023-10-29 18:37:02.191588: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea205f00 of size 256 next 16
# 2023-10-29 18:37:02.191611: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea206000 of size 256 next 17
# 2023-10-29 18:37:02.191635: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea206100 of size 8192 next 20
# 2023-10-29 18:37:02.191657: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea208100 of size 1024 next 23
# 2023-10-29 18:37:02.191680: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea208500 of size 256 next 18
# 2023-10-29 18:37:02.191703: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea208600 of size 256 next 19
# 2023-10-29 18:37:02.191727: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea208700 of size 1024 next 27
# 2023-10-29 18:37:02.191751: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea208b00 of size 1024 next 30
# 2023-10-29 18:37:02.191774: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea208f00 of size 1024 next 32
# 2023-10-29 18:37:02.191796: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea209300 of size 1024 next 34
# 2023-10-29 18:37:02.191819: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea209700 of size 256 next 25
# 2023-10-29 18:37:02.191843: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea209800 of size 73728 next 12
# 2023-10-29 18:37:02.191868: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea21b800 of size 46080 next 13
# 2023-10-29 18:37:02.191890: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea226c00 of size 1024 next 36
# 2023-10-29 18:37:02.191912: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea227000 of size 1024 next 26
# 2023-10-29 18:37:02.191935: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea227400 of size 1024 next 39
# 2023-10-29 18:37:02.191958: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea227800 of size 1024 next 42
# 2023-10-29 18:37:02.191980: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea227c00 of size 8192 next 43
# 2023-10-29 18:37:02.192004: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea229c00 of size 1024 next 44
# 2023-10-29 18:37:02.192028: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22a000 of size 1024 next 47
# 2023-10-29 18:37:02.192052: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22a400 of size 1024 next 49
# 2023-10-29 18:37:02.192073: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22a800 of size 1024 next 50
# 2023-10-29 18:37:02.192094: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22ac00 of size 1024 next 51
# 2023-10-29 18:37:02.192117: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22b000 of size 1024 next 54
# 2023-10-29 18:37:02.192139: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22b400 of size 1024 next 56
# 2023-10-29 18:37:02.192162: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22b800 of size 1024 next 58
# 2023-10-29 18:37:02.192185: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22bc00 of size 1024 next 60
# 2023-10-29 18:37:02.192207: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22c000 of size 1024 next 62
# 2023-10-29 18:37:02.192230: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22c400 of size 1024 next 64
# 2023-10-29 18:37:02.192254: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22c800 of size 256 next 65
# 2023-10-29 18:37:02.192287: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22c900 of size 256 next 67
# 2023-10-29 18:37:02.192310: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22ca00 of size 1024 next 68
# 2023-10-29 18:37:02.192332: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22ce00 of size 256 next 83
# 2023-10-29 18:37:02.192357: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22cf00 of size 256 next 138
# 2023-10-29 18:37:02.192380: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22d000 of size 256 next 120
# 2023-10-29 18:37:02.192403: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22d100 of size 256 next 69
# 2023-10-29 18:37:02.192426: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22d200 of size 1024 next 72
# 2023-10-29 18:37:02.192449: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22d600 of size 1024 next 153
# 2023-10-29 18:37:02.192474: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22da00 of size 1024 next 151
# 2023-10-29 18:37:02.192497: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22de00 of size 1024 next 156
# 2023-10-29 18:37:02.192519: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22e200 of size 1024 next 157
# 2023-10-29 18:37:02.192543: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22e600 of size 1024 next 149
# 2023-10-29 18:37:02.192566: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22ea00 of size 1024 next 148
# 2023-10-29 18:37:02.192589: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22ee00 of size 1024 next 143
# 2023-10-29 18:37:02.192612: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22f200 of size 1024 next 141
# 2023-10-29 18:37:02.192634: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22f600 of size 1024 next 144
# 2023-10-29 18:37:02.192658: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22fa00 of size 1024 next 75
# 2023-10-29 18:37:02.192683: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea22fe00 of size 1024 next 78
# 2023-10-29 18:37:02.192706: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea230200 of size 1024 next 80
# 2023-10-29 18:37:02.192730: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea230600 of size 1024 next 84
# 2023-10-29 18:37:02.192753: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea230a00 of size 1024 next 81
# 2023-10-29 18:37:02.192776: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea230e00 of size 1024 next 88
# 2023-10-29 18:37:02.192800: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea231200 of size 1024 next 90
# 2023-10-29 18:37:02.192823: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea231600 of size 1024 next 92
# 2023-10-29 18:37:02.192848: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea231a00 of size 1792 next 40
# 2023-10-29 18:37:02.192871: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea232100 of size 46080 next 41
# 2023-10-29 18:37:02.192894: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea23d500 of size 431872 next 29
# 2023-10-29 18:37:02.192916: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea2a6c00 of size 262144 next 28
# 2023-10-29 18:37:02.192938: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea2e6c00 of size 262144 next 31
# 2023-10-29 18:37:02.192960: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea326c00 of size 262144 next 33
# 2023-10-29 18:37:02.192981: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea366c00 of size 262144 next 35
# 2023-10-29 18:37:02.193001: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea3a6c00 of size 262144 next 66
# 2023-10-29 18:37:02.193021: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea3e6c00 of size 262144 next 99
# 2023-10-29 18:37:02.193041: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea426c00 of size 262144 next 113
# 2023-10-29 18:37:02.193061: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea466c00 of size 262144 next 112
# 2023-10-29 18:37:02.193081: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea4a6c00 of size 262144 next 115
# 2023-10-29 18:37:02.193102: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea4e6c00 of size 262144 next 117
# 2023-10-29 18:37:02.193123: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea526c00 of size 262144 next 119
# 2023-10-29 18:37:02.193145: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea566c00 of size 262144 next 159
# 2023-10-29 18:37:02.193167: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea5a6c00 of size 262144 next 145
# 2023-10-29 18:37:02.193189: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea5e6c00 of size 262144 next 22
# 2023-10-29 18:37:02.193211: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea626c00 of size 2097152 next 21
# 2023-10-29 18:37:02.193233: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ea826c00 of size 2097152 next 24
# 2023-10-29 18:37:02.193255: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55eaa26c00 of size 22193152 next 10
# 2023-10-29 18:37:02.193277: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ebf51000 of size 15360000 next 11
# 2023-10-29 18:37:02.193298: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecdf7000 of size 1024 next 94
# 2023-10-29 18:37:02.193319: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecdf7400 of size 1024 next 96
# 2023-10-29 18:37:02.193340: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecdf7800 of size 60160 next 163
# 2023-10-29 18:37:02.193361: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece06300 of size 1024 next 203
# 2023-10-29 18:37:02.193383: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece06700 of size 1024 next 205
# 2023-10-29 18:37:02.193404: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece06b00 of size 1024 next 243
# 2023-10-29 18:37:02.193425: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece06f00 of size 1024 next 244
# 2023-10-29 18:37:02.193446: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece07300 of size 1024 next 245
# 2023-10-29 18:37:02.193468: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece07700 of size 1024 next 236
# 2023-10-29 18:37:02.193490: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f55ece07b00 of size 256 next 381
# 2023-10-29 18:37:02.193511: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece07c00 of size 256 next 265
# 2023-10-29 18:37:02.193538: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece07d00 of size 256 next 290
# 2023-10-29 18:37:02.193559: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece07e00 of size 256 next 210
# 2023-10-29 18:37:02.193580: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece07f00 of size 1024 next 232
# 2023-10-29 18:37:02.193601: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece08300 of size 1024 next 238
# 2023-10-29 18:37:02.193621: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece08700 of size 1024 next 208
# 2023-10-29 18:37:02.193643: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece08b00 of size 256 next 366
# 2023-10-29 18:37:02.193665: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece08c00 of size 256 next 370
# 2023-10-29 18:37:02.193687: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece08d00 of size 256 next 372
# 2023-10-29 18:37:02.193708: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece08e00 of size 256 next 363
# 2023-10-29 18:37:02.193729: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece08f00 of size 256 next 351
# 2023-10-29 18:37:02.193751: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece09000 of size 256 next 346
# 2023-10-29 18:37:02.193773: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece09100 of size 256 next 260
# 2023-10-29 18:37:02.193802: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece09200 of size 256 next 217
# 2023-10-29 18:37:02.193826: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece09300 of size 63744 next 85
# 2023-10-29 18:37:02.193848: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece18c00 of size 1024 next 100
# 2023-10-29 18:37:02.193870: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece19000 of size 1024 next 103
# 2023-10-29 18:37:02.193891: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece19400 of size 1024 next 98
# 2023-10-29 18:37:02.193913: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece19800 of size 1024 next 104
# 2023-10-29 18:37:02.193935: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece19c00 of size 1024 next 170
# 2023-10-29 18:37:02.193955: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1a000 of size 1024 next 171
# 2023-10-29 18:37:02.193976: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1a400 of size 1024 next 107
# 2023-10-29 18:37:02.193996: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1a800 of size 1024 next 73
# 2023-10-29 18:37:02.194016: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1ac00 of size 1024 next 77
# 2023-10-29 18:37:02.194038: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1b000 of size 256 next 162
# 2023-10-29 18:37:02.194059: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1b100 of size 1024 next 158
# 2023-10-29 18:37:02.194080: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1b500 of size 1024 next 135
# 2023-10-29 18:37:02.194100: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1b900 of size 1024 next 155
# 2023-10-29 18:37:02.194121: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1bd00 of size 1792 next 109
# 2023-10-29 18:37:02.194142: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1c400 of size 1024 next 111
# 2023-10-29 18:37:02.194162: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1c800 of size 1024 next 114
# 2023-10-29 18:37:02.194183: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1cc00 of size 1024 next 116
# 2023-10-29 18:37:02.194204: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1d000 of size 256 next 118
# 2023-10-29 18:37:02.194226: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1d100 of size 256 next 160
# 2023-10-29 18:37:02.194246: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1d200 of size 256 next 121
# 2023-10-29 18:37:02.194265: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1d300 of size 256 next 122
# 2023-10-29 18:37:02.194285: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1d400 of size 256 next 123
# 2023-10-29 18:37:02.194308: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece1d500 of size 87040 next 164
# 2023-10-29 18:37:02.194329: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece32900 of size 8192 next 169
# 2023-10-29 18:37:02.194351: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece34900 of size 9984 next 53
# 2023-10-29 18:37:02.194372: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece37000 of size 262144 next 52
# 2023-10-29 18:37:02.194393: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ece77000 of size 262144 next 55
# 2023-10-29 18:37:02.194413: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55eceb7000 of size 262144 next 57
# 2023-10-29 18:37:02.194434: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecef7000 of size 262144 next 59
# 2023-10-29 18:37:02.194455: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecf37000 of size 262144 next 61
# 2023-10-29 18:37:02.194477: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecf77000 of size 262144 next 63
# 2023-10-29 18:37:02.194502: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfb7000 of size 46080 next 105
# 2023-10-29 18:37:02.194524: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfc2400 of size 8192 next 152
# 2023-10-29 18:37:02.194548: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfc4400 of size 46080 next 150
# 2023-10-29 18:37:02.194568: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfcf800 of size 1024 next 142
# 2023-10-29 18:37:02.194590: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfcfc00 of size 1024 next 140
# 2023-10-29 18:37:02.194612: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd0000 of size 1024 next 129
# 2023-10-29 18:37:02.194634: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd0400 of size 1024 next 127
# 2023-10-29 18:37:02.194657: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd0800 of size 1024 next 132
# 2023-10-29 18:37:02.194679: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd0c00 of size 1024 next 79
# 2023-10-29 18:37:02.194701: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd1000 of size 1024 next 131
# 2023-10-29 18:37:02.194723: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd1400 of size 8192 next 126
# 2023-10-29 18:37:02.194748: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd3400 of size 1024 next 124
# 2023-10-29 18:37:02.194773: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd3800 of size 1024 next 174
# 2023-10-29 18:37:02.194799: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd3c00 of size 1024 next 86
# 2023-10-29 18:37:02.194825: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4000 of size 256 next 134
# 2023-10-29 18:37:02.194852: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4100 of size 256 next 128
# 2023-10-29 18:37:02.194880: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4200 of size 256 next 175
# 2023-10-29 18:37:02.194906: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4300 of size 256 next 176
# 2023-10-29 18:37:02.194932: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4400 of size 256 next 177
# 2023-10-29 18:37:02.194960: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4500 of size 256 next 178
# 2023-10-29 18:37:02.194988: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4600 of size 256 next 179
# 2023-10-29 18:37:02.195016: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4700 of size 256 next 180
# 2023-10-29 18:37:02.195043: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4800 of size 256 next 181
# 2023-10-29 18:37:02.195071: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4900 of size 256 next 182
# 2023-10-29 18:37:02.195112: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4a00 of size 256 next 183
# 2023-10-29 18:37:02.195136: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4b00 of size 256 next 184
# 2023-10-29 18:37:02.195157: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4c00 of size 256 next 185
# 2023-10-29 18:37:02.195178: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4d00 of size 256 next 186
# 2023-10-29 18:37:02.195199: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4e00 of size 256 next 187
# 2023-10-29 18:37:02.195224: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd4f00 of size 256 next 188
# 2023-10-29 18:37:02.195245: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5000 of size 256 next 189
# 2023-10-29 18:37:02.195267: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5100 of size 256 next 190
# 2023-10-29 18:37:02.195290: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5200 of size 256 next 191
# 2023-10-29 18:37:02.195312: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5300 of size 256 next 192
# 2023-10-29 18:37:02.195334: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5400 of size 256 next 193
# 2023-10-29 18:37:02.195356: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5500 of size 256 next 194
# 2023-10-29 18:37:02.195378: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5600 of size 256 next 195
# 2023-10-29 18:37:02.195402: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5700 of size 256 next 196
# 2023-10-29 18:37:02.195447: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5800 of size 256 next 197
# 2023-10-29 18:37:02.195470: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5900 of size 256 next 274
# 2023-10-29 18:37:02.195493: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5a00 of size 256 next 267
# 2023-10-29 18:37:02.195514: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5b00 of size 256 next 200
# 2023-10-29 18:37:02.195536: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd5c00 of size 1024 next 300
# 2023-10-29 18:37:02.195558: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd6000 of size 1024 next 258
# 2023-10-29 18:37:02.195580: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd6400 of size 1024 next 209
# 2023-10-29 18:37:02.195602: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd6800 of size 1024 next 198
# 2023-10-29 18:37:02.195625: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd6c00 of size 1024 next 291
# 2023-10-29 18:37:02.195648: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd7000 of size 1024 next 288
# 2023-10-29 18:37:02.195669: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd7400 of size 1024 next 289
# 2023-10-29 18:37:02.195691: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd7800 of size 1024 next 286
# 2023-10-29 18:37:02.195713: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd7c00 of size 1024 next 239
# 2023-10-29 18:37:02.195735: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd8000 of size 1024 next 284
# 2023-10-29 18:37:02.195757: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd8400 of size 1024 next 282
# 2023-10-29 18:37:02.195779: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd8800 of size 1024 next 278
# 2023-10-29 18:37:02.195800: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd8c00 of size 1024 next 275
# 2023-10-29 18:37:02.195822: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd9000 of size 1024 next 253
# 2023-10-29 18:37:02.195845: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd9400 of size 1024 next 228
# 2023-10-29 18:37:02.195869: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd9800 of size 1024 next 227
# 2023-10-29 18:37:02.195890: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfd9c00 of size 1024 next 223
# 2023-10-29 18:37:02.195910: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfda000 of size 1024 next 233
# 2023-10-29 18:37:02.195932: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfda400 of size 1024 next 263
# 2023-10-29 18:37:02.195954: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfda800 of size 1024 next 242
# 2023-10-29 18:37:02.195976: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfdac00 of size 1024 next 248
# 2023-10-29 18:37:02.195999: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfdb000 of size 1024 next 256
# 2023-10-29 18:37:02.196021: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfdb400 of size 1024 next 270
# 2023-10-29 18:37:02.196043: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfdb800 of size 1024 next 272
# 2023-10-29 18:37:02.196065: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfdbc00 of size 1792 next 166
# 2023-10-29 18:37:02.196088: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfdc300 of size 46080 next 167
# 2023-10-29 18:37:02.196111: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecfe7700 of size 63744 next 46
# 2023-10-29 18:37:02.196135: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ecff7000 of size 2097152 next 45
# 2023-10-29 18:37:02.196158: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ed1f7000 of size 2097152 next 48
# 2023-10-29 18:37:02.196191: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ed3f7000 of size 262144 next 87
# 2023-10-29 18:37:02.196214: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ed437000 of size 262144 next 82
# 2023-10-29 18:37:02.196238: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ed477000 of size 262144 next 89
# 2023-10-29 18:37:02.196261: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ed4b7000 of size 262144 next 91
# 2023-10-29 18:37:02.196283: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ed4f7000 of size 262144 next 93
# 2023-10-29 18:37:02.196306: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ed537000 of size 262144 next 95
# 2023-10-29 18:37:02.196328: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ed577000 of size 262144 next 97
# 2023-10-29 18:37:02.196352: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ed5b7000 of size 2359296 next 76
# 2023-10-29 18:37:02.196379: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ed7f7000 of size 2097152 next 154
# 2023-10-29 18:37:02.196403: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ed9f7000 of size 2777088 next 38
# 2023-10-29 18:37:02.196425: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55edc9d000 of size 15360000 next 37
# 2023-10-29 18:37:02.196448: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55eeb43000 of size 2097152 next 108
# 2023-10-29 18:37:02.196470: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55eed43000 of size 262144 next 106
# 2023-10-29 18:37:02.196494: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55eed83000 of size 262144 next 74
# 2023-10-29 18:37:02.196516: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55eedc3000 of size 262144 next 147
# 2023-10-29 18:37:02.196538: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55eee03000 of size 262144 next 146
# 2023-10-29 18:37:02.196562: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55eee43000 of size 262144 next 136
# 2023-10-29 18:37:02.196584: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55eee83000 of size 262144 next 137
# 2023-10-29 18:37:02.196606: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55eeec3000 of size 262144 next 110
# 2023-10-29 18:37:02.196629: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55eef03000 of size 262144 next 133
# 2023-10-29 18:37:02.196653: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55eef43000 of size 2097152 next 130
# 2023-10-29 18:37:02.196675: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef143000 of size 2097152 next 125
# 2023-10-29 18:37:02.196697: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef343000 of size 1024 next 218
# 2023-10-29 18:37:02.196719: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef343400 of size 1024 next 268
# 2023-10-29 18:37:02.196742: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef343800 of size 1024 next 211
# 2023-10-29 18:37:02.196764: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef343c00 of size 1024 next 235
# 2023-10-29 18:37:02.196788: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef344000 of size 8192 next 280
# 2023-10-29 18:37:02.196811: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef346000 of size 1024 next 254
# 2023-10-29 18:37:02.196843: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef346400 of size 1024 next 206
# 2023-10-29 18:37:02.196866: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef346800 of size 1024 next 273
# 2023-10-29 18:37:02.196890: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef346c00 of size 1024 next 204
# 2023-10-29 18:37:02.196912: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef347000 of size 1024 next 306
# 2023-10-29 18:37:02.196935: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef347400 of size 1024 next 202
# 2023-10-29 18:37:02.196959: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef347800 of size 8192 next 219
# 2023-10-29 18:37:02.196982: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef349800 of size 1024 next 264
# 2023-10-29 18:37:02.197004: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef349c00 of size 1024 next 305
# 2023-10-29 18:37:02.197027: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34a000 of size 1024 next 250
# 2023-10-29 18:37:02.197050: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34a400 of size 256 next 292
# 2023-10-29 18:37:02.197073: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34a500 of size 256 next 287
# 2023-10-29 18:37:02.197095: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34a600 of size 256 next 215
# 2023-10-29 18:37:02.197118: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34a700 of size 256 next 249
# 2023-10-29 18:37:02.197141: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34a800 of size 256 next 307
# 2023-10-29 18:37:02.197164: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34a900 of size 256 next 308
# 2023-10-29 18:37:02.197188: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34aa00 of size 256 next 309
# 2023-10-29 18:37:02.197210: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34ab00 of size 256 next 310
# 2023-10-29 18:37:02.197232: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34ac00 of size 256 next 311
# 2023-10-29 18:37:02.197254: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34ad00 of size 256 next 312
# 2023-10-29 18:37:02.197277: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34ae00 of size 256 next 313
# 2023-10-29 18:37:02.197301: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34af00 of size 256 next 314
# 2023-10-29 18:37:02.197323: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34b000 of size 256 next 315
# 2023-10-29 18:37:02.197345: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34b100 of size 256 next 316
# 2023-10-29 18:37:02.197367: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34b200 of size 256 next 317
# 2023-10-29 18:37:02.197390: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34b300 of size 256 next 318
# 2023-10-29 18:37:02.197412: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34b400 of size 256 next 319
# 2023-10-29 18:37:02.197435: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34b500 of size 256 next 320
# 2023-10-29 18:37:02.197459: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34b600 of size 256 next 321
# 2023-10-29 18:37:02.197482: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34b700 of size 256 next 322
# 2023-10-29 18:37:02.197504: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34b800 of size 256 next 323
# 2023-10-29 18:37:02.197527: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34b900 of size 256 next 324
# 2023-10-29 18:37:02.197551: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34ba00 of size 256 next 399
# 2023-10-29 18:37:02.197574: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34bb00 of size 256 next 383
# 2023-10-29 18:37:02.197597: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34bc00 of size 256 next 334
# 2023-10-29 18:37:02.197620: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34bd00 of size 256 next 390
# 2023-10-29 18:37:02.197644: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34be00 of size 256 next 356
# 2023-10-29 18:37:02.197667: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34bf00 of size 256 next 378
# 2023-10-29 18:37:02.197690: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34c000 of size 256 next 271
# 2023-10-29 18:37:02.197713: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34c100 of size 256 next 327
# 2023-10-29 18:37:02.197736: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34c200 of size 256 next 403
# 2023-10-29 18:37:02.197759: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34c300 of size 256 next 345
# 2023-10-29 18:37:02.197782: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34c400 of size 256 next 380
# 2023-10-29 18:37:02.197803: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34c500 of size 256 next 398
# 2023-10-29 18:37:02.197827: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34c600 of size 256 next 340
# 2023-10-29 18:37:02.197850: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34c700 of size 256 next 360
# 2023-10-29 18:37:02.197872: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34c800 of size 256 next 364
# 2023-10-29 18:37:02.197896: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34c900 of size 256 next 331
# 2023-10-29 18:37:02.197920: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f55ef34ca00 of size 256 next 368
# 2023-10-29 18:37:02.197942: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34cb00 of size 256 next 384
# 2023-10-29 18:37:02.197965: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34cc00 of size 256 next 376
# 2023-10-29 18:37:02.197988: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34cd00 of size 256 next 373
# 2023-10-29 18:37:02.198011: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34ce00 of size 256 next 418
# 2023-10-29 18:37:02.198034: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34cf00 of size 256 next 355
# 2023-10-29 18:37:02.198059: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34d000 of size 1024 next 295
# 2023-10-29 18:37:02.198085: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef34d400 of size 12288 next 299
# 2023-10-29 18:37:02.198108: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef350400 of size 256 next 412
# 2023-10-29 18:37:02.198131: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f55ef350500 of size 256 next 336
# 2023-10-29 18:37:02.198165: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef350600 of size 256 next 379
# 2023-10-29 18:37:02.198189: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f55ef350700 of size 2816 next 365
# 2023-10-29 18:37:02.198213: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef351200 of size 4608 next 241
# 2023-10-29 18:37:02.198239: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef352400 of size 262144 next 285
# 2023-10-29 18:37:02.198264: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef392400 of size 262144 next 283
# 2023-10-29 18:37:02.198289: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef3d2400 of size 3345408 next 161
# 2023-10-29 18:37:02.198313: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef703000 of size 3039232 next 71
# 2023-10-29 18:37:02.198337: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55ef9e9000 of size 15360000 next 70
# 2023-10-29 18:37:02.198361: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f088f000 of size 2097152 next 172
# 2023-10-29 18:37:02.198384: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f0a8f000 of size 28622848 next 101
# 2023-10-29 18:37:02.198410: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f25db000 of size 15360000 next 102
# 2023-10-29 18:37:02.198433: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f3481000 of size 15360000 next 139
# 2023-10-29 18:37:02.198456: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f4327000 of size 46080 next 279
# 2023-10-29 18:37:02.198479: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f4332400 of size 60160 next 293
# 2023-10-29 18:37:02.198509: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f4340f00 of size 46080 next 294
# 2023-10-29 18:37:02.198532: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f434c300 of size 8192 next 407
# 2023-10-29 18:37:02.198556: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f434e300 of size 87040 next 296
# 2023-10-29 18:37:02.198579: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f4363700 of size 322816 next 255
# 2023-10-29 18:37:02.198603: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f43b2400 of size 262144 next 251
# 2023-10-29 18:37:02.198627: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f43f2400 of size 262144 next 266
# 2023-10-29 18:37:02.198651: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f4432400 of size 23040 next 385
# 2023-10-29 18:37:02.198676: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f4437e00 of size 37120 next 303
# 2023-10-29 18:37:02.198701: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f4440f00 of size 464128 next 259
# 2023-10-29 18:37:02.198725: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f44b2400 of size 478208 next 229
# 2023-10-29 18:37:02.198749: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f4527000 of size 2097152 next 257
# 2023-10-29 18:37:02.198773: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f4727000 of size 262144 next 301
# 2023-10-29 18:37:02.198796: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f4767000 of size 2359296 next 237
# 2023-10-29 18:37:02.198819: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f49a7000 of size 262144 next 262
# 2023-10-29 18:37:02.198842: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f55f49e7000 of size 262144 next 224
# ...
# 2023-10-29 18:37:02.202360: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 4744339098798192052
# 2023-10-29 18:37:02.202395: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 5436486853785445878
# 2023-10-29 18:37:02.202427: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 688561331490260950
# 2023-10-29 18:37:02.202462: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 548164241756985438
# 2023-10-29 18:37:02.202494: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 15016051683243125840
# 2023-10-29 18:37:02.202524: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 5540512307737603848
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> train(tib_eng_translator)
#
# /home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb Cell 12 line 1
#      <a href='vscode-notebook-cell:/home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb#X14sZmlsZQ%3D%3D?line=14'>15</a> tib_eng_val_ds = make_dataset(val_pairs, batch_size)
#      <a href='vscode-notebook-cell:/home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb#X14sZmlsZQ%3D%3D?line=16'>17</a> # fit model to dataset batch
# ---> <a href='vscode-notebook-cell:/home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb#X14sZmlsZQ%3D%3D?line=17'>18</a> tib_eng_translator.fit(
#      <a href='vscode-notebook-cell:/home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb#X14sZmlsZQ%3D%3D?line=18'>19</a> tib_eng_train_ds,
#      <a href='vscode-notebook-cell:/home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb#X14sZmlsZQ%3D%3D?line=19'>20</a> epochs=100,
#      <a href='vscode-notebook-cell:/home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb#X14sZmlsZQ%3D%3D?line=20'>21</a> validation_data=tib_eng_val_ds,
#      <a href='vscode-notebook-cell:/home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb#X14sZmlsZQ%3D%3D?line=21'>22</a> callbacks=[loss_callback]
#      <a href='vscode-notebook-cell:/home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb#X14sZmlsZQ%3D%3D?line=22'>23</a> )
#      <a href='vscode-notebook-cell:/home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb#X14sZmlsZQ%3D%3D?line=24'>25</a> # save the model
#      <a href='vscode-notebook-cell:/home/j/Documents/Projects/Iron-Bridge/lotsawa/notebooks/streamlined-modeling.ipynb#X14sZmlsZQ%3D%3D?line=25'>26</a> tib_eng_translator.save('/home/j/Documents/Projects/Iron-Bridge/lotsawa/models/tib-eng-translator-0.4.1.'+str(i)+'.keras')
#
# File ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:60, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53   # Convert any objects of type core_types.Tensor to Tensor.
#      54   inputs = [
#      55       tensor_conversion_registry.convert(t)
#      56       if isinstance(t, core_types.Tensor)
#      57       else t
#      58       for t in inputs
#      59   ]
# ---> 60   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                       inputs, attrs, num_outputs)
#      62 except core._NotOkStatusException as e:
#      63   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node tib_eng_translator/model_1/dense/Softmax defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#
#   File "/home/j/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1053, in launch_instance
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#
#   File "/home/j/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#
#   File "/home/j/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#
#   File "/home/j/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#
#   File "/home/j/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/home/j/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#
#   File "/home/j/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#
#   File "/home/j/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#
#   File "/tmp/ipykernel_64461/3911765277.py", line 1, in <module>
#
#   File "/tmp/ipykernel_64461/795088789.py", line 18, in train
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1783, in fit
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1377, in train_function
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1360, in step_function
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1349, in run_step
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1126, in train_step
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 589, in __call__
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 589, in __call__
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py", line 255, in call
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/activations.py", line 87, in softmax
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/backend.py", line 5450, in softmax
#
# Detected at node tib_eng_translator/model_1/dense/Softmax defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#
#   File "/home/j/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1053, in launch_instance
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#
#   File "/home/j/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#
#   File "/home/j/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#
#   File "/home/j/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#
#   File "/home/j/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#
#   File "/home/j/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/home/j/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#
#   File "/home/j/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#
#   File "/home/j/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#
#   File "/tmp/ipykernel_64461/3911765277.py", line 1, in <module>
#
#   File "/tmp/ipykernel_64461/795088789.py", line 18, in train
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1783, in fit
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1377, in train_function
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1360, in step_function
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1349, in run_step
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1126, in train_step
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 589, in __call__
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 589, in __call__
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py", line 255, in call
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/activations.py", line 87, in softmax
#
#   File "/home/j/.local/lib/python3.10/site-packages/keras/src/backend.py", line 5450, in softmax
#
# 2 root error(s) found.
#   (0) RESOURCE_EXHAUSTED:  OOM when allocating tensor with shape[128,45,15000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node tib_eng_translator/model_1/dense/Softmax}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[broadcast_weights_1/assert_broadcastable/AssertGuard/pivot_f/_15/_115]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#   (1) RESOURCE_EXHAUSTED:  OOM when allocating tensor with shape[128,45,15000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node tib_eng_translator/model_1/dense/Softmax}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_27733]
